# %% [markdown]
# This notebook is a copy of /om2/user/ckauf/perturbed-neural-nlp/ressources/stimuli_creation/create-concatenated-control.ipynb
#
#
# To run it:
# srun -t 03:00:00 --mem=30G --pty bash
#
# cd /om2/user/ckauf/perturbed-neural-nlp
#
# source /om2/user/ckauf/anaconda39/etc/profile.d/conda.sh
#
# conda activate perturbed3.8
#
# cd /om/user/gretatu/perturbed-neural-nlp/
#
# unset XDG_RUNTIME_DIR (alias xdg)
#
# jupyter notebook --ip=0.0.0.0 --port=1111 --no-browser
#
#
# Here, we create materials based on chatGPT https://chat.openai.com/chat on 20230206.

# %%
import re
from pathlib import Path
from os.path import abspath
import os
import numpy as np
import random
import pickle
import csv
import subprocess
import pandas as pd

# %%
save = False

# %% [markdown]
# # Fetch stimulus set to have a csv we can pass to chatGPT

# %%
importpath = abspath('../..')
# importpath = '/om2/user/ckauf/perturbed-neural-nlp'
os.chdir(importpath)
print(os.getcwd())
# Out:
# /om/user/gretatu/perturbed-neural-nlp

# %%
from neural_nlp.benchmarks.neural import *
import neural_nlp
from neural_nlp.stimuli import StimulusSet
import xarray as xr

benchmark_pool = [
    # primary benchmarks
    ('Pereira2018-encoding', PereiraEncoding),
]
benchmark_pool = {identifier: LazyLoad(lambda identifier=identifier, ctr=ctr: ctr(identifier=identifier))
                  for identifier, ctr in benchmark_pool}

# fetch stimulus set
benchmark = benchmark_pool['Pereira2018-encoding']
stimuli_df = benchmark._target_assembly.attrs['stimulus_set']
stimuli_df
# Out:
# /om2/user/ckauf/anaconda39/envs/perturbed3.8/lib/python3.8/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)
# Loading lookup from /om2/user/ckauf/anaconda39/envs/perturbed3.8/lib/python3.8/site-packages/brainio_collection/lookup.csv
# /om2/user/ckauf/anaconda39/envs/perturbed3.8/lib/python3.8/site-packages/xarray/core/dataarray.py:219: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   elif isinstance(data, pd.Panel):
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture, it does not ...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                   A woman is a female human adult.           380
# 624    A woman is stereotypically seen as a caregiver.           381
# 625     A woman can become pregnant and bear children.           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
# [627 rows x 8 columns]

# %%
# Save copy of the stimulus df
stimuli_df_copy = stimuli_df.copy(deep=True)
if save:
    stimuli_df_copy.to_csv('Pereira2018_stimulus_set_20220209.csv')

# %% [markdown]
# ## Prep the stimulus_df

# %%
#get original sentences
original_sentences = list(stimuli_df_copy.sentence.values)

# %%
# Same regex used in e.g. 2_create_information-loss-manipulation.ipynb

# %%
stimuli_df_copy['sentence_stripped'] = [re.sub(r'[^\w\d\s\'\-\$\%]+', '', sent.lower()) + "." for sent in original_sentences]

# %%
stimuli_df_copy
# Out:
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture, it does not ...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                   A woman is a female human adult.           380
# 624    A woman is stereotypically seen as a caregiver.           381
# 625     A woman can become pregnant and bear children.           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category  \
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
#                                      sentence_stripped
# 0    beekeeping encourages the conservation of loca...
# 1    it is in every beekeeper's interest to conserv...
# 2    as a passive form of agriculture it does not r...
# 3    beekeepers also discourage the use of pesticid...
# 4    artisanal beekeepers go to extremes for their ...
# ..                                                 ...
# 622  some windows have multiple panes to increase i...
# 623                   a woman is a female human adult.
# 624    a woman is stereotypically seen as a caregiver.
# 625     a woman can become pregnant and bear children.
# 626  a woman has different reproductive organs than...
#
# [627 rows x 9 columns]

# %%
# Add number of words (separated by whitespace) in each sentence
stimuli_df_copy['num_words_sentence_stripped'] = [len(x.split(' ')) for x in stimuli_df_copy.sentence_stripped]

# %%
stimuli_df_copy.iloc[5].sentence_stripped
# Out:
# 'artisanal honey-making emphasizes quality and character over quantity and consistency.'

# %%
stimuli_df_copy.iloc[5].num_words_sentence_stripped
# Out:
# 10

# %% [markdown]
# ## Create chatGPT paraphrase benchmark

# %% [markdown]
# The prompt was:
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.

# %%
for i, row in enumerate(stimuli_df_copy.itertuples()):
    print(row.stimulus_id + ' ' + row.sentence)
    if i % 8 ==7:
        print('\nFor each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.\n') # pbs manullay change between expt nums
# Out:
# 243sentences.0 Beekeeping encourages the conservation of local habitats.
# 243sentences.1 It is in every beekeeper's interest to conserve local plants that produce pollen.
# 243sentences.2 As a passive form of agriculture, it does not require that native vegetation be cleared to make way for crops.
# 243sentences.3 Beekeepers also discourage the use of pesticides on crops, because they could kill the honeybees.
# 243sentences.4 Artisanal beekeepers go to extremes for their craft, but their product is worth the effort.
# 243sentences.5 Artisanal honey-making emphasizes quality and character over quantity and consistency.
# 243sentences.6 To produce the finest honey, beekeepers become micromanagers of their honeybees.
# 243sentences.7 They scout the fields, know when nectar flows, and select the best ways to extract honey.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.8 As the beekeeper opens the hive, the deep hum of 40,000 bees fills the air.
# 243sentences.9 The beekeeper checks honey stores, pollen supplies, and the bee nursery.
# 243sentences.10 Bees crawl across his bare arms and hands, but they don't sting, because they're gentle.
# 243sentences.11 I have a recurring dream about exams, even though I'm no longer in college.
# 243sentences.12 In my dream, it's the day of my final exam and I suddenly realize I've never gone to class.
# 243sentences.13 I've never even done any of the reading assignments.
# 243sentences.14 I know many other people who have the same nightmare.
# 243sentences.15 Each morning, participants in the study had to write down their dream experience from the previous night.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.16 They recorded if they recalled any dreams, and described each dream and its emotional intensity.
# 243sentences.17 Participants then assigned each dream to a category, such as a flying dream, a bad dream, or a nightmare.
# 243sentences.18 Every night while we sleep, our minds are as active as when we are awake.
# 243sentences.19 We dream throughout the night, in cycles of about ninety minutes each.
# 243sentences.20 Images, feelings, stories, and strange combinations of characters and places can fill our dreams.
# 243sentences.21 When I decided to start playing cards, things went from bad to worse.
# 243sentences.22 Gambling was something I had to do, and I had already spent close to $10,000 doing it.
# 243sentences.23 My friends were sick of watching me gamble my savings away.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.24 The hardest part was the horror of leaving a casino after losing money I did not have.
# 243sentences.25 Good data on the social and economic effects of legalized gambling are hard to come by.
# 243sentences.26 Some studies indicate that having a casino nearby makes gambling problems more likely.
# 243sentences.27 Gambling may also be associated with personal bankruptcies and marriage problems.
# 243sentences.28 Over the past generation, there has been a dramatic expansion of legalized gambling.
# 243sentences.29 Most states have instituted lotteries, and many have casinos as well.
# 243sentences.30 Gambling has become very big but controversial business.
# 243sentences.31 The wind from the hurricane shook the house, shattering a window in the kitchen.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.32 We ran in, grabbed some food, slammed the door, and surrendered the kitchen to the hurricane.
# 243sentences.33 I was afraid our house would be ripped from its foundation.
# 243sentences.34 Later that night, with the wind shaking the house, we fell asleep huddled on the sofa.
# 243sentences.35 Hurricanes can tear limbs off of trees and suck houses off their foundations.
# 243sentences.36 They dump heavy rains that can trigger floods and mudslides.
# 243sentences.37 Hurricanes can also bring a storm surge: a wall of ocean water that lurches onto land.
# 243sentences.38 Scientists use several methods to look for evidence of ancient hurricanes.
# 243sentences.39 The strongest storms deposited layers of windblown beach sand at the bottoms of coastal lakes.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.40 Trees drenched by passing hurricanes preserve a record of each storm in their growth rings.
# 243sentences.41 American ice cream is exported around the world, but different countries have different preferences.
# 243sentences.42 Many people enjoy their ice cream flavored with local delicacies.
# 243sentences.43 In some tropical places, vanilla ice cream is topped with bananas and fresh mangos.
# 243sentences.44 I remember making ice cream at home as a child.
# 243sentences.45 We poured the cream mixture into a frozen tub, then start turning the crank to expose it to the cold.
# 243sentences.46 Eventually it froze enough that I couldn't turn the hand crank any more.
# 243sentences.47 Then I put the container of half-frozen ice cream into the freezer to harden.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.48 Ice cream is a mixture of milk or cream, sugar, flavorings, and up to half whipped-in air.
# 243sentences.49 The butterfat in milk and cream is what makes it smooth and silky.
# 243sentences.50 High-priced premium ice cream is loaded with butterfat and natural flavorings.
# 243sentences.51 When I use the riding lawn mower, the uncomfortable chair makes my back hurt.
# 243sentences.52 I use the two levers in front of me to control the machine.
# 243sentences.53 The sharp blades underneath the lawn mower precisely sever each blade of grass.
# 243sentences.54 Mowing the lawn is a long task and it has taught me patience.
# 243sentences.55 A lawn mower is a machine with revolving blades that cut grass to an even height.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.56 The blades may be powered by muscle or the machine may have a motor.
# 243sentences.57 The most common power source for lawn mowers is a small gas engine.
# 243sentences.58 Electric lawnmowers are better for the environment because they do not create emissions.
# 243sentences.59 They also need less maintenance and are less expensive to run.
# 243sentences.60 Electric lawn mowers use as much electricity as an ordinary toaster.
# 243sentences.61 Astronauts train a long time for their spacewalks.
# 243sentences.62 Much of their training is conducted underwater.
# 243sentences.63 They may spend 8 to 10 hours in the pool for every hour they will spend floating in space.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.64 Astronauts practice to be able to perform construction and repair work on the outside of the space station.
# 243sentences.65 The commanders of shuttle flights are always pilots, and many have backgrounds as military test pilots.
# 243sentences.66 Other astronauts are trained as doctors, engineers, and scientists, who can run experiments in space.
# 243sentences.67 Early crews were all young men, but astronauts now are much more diverse.
# 243sentences.68 The team of astronauts floated out together to the exterior of the space shuttle.
# 243sentences.69 They carried tools needed to repair the broken part on the huge telescope.
# 243sentences.70 One astronaut loosened the bolts on the pipe, while the other fitted the replacement part into place.
# 243sentences.71 Computers have been used in art for a long time by experimental artists.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.72 Now that computers are more affordable and widespread, computer graphics have entered the mainstream art world.
# 243sentences.73 Some computer science conferences have art exhibitions that showcase the latest graphics technology.
# 243sentences.74 Brand new conferences have sprung up that are devoted to bridging the two cultures.
# 243sentences.75 The computer graphics specialist works with doctors to visualize medical conditions and surgical procedures.
# 243sentences.76 She uses digital animation to help doctors understand structures within a patient's body.
# 243sentences.77 Seeing the internal structures in an animation on a screen is much clearer than squinting at X-rays.
# 243sentences.78 Modern digital animation is a powerful tool for education.
# 243sentences.79 As the field of computer graphics broadens, we must ask if graphics actually help students.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.80 Research does suggest that vivid and engaging digital imagery can be effective in the classroom.
# 243sentences.81 The reason he came to law school in the first place was cliche.
# 243sentences.82 He wanted to change things for the better.
# 243sentences.83 He recalled one evening at law school when he and the program director had pulled an all-nighter.
# 243sentences.84 They finally finished drafting a petition for several evicted families at sunrise.
# 243sentences.85 Over the past four decades, the cost of legal education has gone up relentlessly.
# 243sentences.86 Private law school tuition increased by a factor of four since the 1970s.
# 243sentences.87 The market for admission to law school and for new lawyers could eventually crash.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.88 Law school faculty often have minimal experience in actually practicing law.
# 243sentences.89 Professors focus on writing law review articles for prestigious journals.
# 243sentences.90 Law schools often emphasize the theoretical, with classes on topics like property law in feudal England.
# 243sentences.91 Pharmacists are increasingly involved in preventive care.
# 243sentences.92 They are becoming front-line health advisers because people go to pharmacies often.
# 243sentences.93 Pharmacists are often a good source of information about public health.
# 243sentences.94 Doctors consult with pharmacists because they know a lot about drug interactions and side effects.
# 243sentences.95 Pharmacists dispense prescription drugs to patients and offer advice about the safe use of medications.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.96 They also conduct health and wellness screenings and provide vaccines.
# 243sentences.97 Pharmacists must have professional degrees and pass two exams in order to be licensed.
# 243sentences.98 I think the pharmacy profession chose me as much as I chose to be a pharmacist.
# 243sentences.99 I was fascinated by the neatly arranged bottles in pharmacies as a child.
# 243sentences.100 I know it's cliche, but I love the impact that I have on lives of my patients.
# 243sentences.101 Each person has his or her own response to potentially stressful situations.
# 243sentences.102 One person may be devastated by unemployment, while another may find working fulltime stressful.
# 243sentences.103 There are everyday stresses, like being stuck in traffic.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.104 There are also traumatic stresses, such as divorce or loss of a child.
# 243sentences.105 Some people can adapt to different levels of stress.
# 243sentences.106 If not dealt with effectively, though, stress can take a real toll on health.
# 243sentences.107 Remember that it's your reaction to stress that determines if it will be harmful or beneficial.
# 243sentences.108 When my company was downsizing, I felt incredibly stressed and worried.
# 243sentences.109 My heart would race for no reason, and I even felt dizzy at times.
# 243sentences.110 Then, I started taking yoga to try to manage my stress level.
# 243sentences.111 The man wore a jet black tuxedo with satin stripes.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.112 It was made with rich fabric cut in the latest style.
# 243sentences.113 Clearly he had it tailored, as it fit the man perfectly.
# 243sentences.114 It looked like something a professional stylist would have picked out for a formal event.
# 243sentences.115 While the tuxedo is still preferred, today's grooms are making personal statements in wedding attire.
# 243sentences.116 Shorter jackets are on the cutting edge of wedding fashion for men.
# 243sentences.117 Grooms are also jazzing up their tuxedos with colorful shirts and satin ties.
# 243sentences.118 A tuxedo jacket is a tailless dinner jacket with black silk lapels.
# 243sentences.119 Black tie trousers should be a perfect match to the tuxedo jacket.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.120 The shirt should always be plain white and the tie should be black and match the jacket lapels.
# 243sentences.121 The concert pianist went blind in adulthood.
# 243sentences.122 Her blindness was caused by a genetic condition that slowly damaged the eyes.
# 243sentences.123 She told interviewers that being blind was an advantage to a pianist.
# 243sentences.124 She had no visual distractions, so she could concentrate more fully on her music.
# 243sentences.125 The government defines blindness as vision insufficient for the ordinary activities of life.
# 243sentences.126 By establishing the parameters of legal blindness, resources can be focused on the legally blind.
# 243sentences.127 This may overlook those who have vision problems but who do not meet the standard.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.128 In developing countries, blindness in children is usually caused by infectious disease and nutritional deficiencies.
# 243sentences.129 These causes can often be prevented by medicine and vitamin supplements.
# 243sentences.130 In developed countries, blindness is more likely to be caused by genetic problems.
# 243sentences.131 No one really knows exactly how a taste gets from your mouth to your brain.
# 243sentences.132 Scientists think the process begins when a molecule of food touches a taste bud cell.
# 243sentences.133 The cell carries a taste message to taste nerves beneath the cell.
# 243sentences.134 It was once believed that each taste bud responded to one of the four basic tastes.
# 243sentences.135 That is, a taste bud on the tip of the tongue would respond only if you were eating something sweet.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.136 Scientists now think that a single taste bud can be sensitive to all of the basic tastes.
# 243sentences.137 My sense of taste isn't very good, so I tend to eat foods with very strong flavors.
# 243sentences.138 I like lots of hot sauce, and I drink my coffee with no cream, so it's very bitter.
# 243sentences.139 I can't even taste sweetness well, so when I make cookies I add extra sugar.
# 243sentences.140 Hip fractures are a real problem for aging individuals.
# 243sentences.141 Patients are faced with the pain of the break and the difficult process of healing.
# 243sentences.142 Families have to adjust to the patient's loss of independence.
# 243sentences.143 And for society, hip fractures involve substantial expense and time in the hospital.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.144 Halfway through the race, I heard a sound like someone snapping their fingers.
# 243sentences.145 I felt a crunch and I knew instantly that my foot was broken.
# 243sentences.146 Every step felt like running on spikes.
# 243sentences.147 At the doctor's office afterward, the x-ray clearly showed the fracture.
# 243sentences.148 There are a few different types of bone fracture.
# 243sentences.149 In closed or simple fractures, the bone is broken but the skin is intact.
# 243sentences.150 In open or compound fractures, the broken bone has punctured the skin and produced an open wound.
# 243sentences.151 New ear piercings can become infected if they're not carefully cleaned.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.152 Signs of infection include tenderness, swelling, or redness around the earlobe.
# 243sentences.153 If you see these symptoms, clean the area and apply some ointment.
# 243sentences.154 If the redness and swelling don't go away, contact your health care provider.
# 243sentences.155 A local hospital has initiated new measures to reduce infections.
# 243sentences.156 They have improved hand washing habits and ensured that infected patients are isolated from other patients.
# 243sentences.157 The hospital has seen infection rates drop since the new measures began.
# 243sentences.158 Scrubbing a wound with soap or alcohol delays healing, which increases the risk of infection.
# 243sentences.159 Band-aids can increase the risk of infection by holding in heat and moisture.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.160 Fortunately, most skin infections can easily be treated once they are diagnosed.
# 243sentences.161 Modern opera started at the end of the sixteenth century.
# 243sentences.162 It began as an effort to rediscover and imitate Greek tragic performance.
# 243sentences.163 Early founders of opera chose tales from antiquity for their subject matter.
# 243sentences.164 Later operas branched out into different sources of stories and musical traditions.
# 243sentences.165 Opera is an art form in which singers and musicians perform a play that combines words and music.
# 243sentences.166 It incorporates many of the elements of spoken theatre, such as acting, scenery, and costumes.
# 243sentences.167 Performances are typically given in an opera house and accompanied by an orchestra.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.168 The opera singer has worked hard to win the role in the new production.
# 243sentences.169 Her job is not just about singing.
# 243sentences.170 Acting, stage presence, and musical interpretation are all critical.
# 243sentences.171 But her pure, strong voice is certainly the star of the show.
# 243sentences.172 A painter must keep many elements in mind while completing a painting.
# 243sentences.173 She has to use solid elements of design, like strong composition and lighting.
# 243sentences.174 She has to execute the brush strokes with skill.
# 243sentences.175 Most importantly, the content of the painting should reveal a glimpse of the painter's soul.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.176 Long ago, painters were employed more as skilled artisans than as creative artists.
# 243sentences.177 However, prominent painters had the social status of scholars and members of the royal court.
# 243sentences.178 They signed their work, decided on its subject and imagery, and established a personal relationship with their patrons.
# 243sentences.179 As a painter, I learned to focus less on the actual scene and more on the painting itself.
# 243sentences.180 An artist's eye is not a camera lens that has to record everything within its field of vision.
# 243sentences.181 I found nature provides useful information, but more than is needed for a good painting.
# 243sentences.182 The eagle owl is an impressive bird.
# 243sentences.183 It has ear tufts that stick up like horns.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.184 Its large orange eyes are downright creepy, and look like they could pierce right through you.
# 243sentences.185 This owl hunts at night, flying swiftly and silently through the darkness.
# 243sentences.186 While some owl species have become endangered, others are thriving.
# 243sentences.187 The barred owl has spread well beyond its previous habitat.
# 243sentences.188 Early findings suggest that logging may have facilitated the barred owl's invasion.
# 243sentences.189 The owl landed on a thick branch and gripped it with her talons.
# 243sentences.190 She pressed her wings to her sides and settled down, half-closing an eye.
# 243sentences.191 She might have been a statue but for the glow of her eyes.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.192 It's unnerving to watch a polar bear stalk across floating sea ice.
# 243sentences.193 It's even worse when you are submerged in the frigid waters directly beneath the huge animal.
# 243sentences.194 Overhead, giant paws set down on the ice as the polar bear pursued its prey.
# 243sentences.195 As part of the film crew for a polar bear documentary, I spent months capturing these shots.
# 243sentences.196 Polar bears are one of the few animals that will attack people for reasons other than fear or confusion.
# 243sentences.197 They may attack out of hunger because they live in a food-scarce environment.
# 243sentences.198 They will sneak up on people slowly, careful to conserve their energy.
# 243sentences.199 The seal is an important part of the polar bear's diet.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.200 When hunting, they will wait by a seal's breathing hole, or stalk seals that are basking on the ice.
# 243sentences.201 The polar bear will crawl quietly forward and freeze in place when the seal looks around.
# 243sentences.202 The medieval castle was not a structure built primarily for defense.
# 243sentences.203 Its purpose was to dominate its surroundings.
# 243sentences.204 A castle could easily control lands within a day's walk.
# 243sentences.205 During times of attack, peasants, livestock, and property could be brought inside the castle's walls for protection.
# 243sentences.206 Spectacular castles in dramatic locations provide a record of the stormy history of many regions.
# 243sentences.207 Today, they stand atop rocky cliffs overlooking beautiful landscapes and quaint villages.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.208 In the past, they were home to battles, plots and intrigue.
# 243sentences.209 Upon leaving the train station we saw our hotel looming above:  a magnificent castle built on a cliff.
# 243sentences.210 The thick outside walls sheltered an inner courtyard hundreds of feet above the river.
# 243sentences.211 Our tower rooms had an incredible but slightly scary view.
# 243sentences.212 After climbing fifty feet up the side of the pyramid, the man gestured me into a small black entranceway.
# 243sentences.213 This led into the chamber at the pyramid's center.
# 243sentences.214 I followed him down the steep, dark, narrow Passage.
# 243sentences.215 The smell inside the pyramid was chalky and the air was thick.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.216 More than just the tomb of the king, pyramids represented the pride of the nation.
# 243sentences.217 The care that the pyramid builders took in their craft is evident.
# 243sentences.218 The stones covering the pyramid were precisely fitted together and polished until the structure gleamed.
# 243sentences.219 Architects are still working to solve the mysteries of how pyramids were constructed.
# 243sentences.220 Some think ramps were built inside the pyramid's walls to raise stone blocks.
# 243sentences.221 Others speculate that ramps zigzagged up the exterior walls of the pyramid.
# 243sentences.222 Even beginner rock climbing takes courage and strength.
# 243sentences.223 Climbers who are learning the sport can try scrambling on large boulders.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.224 Once they're comfortable with that, they can begin using ropes to safely climb vertical rock faces.
# 243sentences.225 All of the boys on the trip were new to rock climbing.
# 243sentences.226 Many were afraid of heights.
# 243sentences.227 Having someone else check their knots and harnesses helped them calm down.
# 243sentences.228 The adults set up climbing routes appropriate for beginners.
# 243sentences.229 Free-climbing is one particular style of rock climbing.
# 243sentences.230 The climber relies solely on her skill and physical strength to ascend a rock face.
# 243sentences.231 Rope and bolts are the only equipment used.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.232 They are meant only to stop the climber if she falls.
# 243sentences.233 I hesitantly skied down the steep trail that my buddies convinced me to try.
# 243sentences.234 I made a bad turn and I found myself tumbling down.
# 243sentences.235 I finally came to a stop at a flat part of the slope.
# 243sentences.236 My skis were nowhere to be found and my poles were lodged in a snow drift up the hill.
# 243sentences.237 A major strength of professional skiers is how they use ski poles.
# 243sentences.238 Proper use of ski poles improves their balance and adds flair to their skiing.
# 243sentences.239 It minimizes the need for upper body movements to regain lost balance while skiing.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 243sentences.240 New ski designs and stiffer boots let skiers turn more quickly.
# 243sentences.241 But faster and tighter turns increase the twisting force on the legs.
# 243sentences.242 This has led to more injuries, particularly to ligaments in the skier's knee.
# 384sentences.0 An accordion is a portable musical instrument with two keyboards.
# 384sentences.1 One keyboard is used for individual notes, the other for chords.
# 384sentences.2 Accordions produce sound with bellows that blow air through reeds.
# 384sentences.3 An accordionist plays both keyboards while opening and closing the bellows.
# 384sentences.4 An apartment is a self-contained home that is part of a building.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.5 An apartment may have one or more rooms, as well as a kitchen and a bathroom.
# 384sentences.6 Some apartments are for single people, others for families.
# 384sentences.7 The building can have a garage, a laundry facility or extra storage space.
# 384sentences.8 An apple is a fruit that can be green, red or yellow.
# 384sentences.9 Apples have thin skin, a crisp, sweet pulp and seeds inside.
# 384sentences.10 Some very tart apples are used to make cider.
# 384sentences.11 Apples can be eaten raw, roasted or baked in pies.
# 384sentences.12 Arson is the criminal act of burning a building or wildland.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.13 A fire investigation determines if a fire was caused by accident or arson.
# 384sentences.14 Arson can be done to cause damage to others or collect insurance.
# 384sentences.15 The severity of the crime depends on whether people were harmed.
# 384sentences.16 An automobile, or car, is a wheeled vehicle for transporting passengers.
# 384sentences.17 A car can be powered by a gasoline or electric engine.
# 384sentences.18 The driver steers the car on roads, other passengers just sit.
# 384sentences.19 Automobiles vary in size, number of doors and the type of trunk.
# 384sentences.20 The axe is a tool used to split and cut wood.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.21 The axe usually consists of a head attached to a handle.
# 384sentences.22 Historically, axe heads were made of stone and then metal.
# 384sentences.23 Axes are used by woodcutters and firemen entering buildings.
# 384sentences.24 A banana is a long fruit that grows in bunchs, with a soft edible inside.
# 384sentences.25 A banana when ripe can be yellow, purple or red and have small brown spots.
# 384sentences.26 The greatest producers are tropical countries, such as India or Ecuador.
# 384sentences.27 Unripe bananas and plantains are staple foods and often cooked like potatoes.
# 384sentences.28 A bed is a piece of furniture used as a place to sleep or have sex in.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.29 A bed is made of a mattress and a box spring, plus sheets, pillows and covers.
# 384sentences.30 In waterbeds the mattress is filled with water, and in airbeds it is filled with air.
# 384sentences.31 Another type of bed is the hammock, a fabric sling suspended above the ground.
# 384sentences.32 A bee is a flying insect, with a black and yellow body and six legs.
# 384sentences.33 Bees spread pollen between flowers as they collect nectar to make honey.
# 384sentences.34 Bees are social insects and live together in a colony located in a hive.
# 384sentences.35 Many bees have stingers and can attack if they feel threatened.
# 384sentences.36 A bicycle is a vehicle with two wheels and pedals on a frame.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.37 A bicycle is propelled by the pedalling of a cyclist on the saddle.
# 384sentences.38 The wheels have rubber tires with an inner tube full of air.
# 384sentences.39 People use bicycles for transportation, recreation and racing.
# 384sentences.40 A blacksmith creates objects by forging iron or steel.
# 384sentences.41 A blacksmith hammers and bends hot iron on an anvil to change its shape.
# 384sentences.42 Blacksmiths wears a thick apron and handle the metal with tongs.
# 384sentences.43 Blacksmiths make objects like weapons, horse shoes or iron furniture.
# 384sentences.44 A blender is a kitchen appliance used to mix ingredients or puree food.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.45 Blenders have a glass or plastic container with a rotating blade in the bottom.
# 384sentences.46 Blenders are used to make milk shakes and fruit smoothies.
# 384sentences.47 Blenders are also used to make cold alcoholic drinks with crushed ice.
# 384sentences.48 A boy is a young male child who has not undergone puberty.
# 384sentences.49 The term is used to indicate sex distinctions relative to girls.
# 384sentences.50 Traditionally boys like to play rough games and fight with each other.
# 384sentences.51 An adult male behaving immaturely is often referred to as a boy.
# 384sentences.52 Broccoli is a plant in the cabbage family.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.53 Broccoli has a green flower head and a thick, tough stalk.
# 384sentences.54 Broccoli is high in vitamins, fiber and other nutrients.
# 384sentences.55 Broccoli can be boiled, stir-fried or eaten raw.
# 384sentences.56 A butterfly is a flying insect with four large wings.
# 384sentences.57 The wings of butterflies can be very colorful and patterned.
# 384sentences.58 Metamorphosis is the transformation of a caterpillar into a butterfly.
# 384sentences.59 Some people collect butterflies because of their colorful wings.
# 384sentences.60 A carpenter is an artist or manual laborer who works with wood.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.61 Carpenters build and repair houses, furniture, boats and other objects.
# 384sentences.62 Carpenters use tools such as hammers, saws, pliers and planes.
# 384sentences.63 A luthier is a carpenter that makes and repairs musical instruments.
# 384sentences.64 Cats are small furry animals with four legs and a tail.
# 384sentences.65 Cats like to groom themselves by licking their fur.
# 384sentences.66 Cats can hunt mice or birds, but are often fed by their owners.
# 384sentences.67 The claws of cats are retractable so that they keep sharp.
# 384sentences.68 A chair is a piece of furniture designed for people to sit on.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.69 Chairs consist of a seat raised above floor level, supported by legs.
# 384sentences.70 Chairs can also have back and arm rests, as well as a cushion.
# 384sentences.71 Seats are fixed chairs located in vehicles or in places like cinemas.
# 384sentences.72 A clarinet is a woodwind musical instrument.
# 384sentences.73 A clarinet is a long black tube with a flare at the bottom.
# 384sentences.74 The player chooses notes by pressing keys and holes.
# 384sentences.75 The clarinet is used both in jazz and classical music.
# 384sentences.76 A cod is a fish that lives in the colder areas of the Atlantic.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.77 Cod flesh is white and mild-tasting, and flakes easily when cooked.
# 384sentences.78 Fresh cod is used for fish and chips, salted cod for elaborate dishes.
# 384sentences.79 Cod has been caught, salted and traded since the time of the Vikings.
# 384sentences.80 Coffee is made from coffee beans, the seeds of the coffee plant.
# 384sentences.81 Coffee is a popular drink in many countries, and usually served hot.
# 384sentences.82 Coffee contains a mild drug called caffeine that keeps people awake.
# 384sentences.83 Coffee is the world's seventh-largest legal agricultural export.
# 384sentences.84 A desert is a natural environment where almost no rain falls.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.85 Hot deserts are usually filled with sand dunes or rocks.
# 384sentences.86 Some animals and plants have adapted to live in deserts.
# 384sentences.87 The biggest hot desert is the Sahara in northern Africa.
# 384sentences.88 A desk is a piece of furniture used for working at, sometimes with a computer.
# 384sentences.89 A desk has a flat surface and can be made of wood, plastic or metal.
# 384sentences.90 A desk may have drawers to store supplies and papers.
# 384sentences.91 A cubicle consists of a desk surrounded by partitions on three sides.
# 384sentences.92 A door is a movable barrier to entrance or exit from an enclosed area.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.93 Most doors have locks to control who gets to pass through them.
# 384sentences.94 Most doors are opened by pushing or pulling a handle after they are unlocked.
# 384sentences.95 Other types of doors can slide or consist of a revolving chamber.
# 384sentences.96 A dress is a piece of clothing that women sometimes wear.
# 384sentences.97 A dress is like a shirt attached to a long, matching skirt.
# 384sentences.98 A dress is usually worn at formal occasions, such as a wedding or a dance.
# 384sentences.99 It can be hard to climb stairs or ride a bike in a dress.
# 384sentences.100 Drunk driving is the act of driving under the effects of alcohol.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.101 Drunk driving of any vehicle is a crime in most of the world.
# 384sentences.102 It plays a role in almost half of all vehicle-related deaths.
# 384sentences.103 Drunk drivers are caught by field sobriety and breathing tests.
# 384sentences.104 A drought is a persistent shortage of the water supply caused by lack of rain.
# 384sentences.105 Drought will cause crops and plants to stop growing and die.
# 384sentences.106 Extreme drought will eventually turn areas into desert and cause famine.
# 384sentences.107 Large numbers of people have to migrate away from dust bowls.
# 384sentences.108 Eagles are large birds of prey that hunt during the day and have very good eyesight.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.109 Eagles have hooked beaks for tearing flesh, strong legs and sharp talons.
# 384sentences.110 Eagles live in eyries and some species eat fish and others small mammals.
# 384sentences.111 The bald eagle has a bright white head and is the national bird of the United States.
# 384sentences.112 Earthquakes shake the ground and can knock down buildings and other structures.
# 384sentences.113 The shaking can also trigger landslides and volcanic activity.
# 384sentences.114 Most earthquakes are caused by the release of energy in the Earth's crust.
# 384sentences.115 An earthquake at sea can displace the seabed and cause a tsunami.
# 384sentences.116 Elephants are the largest kind of land mammal, weighing several tons.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.117 An elephant has a long nose called a trunk, which can grab things or food.
# 384sentences.118 The elephant has a pair of ivory tusks, for moving objects or digging into trees.
# 384sentences.119 The elephant flaps its large ears to cool the blood in them and its body.
# 384sentences.120 The eye is an organ for sensing light and coding it for the visual cortex.
# 384sentences.121 Most animals have complex eyes which can detect color, motion and texture.
# 384sentences.122 The fovea is the center of the human eye and the most sensitive part of it.
# 384sentences.123 Insects have compound eyes made up of eye units facing in many directions.
# 384sentences.124 A farm is land used to grow plants or raise animals for food.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.125 Farmers are the people who run the farm and decide what to produce.
# 384sentences.126 Farms usually have a house for farmers, a silo and a barn.
# 384sentences.127 A cooperative is a farm where many farmers share the land and equipment.
# 384sentences.128 Primates usually have four fingers and a thumb on each hand.
# 384sentences.129 Fingers are used for grasping, writing, grooming and other activities.
# 384sentences.130 The fingertips are sensitive to temperature, pressure and vibration.
# 384sentences.131 The nail protects the tip of the finger and can be grown or decorated.
# 384sentences.132 A flood is an overflow of an expanse of water that submerges inhabited land.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.133 Flood can be caused by heavy rain or rapid snow melt, as well as earthquakes at sea.
# 384sentences.134 In a flood a river will flow out of its channel or break dams and levees.
# 384sentences.135 During a flood people evacuate and the contaminated water causes diseases.
# 384sentences.136 A floor is a horizontal surface inside a building, used for walking on.
# 384sentences.137 Floors may be made of bare concrete, tile, linoleum or wooden floorboards.
# 384sentences.138 People often put carpets on a floor, for comfort and to dampen noise.
# 384sentences.139 In buildings the floor often has pipes and electrical wiring under it.
# 384sentences.140 A foot is a body part on the end of a leg.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.141 People use their feet when walking, running or standing straight.
# 384sentences.142 People also use their feet to kick, in both fighting and sports.
# 384sentences.143 Many cultures have rules for behavior related to feet.
# 384sentences.144 A forest is an area with a high density of trees and canopy cover.
# 384sentences.145 The type of forest depends on temperature and rainfall in its location.
# 384sentences.146 A forest ecosystem has various types of trees and animals, as well as ground plants.
# 384sentences.147 Deforestation is the cutting down of forests disregarding regeneration.
# 384sentences.148 A fork is a tool for eating solid foods, with a handle and several tines.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.149 Forks are usually  made of metal, or plastic, if disposable.
# 384sentences.150 Forks are used to lift food to the mouth or to hold food in place while cutting.
# 384sentences.151 Forks are used in Western cultures, and there are special kinds for various foods.
# 384sentences.152 A frying pan is a small pan with sloping sides and a handle.
# 384sentences.153 A frying pan is used to fry, sear and brown food.
# 384sentences.154 The food is cooked on oil covering the bottom of the pan.
# 384sentences.155 Frying pans are made of iron or teflon-clad steel.
# 384sentences.156 A girl is a female human who has not yet reached maturity.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.157 At puberty the body of a girl develops into that of a woman.
# 384sentences.158 Girls often like playing with dolls and social games.
# 384sentences.159 Girls sometimes grow long hair and wear dresses and skirts.
# 384sentences.160 A glove is a piece of clothing that covers the hand and fingers.
# 384sentences.161 Gloves to protect against cold are made of wool or lined waterproof material.
# 384sentences.162 Disposable rubber or latex gloves are used to shield hands from germs or chemicals.
# 384sentences.163 A mitten is a kind of glove where the four fingers are covered together.
# 384sentences.164 A hammer is a tool used to deliver an impact to an object.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.165 A hammer is most often used to drive nails into wood.
# 384sentences.166 The claw on the head can be used to remove nails.
# 384sentences.167 Hammers vary in the shape of the head and handle length.
# 384sentences.168 A hand grenade is an explosive used as a weapon against people.
# 384sentences.169 Hand grenades are thrown and timed to explode a bit after that.
# 384sentences.170 Grenades can also be fired from rifles or shoulder launchers.
# 384sentences.171 Tear gas grenades are thrown into the middle of a mob to disperse it.
# 384sentences.172 A horse is a large hoofed mammal with four long, muscular legs.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.173 A horse has a tail and a mane on its neck, and is usually gray or brown.
# 384sentences.174 Horses have been used for draft work, travel and entertainment.
# 384sentences.175 A human can ride a horse while it walks, trots or gallops.
# 384sentences.176 People go to hospitals to be healed when they are sick or injured.
# 384sentences.177 Hospitals are staffed by professional physicians, surgeons, and nurses.
# 384sentences.178 Some patients go there for specialist diagnosis or therapy, leaving the same day.
# 384sentences.179 For some operations or treatments patients have to stay for several weeks.
# 384sentences.180 A house is a permanent building or structure for people or families to live in.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.181 A house has a roof and walls to keep out cold and rain, and windows to let light in.
# 384sentences.182 A house can have rooms for purposes like sleeping, cooking or washing.
# 384sentences.183 Most people leave the house to work and come back at night to eat and sleep.
# 384sentences.184 An igloo is a type of shelter made from blocks of snow by Inuit.
# 384sentences.185 Igloos are built in places where snow covers the land most of the time.
# 384sentences.186 Igloos are often built in the shape of a dome, with an entrance tunnel.
# 384sentences.187 Air pockets in snow insulate the space, and body heat warms igloos.
# 384sentences.188 A knife is a tool with a sharp edge that is used to cut things.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.189 Modern knives consist of a handle and a blade, usually made of metal.
# 384sentences.190 Knives have also been used as weapons and instruments in rituals.
# 384sentences.191 A knife can be used to attack by slashing, stabbing or throwing.
# 384sentences.192 Lentils are the seeds of a plant of the legume family.
# 384sentences.193 Lentils can be red, green, brown, black or yellow.
# 384sentences.194 Lentils are commonly used in Indian and Mediterranean cuisines.
# 384sentences.195 Lentils are cooked by boiling and are a great source of protein.
# 384sentences.196 Lettuce is a biennial plant often grown in temperate climates as a leaf vegetable.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.197 Lettuce can be eaten cold and raw, in salads and other dishes, or cooked.
# 384sentences.198 Lettuce is considered fairly easy to grow and a suitable crop for beginners.
# 384sentences.199 Most lettuce leaves taste bitter, but some are bred to remove the bitterness.
# 384sentences.200 A library is a place where a collection of books, documents and media is kept.
# 384sentences.201 Librarians work at libraries and are experts at finding and organizing information.
# 384sentences.202 People can go to public libraries and borrow books to take home for several weeks.
# 384sentences.203 Academic libraries support scholarly research and have specialized books.
# 384sentences.204 A log cabin is a small house built from round logs.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.205 Log cabin is a symbol of American frontier life and humble origins.
# 384sentences.206 Log cabins were used as first shelters by european settlers.
# 384sentences.207 Log cabins were built using logs with notch joints at the ends.
# 384sentences.208 A man is a male human adult.
# 384sentences.209 A boy becomes a man after passing through puberty.
# 384sentences.210 Manhood is associated with masculinity and virility.
# 384sentences.211 Men differ from women in height, weight, and body structure.
# 384sentences.212 Milk is a white liquid produced by female mammals to feed their young.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.213 Newborn animals must be fed milk before they can eat solid food.
# 384sentences.214 Dairy products such as cheese and butter are made from milk.
# 384sentences.215 Liquid produced from soybeans and coconuts is sometimes called milk.
# 384sentences.216 Mosquitos are thin, small flying insects that emit a high-pitched sound.
# 384sentences.217 Mosquitoes have mouthparts for piercing the skin of plants and animals.
# 384sentences.218 Female mosquitoes bite people and animals and suck their blood for protein.
# 384sentences.219 Mosquito bites can spread yellow fever, malaria and other parasite diseases.
# 384sentences.220 A mountain is a landform that rises steeply above surrounding land.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.221 Mountains rise higher than hills and sometimes have snow at the top.
# 384sentences.222 A range of mountains forms due to tectonic plate collision.
# 384sentences.223 Mountaineers are people who climb or hike up mountains.
# 384sentences.224 The mouth is the face cavity we put food in when we eat.
# 384sentences.225 The mouth has teeth to chew food and mix it with saliva.
# 384sentences.226 The mouth is also used for kissing and talking.
# 384sentences.227 Speech sounds are controlled by tongue placement in the mouth.
# 384sentences.228 A mug is a sturdy cup with a handle for drinking hot liquids.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.229 A mug is normally ceramic, but can also be made of metal or glass.
# 384sentences.230 A mug is thick and has a ring base for thermal insulation.
# 384sentences.231 Mugs can be plain or have drawings imprinted or carved on them.
# 384sentences.232 Murder is the unlawful killing of another human being with intent.
# 384sentences.233 Murder a serious crime because it deprives the victim of their existence.
# 384sentences.234 Killing in self-defense, accidentally or in war is not considered murder.
# 384sentences.235 A convicted murderer is often given a life sentence or the death penalty.
# 384sentences.236 Orange juice is a drink made from the liquid in orange pulp.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.237 Orange juice has a sweet, acid taste and contains a lot of vitamin C.
# 384sentences.238 Freshly squeezed orange juice often contains pulp as well.
# 384sentences.239 Orange juice is often drunk at breakfast from a glass.
# 384sentences.240 A parrot is a bird that lives in warm and tropical regions.
# 384sentences.241 Parrots have brightly-colored feathers and a sharp, curved beak.
# 384sentences.242 Parrots can imitate the human voice if they hear it repeatedly.
# 384sentences.243 Their appearance and abilities makes them popular pets.
# 384sentences.244 A peach is an orange-yellow fruit with a characteristic smell.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.245 The skin of a peach is thin and covered in small, fine hairs.
# 384sentences.246 Peaches have a large, red-brown stone inside which contains the seed.
# 384sentences.247 Peaches are sweet and delicate, and must be harvested after ripening.
# 384sentences.248 The piano is a popular musical instrument played by means of a keyboard.
# 384sentences.249 Pressing a piano key causes a felt-tipped hammer to hit a vibrating steel string.
# 384sentences.250 The piano has an enormous note range, and pedals to change the sound quality.
# 384sentences.251 The piano repertoire is large and famous pianists can give solo concerts.
# 384sentences.252 Piranhas are small, ferocious fish that live in South American rivers.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.253 Piranhas live and attack in schools and are most active during the day.
# 384sentences.254 Piranhas have very sharp teeth and are opportunistic carnivores.
# 384sentences.255 Piranhas eat fish, insects, lizards, mammals and carrion.
# 384sentences.256 The raspberry is a fruit that grows in forest clearings or fields.
# 384sentences.257 A single raspberry consists of many small fruits joined together.
# 384sentences.258 Raspberries are eaten by themselves or cooked with sugar into jam.
# 384sentences.259 Leaves of the raspberry are used fresh or dried in herbal teas.
# 384sentences.260 A raven is a large black bird that thrives in many climates.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.261 Ravens feed on carrion, insects, berries or small animals.
# 384sentences.262 Ravens have large brains and are capable of problem solving.
# 384sentences.263 In folklore ravens are birds of ill-omen and also tricksters.
# 384sentences.264 A refrigerator is a cooling device used to contain and preserve food.
# 384sentences.265 Some refrigerators can have a small compartment at freezing temperature.
# 384sentences.266 A refrigerator can have shelves and small compartments for different types of food.
# 384sentences.267 A refrigerator is generally white and people often put magnets on its surface.
# 384sentences.268 A rifle is a firearm that rests on the shoulder and has a barrel with twisting grooves.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.269 The grooves make the bullets spin around the rifle axis as they fly through the air.
# 384sentences.270 Rifles are used in hunting and shooting sports, sometimes with scopes.
# 384sentences.271 Assault rifles can fire in bursts and are the standard infantry weapon.
# 384sentences.272 Salmon is a fish that migrates from fresh water to the ocean and back to spawn.
# 384sentences.273 Salmon flesh is orange or red and has high protein content and a nice taste.
# 384sentences.274 Salmon can be eaten raw in sushi or cooked by grilling, poaching or in other ways.
# 384sentences.275 Salmon is the most common farmed fish, though it can also be caught in the wild.
# 384sentences.276 A saw is a tool that uses a hard blade or abrasive wire to cut hard materials.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.277 The small sharp points along the cutting side of the saw are called the teeth.
# 384sentences.278 Saws can be worked by hand, or powered by an electric motor or gas engine.
# 384sentences.279 Saws are used extensively in forestry, construction, carpentry and medicine.
# 384sentences.280 A scientist studies and produces new knowledge about the physical world.
# 384sentences.281 A scientist creates hypotheses and does experiments to test them.
# 384sentences.282 Physics, chemistry and biology are classic examples of sciences.
# 384sentences.283 Scientists publish their research in journals and conferences.
# 384sentences.284 Scissors are a two-bladed instrument used for cutting.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.285 The blades are usually metallic, with plastic or metal handles.
# 384sentences.286 Depending on the size and format, scissors can cut paper, hair or fabric.
# 384sentences.287 Shears are large scissors used for cutting shrubs or pieces of metal.
# 384sentences.288 A screwdriver is a tool for inserting and tightening screws into something.
# 384sentences.289 Screwdrivers can also be used to remove screws after they are inserted.
# 384sentences.290 The screwdriver tip applies the torque from rotating the handle.
# 384sentences.291 The two major types of screwdrivers are Phillips and flathead.
# 384sentences.292 A shark is a large fish with a cartilage skeleton.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.293 Sharks have streamlined bodies, with a large dorsal fin.
# 384sentences.294 Most sharks predate on fish and mammals, with powerful jaws.
# 384sentences.295 Sharks have very keen senses and can detect electrical fields.
# 384sentences.296 A ship is a large vehicle that floats and travels on water.
# 384sentences.297 A ship can be powered in the ocean by sails, steam, or diesel engines.
# 384sentences.298 Ships are used to fish in the ocean and to transport cargo containers.
# 384sentences.299 Cruise ships are floating hotels that take people between cities.
# 384sentences.300 A shoe is clothing for the foot, with a sole, an outsole and a heel.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.301 Shoes are usually made of leather, canvas, rubber or plastic.
# 384sentences.302 Women's shoes often have high heels and come in many styles and colors.
# 384sentences.303 A sneaker is a shoe for sports and athletic activity.
# 384sentences.304 A soldier is a member of the national armed forces who fights on land.
# 384sentences.305 A soldier in the militia must wear a uniform, usually camouflage.
# 384sentences.306 In a volunteer army, a soldier is paid for his or her work.
# 384sentences.307 A soldier fights using weapons such as rifles and grenades.
# 384sentences.308 Spears are weapons that consist of a pole and sharpened head at one end.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.309 Spears were the most common personal weapon before the advent of firearms.
# 384sentences.310 Spears were used for stabbing or throwing when fighting in war.
# 384sentences.311 Some native people still use the spear for hunting and fishing.
# 384sentences.312 Spiders are insects with eight legs that make silk.
# 384sentences.313 Spiders build webs with silk and use them to catch insects.
# 384sentences.314 Spiders use venomous fangs to paralyse their stuck prey.
# 384sentences.315 Spiders can be as small as a coin or as big as a bird.
# 384sentences.316 Swamps are low, spongy land subject to frequent inundation.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.317 A swamp is covered with shallow water, mud and vegetation.
# 384sentences.318 Swamps are nesting and breeding grounds for birds and reptiles.
# 384sentences.319 Farmers often drain swamps to produce fertile arable land.
# 384sentences.320 A sweater is a heavy garment worn on the torso for warmth.
# 384sentences.321 Sweaters are often knitted from wool but cotton is also common.
# 384sentences.322 A sweater that opens down the front is called a cardigan.
# 384sentences.323 Sweaters differ in cut, collar and sleeve shape, as well as decoration.
# 384sentences.324 A table is a piece of furniture with a flat surface and legs.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.325 There are usually chairs around a table for people to sit.
# 384sentences.326 People set cutlery, plates and food on a table to eat a meal together.
# 384sentences.327 Tables are also used as surfaces to work or write on.
# 384sentences.328 A television is an appliance with a screen that displays moving images.
# 384sentences.329 Televisions are mostly used for watching programs or films.
# 384sentences.330 They are used to play videogames when connected to a game console.
# 384sentences.331 Television content can be broadcast or received via cable or internet.
# 384sentences.332 Theft is the taking of person's property without their consent.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.333 Thieves steal to own something or to sell it to receivers.
# 384sentences.334 Theft is a crime and can be punishable with jail or fines.
# 384sentences.335 Industrial espionage is theft of ideas and intellectual property.
# 384sentences.336 A toaster is a kitchen appliance for toasting bread using heating elements.
# 384sentences.337 Pop-up toasters toast the bread placed in a slot and eject it once done.
# 384sentences.338 Toaster ovens have a door on the side, a tray within and temperature control.
# 384sentences.339 They allow bread to be cooked with toppings like garlic or cheese.
# 384sentences.340 The tomato is a shiny and smooth red fruit, with a savory taste.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.341 A tomato softens and changes color from green to red as it gets more ripe.
# 384sentences.342 Tomatoes can be used to make salads, soup or ketchup, as well as sauce.
# 384sentences.343 There are many varieties of tomato, with different sizes and tastes.
# 384sentences.344 A train is a connected series of cars that moves between stations on a track.
# 384sentences.345 The train is pulled by a locomotive, powered by diesel or electricity.
# 384sentences.346 A freight train transports containers of goods or fuel over long distances.
# 384sentences.347 Commuter trains transport people between suburbs and stations inside a city.
# 384sentences.348 A train station is a place where passengers get on or off a train.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.349 Train stations have counters or machines for purchasing tickets.
# 384sentences.350 There are waiting rooms and places to eat in a station.
# 384sentences.351 Passengers or cargo trains enter from a platform next to the line.
# 384sentences.352 A tropical cyclone is a storm formed over warm tropical sea.
# 384sentences.353 Cyclones can produce very powerful winds and torrential rain.
# 384sentences.354 Tropical cyclone can also cause high waves and coastal flooding.
# 384sentences.355 A tropical cyclone can move inland and seriously damage property.
# 384sentences.356 The violin is an instrument with four strings that is played with a bow.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.357 Violin is the smallest and highest pitched instrument in its family.
# 384sentences.358 A violinist holds the instrument between the chin and the collarbone.
# 384sentences.359 Different notes are made by fingering the neck with one hand while bowing.
# 384sentences.360 Vultures are scavenging birds, feeding mostly on the carcasses of dead animals.
# 384sentences.361 Many vultures have a bald head without feathers for losing heat.
# 384sentences.362 Vultures use their large wings to soar for miles without flapping.
# 384sentences.363 Vultures seldom attack healthy animals, but may kill the wounded or sick.
# 384sentences.364 A wall is a solid structure that defines and sometimes protects an area.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.365 Walls delineate a building, support the roof, and divide the space into rooms.
# 384sentences.366 Walls are usually made of stone, brick, or cement, as well as drywall.
# 384sentences.367 Retaining walls provide a barrier to movement of earth, stone or water.
# 384sentences.368 Water is the most common liquid on Earth, covering 70% of its area.
# 384sentences.369 Plants, animals and people must drink water in order to live.
# 384sentences.370 Water freezes at a low temperature and becomes solid ice.
# 384sentences.371 Rain is water that falls from clouds in the sky, which are condensed vapor.
# 384sentences.372 A whale is a very large mammal that lives in the ocean.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.373 Whales breathe through blowholes on their heads when surfacing.
# 384sentences.374 The blubber in a whale serves as an energy reservoir and as insulation.
# 384sentences.375 Whales have been hunted for meat, whale oil and ambergris.
# 384sentences.376 A window is a transparent opening in a wall to let light through.
# 384sentences.377 A typical window is made of sheets of glass held in place by frames.
# 384sentences.378 When open, a window will also let air and sound through.
# 384sentences.379 Some windows have multiple panes to increase insulation inside.
# 384sentences.380 A woman is a female human adult.
#
# For each sentence, generate 3 paraphrases. Index each sentence with 384sentences.{number}.{1,2,3}.
#
# 384sentences.381 A woman is stereotypically seen as a caregiver.
# 384sentences.382 A woman can become pregnant and bear children.
# 384sentences.383 A woman has different reproductive organs than a man.

# %%
for i, item in enumerate(stimuli_df_copy.sentence_stripped.values):
    print(i + 'item)
    if i % 6 == 5:
        print(f'\nChunk {i} \n ')
# Out:
# beekeeping encourages the conservation of local habitats.
# it is in every beekeeper's interest to conserve local plants that produce pollen.
# as a passive form of agriculture it does not require that native vegetation be cleared to make way for crops.
# beekeepers also discourage the use of pesticides on crops because they could kill the honeybees.
# artisanal beekeepers go to extremes for their craft but their product is worth the effort.
# artisanal honey-making emphasizes quality and character over quantity and consistency.
#
# Chunk 5
#
# to produce the finest honey beekeepers become micromanagers of their honeybees.
# they scout the fields know when nectar flows and select the best ways to extract honey.
# as the beekeeper opens the hive the deep hum of 40000 bees fills the air.
# the beekeeper checks honey stores pollen supplies and the bee nursery.
# bees crawl across his bare arms and hands but they don't sting because they're gentle.
# i have a recurring dream about exams even though i'm no longer in college.
#
# Chunk 11
#
# in my dream it's the day of my final exam and i suddenly realize i've never gone to class.
# i've never even done any of the reading assignments.
# i know many other people who have the same nightmare.
# each morning participants in the study had to write down their dream experience from the previous night.
# they recorded if they recalled any dreams and described each dream and its emotional intensity.
# participants then assigned each dream to a category such as a flying dream a bad dream or a nightmare.
#
# Chunk 17
#
# every night while we sleep our minds are as active as when we are awake.
# we dream throughout the night in cycles of about ninety minutes each.
# images feelings stories and strange combinations of characters and places can fill our dreams.
# when i decided to start playing cards things went from bad to worse.
# gambling was something i had to do and i had already spent close to $10000 doing it.
# my friends were sick of watching me gamble my savings away.
#
# Chunk 23
#
# the hardest part was the horror of leaving a casino after losing money i did not have.
# good data on the social and economic effects of legalized gambling are hard to come by.
# some studies indicate that having a casino nearby makes gambling problems more likely.
# gambling may also be associated with personal bankruptcies and marriage problems.
# over the past generation there has been a dramatic expansion of legalized gambling.
# most states have instituted lotteries and many have casinos as well.
#
# Chunk 29
#
# gambling has become very big but controversial business.
# the wind from the hurricane shook the house shattering a window in the kitchen.
# we ran in grabbed some food slammed the door and surrendered the kitchen to the hurricane.
# i was afraid our house would be ripped from its foundation.
# later that night with the wind shaking the house we fell asleep huddled on the sofa.
# hurricanes can tear limbs off of trees and suck houses off their foundations.
#
# Chunk 35
#
# they dump heavy rains that can trigger floods and mudslides.
# hurricanes can also bring a storm surge a wall of ocean water that lurches onto land.
# scientists use several methods to look for evidence of ancient hurricanes.
# the strongest storms deposited layers of windblown beach sand at the bottoms of coastal lakes.
# trees drenched by passing hurricanes preserve a record of each storm in their growth rings.
# american ice cream is exported around the world but different countries have different preferences.
#
# Chunk 41
#
# many people enjoy their ice cream flavored with local delicacies.
# in some tropical places vanilla ice cream is topped with bananas and fresh mangos.
# i remember making ice cream at home as a child.
# we poured the cream mixture into a frozen tub then start turning the crank to expose it to the cold.
# eventually it froze enough that i couldn't turn the hand crank any more.
# then i put the container of half-frozen ice cream into the freezer to harden.
#
# Chunk 47
#
# ice cream is a mixture of milk or cream sugar flavorings and up to half whipped-in air.
# the butterfat in milk and cream is what makes it smooth and silky.
# high-priced premium ice cream is loaded with butterfat and natural flavorings.
# when i use the riding lawn mower the uncomfortable chair makes my back hurt.
# i use the two levers in front of me to control the machine.
# the sharp blades underneath the lawn mower precisely sever each blade of grass.
#
# Chunk 53
#
# mowing the lawn is a long task and it has taught me patience.
# a lawn mower is a machine with revolving blades that cut grass to an even height.
# the blades may be powered by muscle or the machine may have a motor.
# the most common power source for lawn mowers is a small gas engine.
# electric lawnmowers are better for the environment because they do not create emissions.
# they also need less maintenance and are less expensive to run.
#
# Chunk 59
#
# electric lawn mowers use as much electricity as an ordinary toaster.
# astronauts train a long time for their spacewalks.
# much of their training is conducted underwater.
# they may spend 8 to 10 hours in the pool for every hour they will spend floating in space.
# astronauts practice to be able to perform construction and repair work on the outside of the space station.
# the commanders of shuttle flights are always pilots and many have backgrounds as military test pilots.
#
# Chunk 65
#
# other astronauts are trained as doctors engineers and scientists who can run experiments in space.
# early crews were all young men but astronauts now are much more diverse.
# the team of astronauts floated out together to the exterior of the space shuttle.
# they carried tools needed to repair the broken part on the huge telescope.
# one astronaut loosened the bolts on the pipe while the other fitted the replacement part into place.
# computers have been used in art for a long time by experimental artists.
#
# Chunk 71
#
# now that computers are more affordable and widespread computer graphics have entered the mainstream art world.
# some computer science conferences have art exhibitions that showcase the latest graphics technology.
# brand new conferences have sprung up that are devoted to bridging the two cultures.
# the computer graphics specialist works with doctors to visualize medical conditions and surgical procedures.
# she uses digital animation to help doctors understand structures within a patient's body.
# seeing the internal structures in an animation on a screen is much clearer than squinting at x-rays.
#
# Chunk 77
#
# modern digital animation is a powerful tool for education.
# as the field of computer graphics broadens we must ask if graphics actually help students.
# research does suggest that vivid and engaging digital imagery can be effective in the classroom.
# the reason he came to law school in the first place was cliche.
# he wanted to change things for the better.
# he recalled one evening at law school when he and the program director had pulled an all-nighter.
#
# Chunk 83
#
# they finally finished drafting a petition for several evicted families at sunrise.
# over the past four decades the cost of legal education has gone up relentlessly.
# private law school tuition increased by a factor of four since the 1970s.
# the market for admission to law school and for new lawyers could eventually crash.
# law school faculty often have minimal experience in actually practicing law.
# professors focus on writing law review articles for prestigious journals.
#
# Chunk 89
#
# law schools often emphasize the theoretical with classes on topics like property law in feudal england.
# pharmacists are increasingly involved in preventive care.
# they are becoming front-line health advisers because people go to pharmacies often.
# pharmacists are often a good source of information about public health.
# doctors consult with pharmacists because they know a lot about drug interactions and side effects.
# pharmacists dispense prescription drugs to patients and offer advice about the safe use of medications.
#
# Chunk 95
#
# they also conduct health and wellness screenings and provide vaccines.
# pharmacists must have professional degrees and pass two exams in order to be licensed.
# i think the pharmacy profession chose me as much as i chose to be a pharmacist.
# i was fascinated by the neatly arranged bottles in pharmacies as a child.
# i know it's cliche but i love the impact that i have on lives of my patients.
# each person has his or her own response to potentially stressful situations.
#
# Chunk 101
#
# one person may be devastated by unemployment while another may find working fulltime stressful.
# there are everyday stresses like being stuck in traffic.
# there are also traumatic stresses such as divorce or loss of a child.
# some people can adapt to different levels of stress.
# if not dealt with effectively though stress can take a real toll on health.
# remember that it's your reaction to stress that determines if it will be harmful or beneficial.
#
# Chunk 107
#
# when my company was downsizing i felt incredibly stressed and worried.
# my heart would race for no reason and i even felt dizzy at times.
# then i started taking yoga to try to manage my stress level.
# the man wore a jet black tuxedo with satin stripes.
# it was made with rich fabric cut in the latest style.
# clearly he had it tailored as it fit the man perfectly.
#
# Chunk 113
#
# it looked like something a professional stylist would have picked out for a formal event.
# while the tuxedo is still preferred today's grooms are making personal statements in wedding attire.
# shorter jackets are on the cutting edge of wedding fashion for men.
# grooms are also jazzing up their tuxedos with colorful shirts and satin ties.
# a tuxedo jacket is a tailless dinner jacket with black silk lapels.
# black tie trousers should be a perfect match to the tuxedo jacket.
#
# Chunk 119
#
# the shirt should always be plain white and the tie should be black and match the jacket lapels.
# the concert pianist went blind in adulthood.
# her blindness was caused by a genetic condition that slowly damaged the eyes.
# she told interviewers that being blind was an advantage to a pianist.
# she had no visual distractions so she could concentrate more fully on her music.
# the government defines blindness as vision insufficient for the ordinary activities of life.
#
# Chunk 125
#
# by establishing the parameters of legal blindness resources can be focused on the legally blind.
# this may overlook those who have vision problems but who do not meet the standard.
# in developing countries blindness in children is usually caused by infectious disease and nutritional deficiencies.
# these causes can often be prevented by medicine and vitamin supplements.
# in developed countries blindness is more likely to be caused by genetic problems.
# no one really knows exactly how a taste gets from your mouth to your brain.
#
# Chunk 131
#
# scientists think the process begins when a molecule of food touches a taste bud cell.
# the cell carries a taste message to taste nerves beneath the cell.
# it was once believed that each taste bud responded to one of the four basic tastes.
# that is a taste bud on the tip of the tongue would respond only if you were eating something sweet.
# scientists now think that a single taste bud can be sensitive to all of the basic tastes.
# my sense of taste isn't very good so i tend to eat foods with very strong flavors.
#
# Chunk 137
#
# i like lots of hot sauce and i drink my coffee with no cream so it's very bitter.
# i can't even taste sweetness well so when i make cookies i add extra sugar.
# hip fractures are a real problem for aging individuals.
# patients are faced with the pain of the break and the difficult process of healing.
# families have to adjust to the patient's loss of independence.
# and for society hip fractures involve substantial expense and time in the hospital.
#
# Chunk 143
#
# halfway through the race i heard a sound like someone snapping their fingers.
# i felt a crunch and i knew instantly that my foot was broken.
# every step felt like running on spikes.
# at the doctor's office afterward the x-ray clearly showed the fracture.
# there are a few different types of bone fracture.
# in closed or simple fractures the bone is broken but the skin is intact.
#
# Chunk 149
#
# in open or compound fractures the broken bone has punctured the skin and produced an open wound.
# new ear piercings can become infected if they're not carefully cleaned.
# signs of infection include tenderness swelling or redness around the earlobe.
# if you see these symptoms clean the area and apply some ointment.
# if the redness and swelling don't go away contact your health care provider.
# a local hospital has initiated new measures to reduce infections.
#
# Chunk 155
#
# they have improved hand washing habits and ensured that infected patients are isolated from other patients.
# the hospital has seen infection rates drop since the new measures began.
# scrubbing a wound with soap or alcohol delays healing which increases the risk of infection.
# band-aids can increase the risk of infection by holding in heat and moisture.
# fortunately most skin infections can easily be treated once they are diagnosed.
# modern opera started at the end of the sixteenth century.
#
# Chunk 161
#
# it began as an effort to rediscover and imitate greek tragic performance.
# early founders of opera chose tales from antiquity for their subject matter.
# later operas branched out into different sources of stories and musical traditions.
# opera is an art form in which singers and musicians perform a play that combines words and music.
# it incorporates many of the elements of spoken theatre such as acting scenery and costumes.
# performances are typically given in an opera house and accompanied by an orchestra.
#
# Chunk 167
#
# the opera singer has worked hard to win the role in the new production.
# her job is not just about singing.
# acting stage presence and musical interpretation are all critical.
# but her pure strong voice is certainly the star of the show.
# a painter must keep many elements in mind while completing a painting.
# she has to use solid elements of design like strong composition and lighting.
#
# Chunk 173
#
# she has to execute the brush strokes with skill.
# most importantly the content of the painting should reveal a glimpse of the painter's soul.
# long ago painters were employed more as skilled artisans than as creative artists.
# however prominent painters had the social status of scholars and members of the royal court.
# they signed their work decided on its subject and imagery and established a personal relationship with their patrons.
# as a painter i learned to focus less on the actual scene and more on the painting itself.
#
# Chunk 179
#
# an artist's eye is not a camera lens that has to record everything within its field of vision.
# i found nature provides useful information but more than is needed for a good painting.
# the eagle owl is an impressive bird.
# it has ear tufts that stick up like horns.
# its large orange eyes are downright creepy and look like they could pierce right through you.
# this owl hunts at night flying swiftly and silently through the darkness.
#
# Chunk 185
#
# while some owl species have become endangered others are thriving.
# the barred owl has spread well beyond its previous habitat.
# early findings suggest that logging may have facilitated the barred owl's invasion.
# the owl landed on a thick branch and gripped it with her talons.
# she pressed her wings to her sides and settled down half-closing an eye.
# she might have been a statue but for the glow of her eyes.
#
# Chunk 191
#
# it's unnerving to watch a polar bear stalk across floating sea ice.
# it's even worse when you are submerged in the frigid waters directly beneath the huge animal.
# overhead giant paws set down on the ice as the polar bear pursued its prey.
# as part of the film crew for a polar bear documentary i spent months capturing these shots.
# polar bears are one of the few animals that will attack people for reasons other than fear or confusion.
# they may attack out of hunger because they live in a food-scarce environment.
#
# Chunk 197
#
# they will sneak up on people slowly careful to conserve their energy.
# the seal is an important part of the polar bear's diet.
# when hunting they will wait by a seal's breathing hole or stalk seals that are basking on the ice.
# the polar bear will crawl quietly forward and freeze in place when the seal looks around.
# the medieval castle was not a structure built primarily for defense.
# its purpose was to dominate its surroundings.
#
# Chunk 203
#
# a castle could easily control lands within a day's walk.
# during times of attack peasants livestock and property could be brought inside the castle's walls for protection.
# spectacular castles in dramatic locations provide a record of the stormy history of many regions.
# today they stand atop rocky cliffs overlooking beautiful landscapes and quaint villages.
# in the past they were home to battles plots and intrigue.
# upon leaving the train station we saw our hotel looming above  a magnificent castle built on a cliff.
#
# Chunk 209
#
# the thick outside walls sheltered an inner courtyard hundreds of feet above the river.
# our tower rooms had an incredible but slightly scary view.
# after climbing fifty feet up the side of the pyramid the man gestured me into a small black entranceway.
# this led into the chamber at the pyramid's center.
# i followed him down the steep dark narrow passage.
# the smell inside the pyramid was chalky and the air was thick.
#
# Chunk 215
#
# more than just the tomb of the king pyramids represented the pride of the nation.
# the care that the pyramid builders took in their craft is evident.
# the stones covering the pyramid were precisely fitted together and polished until the structure gleamed.
# architects are still working to solve the mysteries of how pyramids were constructed.
# some think ramps were built inside the pyramid's walls to raise stone blocks.
# others speculate that ramps zigzagged up the exterior walls of the pyramid.
#
# Chunk 221
#
# even beginner rock climbing takes courage and strength.
# climbers who are learning the sport can try scrambling on large boulders.
# once they're comfortable with that they can begin using ropes to safely climb vertical rock faces.
# all of the boys on the trip were new to rock climbing.
# many were afraid of heights.
# having someone else check their knots and harnesses helped them calm down.
#
# Chunk 227
#
# the adults set up climbing routes appropriate for beginners.
# free-climbing is one particular style of rock climbing.
# the climber relies solely on her skill and physical strength to ascend a rock face.
# rope and bolts are the only equipment used.
# they are meant only to stop the climber if she falls.
# i hesitantly skied down the steep trail that my buddies convinced me to try.
#
# Chunk 233
#
# i made a bad turn and i found myself tumbling down.
# i finally came to a stop at a flat part of the slope.
# my skis were nowhere to be found and my poles were lodged in a snow drift up the hill.
# a major strength of professional skiers is how they use ski poles.
# proper use of ski poles improves their balance and adds flair to their skiing.
# it minimizes the need for upper body movements to regain lost balance while skiing.
#
# Chunk 239
#
# new ski designs and stiffer boots let skiers turn more quickly.
# but faster and tighter turns increase the twisting force on the legs.
# this has led to more injuries particularly to ligaments in the skier's knee.
# an accordion is a portable musical instrument with two keyboards.
# one keyboard is used for individual notes the other for chords.
# accordions produce sound with bellows that blow air through reeds.
#
# Chunk 245
#
# an accordionist plays both keyboards while opening and closing the bellows.
# an apartment is a self-contained home that is part of a building.
# an apartment may have one or more rooms as well as a kitchen and a bathroom.
# some apartments are for single people others for families.
# the building can have a garage a laundry facility or extra storage space.
# an apple is a fruit that can be green red or yellow.
#
# Chunk 251
#
# apples have thin skin a crisp sweet pulp and seeds inside.
# some very tart apples are used to make cider.
# apples can be eaten raw roasted or baked in pies.
# arson is the criminal act of burning a building or wildland.
# a fire investigation determines if a fire was caused by accident or arson.
# arson can be done to cause damage to others or collect insurance.
#
# Chunk 257
#
# the severity of the crime depends on whether people were harmed.
# an automobile or car is a wheeled vehicle for transporting passengers.
# a car can be powered by a gasoline or electric engine.
# the driver steers the car on roads other passengers just sit.
# automobiles vary in size number of doors and the type of trunk.
# the axe is a tool used to split and cut wood.
#
# Chunk 263
#
# the axe usually consists of a head attached to a handle.
# historically axe heads were made of stone and then metal.
# axes are used by woodcutters and firemen entering buildings.
# a banana is a long fruit that grows in bunchs with a soft edible inside.
# a banana when ripe can be yellow purple or red and have small brown spots.
# the greatest producers are tropical countries such as india or ecuador.
#
# Chunk 269
#
# unripe bananas and plantains are staple foods and often cooked like potatoes.
# a bed is a piece of furniture used as a place to sleep or have sex in.
# a bed is made of a mattress and a box spring plus sheets pillows and covers.
# in waterbeds the mattress is filled with water and in airbeds it is filled with air.
# another type of bed is the hammock a fabric sling suspended above the ground.
# a bee is a flying insect with a black and yellow body and six legs.
#
# Chunk 275
#
# bees spread pollen between flowers as they collect nectar to make honey.
# bees are social insects and live together in a colony located in a hive.
# many bees have stingers and can attack if they feel threatened.
# a bicycle is a vehicle with two wheels and pedals on a frame.
# a bicycle is propelled by the pedalling of a cyclist on the saddle.
# the wheels have rubber tires with an inner tube full of air.
#
# Chunk 281
#
# people use bicycles for transportation recreation and racing.
# a blacksmith creates objects by forging iron or steel.
# a blacksmith hammers and bends hot iron on an anvil to change its shape.
# blacksmiths wears a thick apron and handle the metal with tongs.
# blacksmiths make objects like weapons horse shoes or iron furniture.
# a blender is a kitchen appliance used to mix ingredients or puree food.
#
# Chunk 287
#
# blenders have a glass or plastic container with a rotating blade in the bottom.
# blenders are used to make milk shakes and fruit smoothies.
# blenders are also used to make cold alcoholic drinks with crushed ice.
# a boy is a young male child who has not undergone puberty.
# the term is used to indicate sex distinctions relative to girls.
# traditionally boys like to play rough games and fight with each other.
#
# Chunk 293
#
# an adult male behaving immaturely is often referred to as a boy.
# broccoli is a plant in the cabbage family.
# broccoli has a green flower head and a thick tough stalk.
# broccoli is high in vitamins fiber and other nutrients.
# broccoli can be boiled stir-fried or eaten raw.
# a butterfly is a flying insect with four large wings.
#
# Chunk 299
#
# the wings of butterflies can be very colorful and patterned.
# metamorphosis is the transformation of a caterpillar into a butterfly.
# some people collect butterflies because of their colorful wings.
# a carpenter is an artist or manual laborer who works with wood.
# carpenters build and repair houses furniture boats and other objects.
# carpenters use tools such as hammers saws pliers and planes.
#
# Chunk 305
#
# a luthier is a carpenter that makes and repairs musical instruments.
# cats are small furry animals with four legs and a tail.
# cats like to groom themselves by licking their fur.
# cats can hunt mice or birds but are often fed by their owners.
# the claws of cats are retractable so that they keep sharp.
# a chair is a piece of furniture designed for people to sit on.
#
# Chunk 311
#
# chairs consist of a seat raised above floor level supported by legs.
# chairs can also have back and arm rests as well as a cushion.
# seats are fixed chairs located in vehicles or in places like cinemas.
# a clarinet is a woodwind musical instrument.
# a clarinet is a long black tube with a flare at the bottom.
# the player chooses notes by pressing keys and holes.
#
# Chunk 317
#
# the clarinet is used both in jazz and classical music.
# a cod is a fish that lives in the colder areas of the atlantic.
# cod flesh is white and mild-tasting and flakes easily when cooked.
# fresh cod is used for fish and chips salted cod for elaborate dishes.
# cod has been caught salted and traded since the time of the vikings.
# coffee is made from coffee beans the seeds of the coffee plant.
#
# Chunk 323
#
# coffee is a popular drink in many countries and usually served hot.
# coffee contains a mild drug called caffeine that keeps people awake.
# coffee is the world's seventh-largest legal agricultural export.
# a desert is a natural environment where almost no rain falls.
# hot deserts are usually filled with sand dunes or rocks.
# some animals and plants have adapted to live in deserts.
#
# Chunk 329
#
# the biggest hot desert is the sahara in northern africa.
# a desk is a piece of furniture used for working at sometimes with a computer.
# a desk has a flat surface and can be made of wood plastic or metal.
# a desk may have drawers to store supplies and papers.
# a cubicle consists of a desk surrounded by partitions on three sides.
# a door is a movable barrier to entrance or exit from an enclosed area.
#
# Chunk 335
#
# most doors have locks to control who gets to pass through them.
# most doors are opened by pushing or pulling a handle after they are unlocked.
# other types of doors can slide or consist of a revolving chamber.
# a dress is a piece of clothing that women sometimes wear.
# a dress is like a shirt attached to a long matching skirt.
# a dress is usually worn at formal occasions such as a wedding or a dance.
#
# Chunk 341
#
# it can be hard to climb stairs or ride a bike in a dress.
# drunk driving is the act of driving under the effects of alcohol.
# drunk driving of any vehicle is a crime in most of the world.
# it plays a role in almost half of all vehicle-related deaths.
# drunk drivers are caught by field sobriety and breathing tests.
# a drought is a persistent shortage of the water supply caused by lack of rain.
#
# Chunk 347
#
# drought will cause crops and plants to stop growing and die.
# extreme drought will eventually turn areas into desert and cause famine.
# large numbers of people have to migrate away from dust bowls.
# eagles are large birds of prey that hunt during the day and have very good eyesight.
# eagles have hooked beaks for tearing flesh strong legs and sharp talons.
# eagles live in eyries and some species eat fish and others small mammals.
#
# Chunk 353
#
# the bald eagle has a bright white head and is the national bird of the united states.
# earthquakes shake the ground and can knock down buildings and other structures.
# the shaking can also trigger landslides and volcanic activity.
# most earthquakes are caused by the release of energy in the earth's crust.
# an earthquake at sea can displace the seabed and cause a tsunami.
# elephants are the largest kind of land mammal weighing several tons.
#
# Chunk 359
#
# an elephant has a long nose called a trunk which can grab things or food.
# the elephant has a pair of ivory tusks for moving objects or digging into trees.
# the elephant flaps its large ears to cool the blood in them and its body.
# the eye is an organ for sensing light and coding it for the visual cortex.
# most animals have complex eyes which can detect color motion and texture.
# the fovea is the center of the human eye and the most sensitive part of it.
#
# Chunk 365
#
# insects have compound eyes made up of eye units facing in many directions.
# a farm is land used to grow plants or raise animals for food.
# farmers are the people who run the farm and decide what to produce.
# farms usually have a house for farmers a silo and a barn.
# a cooperative is a farm where many farmers share the land and equipment.
# primates usually have four fingers and a thumb on each hand.
#
# Chunk 371
#
# fingers are used for grasping writing grooming and other activities.
# the fingertips are sensitive to temperature pressure and vibration.
# the nail protects the tip of the finger and can be grown or decorated.
# a flood is an overflow of an expanse of water that submerges inhabited land.
# flood can be caused by heavy rain or rapid snow melt as well as earthquakes at sea.
# in a flood a river will flow out of its channel or break dams and levees.
#
# Chunk 377
#
# during a flood people evacuate and the contaminated water causes diseases.
# a floor is a horizontal surface inside a building used for walking on.
# floors may be made of bare concrete tile linoleum or wooden floorboards.
# people often put carpets on a floor for comfort and to dampen noise.
# in buildings the floor often has pipes and electrical wiring under it.
# a foot is a body part on the end of a leg .
#
# Chunk 383
#
# people use their feet when walking running or standing straight.
# people also use their feet to kick in both fighting and sports.
# many cultures have rules for behavior related to feet.
# a forest is an area with a high density of trees and canopy cover.
# the type of forest depends on temperature and rainfall in its location.
# a forest ecosystem has various types of trees and animals as well as ground plants.
#
# Chunk 389
#
# deforestation is the cutting down of forests disregarding regeneration.
# a fork is a tool for eating solid foods with a handle and several tines.
# forks are usually  made of metal or plastic if disposable.
# forks are used to lift food to the mouth or to hold food in place while cutting.
# forks are used in western cultures and there are special kinds for various foods.
# a frying pan is a small pan with sloping sides and a handle.
#
# Chunk 395
#
# a frying pan is used to fry sear and brown food.
# the food is cooked on oil covering the bottom of the pan.
# frying pans are made of iron or teflon-clad steel.
# a girl is a female human who has not yet reached maturity.
# at puberty the body of a girl develops into that of a woman.
# girls often like playing with dolls and social games.
#
# Chunk 401
#
# girls sometimes grow long hair and wear dresses and skirts.
# a glove is a piece of clothing that covers the hand and fingers.
# gloves to protect against cold are made of wool or lined waterproof material.
# disposable rubber or latex gloves are used to shield hands from germs or chemicals.
# a mitten is a kind of glove where the four fingers are covered together.
# a hammer is a tool used to deliver an impact to an object.
#
# Chunk 407
#
# a hammer is most often used to drive nails into wood.
# the claw on the head can be used to remove nails.
# hammers vary in the shape of the head and handle length.
# a hand grenade is an explosive used as a weapon against people.
# hand grenades are thrown and timed to explode a bit after that.
# grenades can also be fired from rifles or shoulder launchers.
#
# Chunk 413
#
# tear gas grenades are thrown into the middle of a mob to disperse it.
# a horse is a large hoofed mammal with four long muscular legs.
# a horse has a tail and a mane on its neck and is usually gray or brown.
# horses have been used for draft work travel and entertainment.
# a human can ride a horse while it walks trots or gallops.
# people go to hospitals to be healed when they are sick or injured.
#
# Chunk 419
#
# hospitals are staffed by professional physicians surgeons and nurses.
# some patients go there for specialist diagnosis or therapy leaving the same day.
# for some operations or treatments patients have to stay for several weeks.
# a house is a permanent building or structure for people or families to live in.
# a house has a roof and walls to keep out cold and rain and windows to let light in.
# a house can have rooms for purposes like sleeping cooking or washing.
#
# Chunk 425
#
# most people leave the house to work and come back at night to eat and sleep.
# an igloo is a type of shelter made from blocks of snow by inuit.
# igloos are built in places where snow covers the land most of the time.
# igloos are often built in the shape of a dome with an entrance tunnel.
# air pockets in snow insulate the space and body heat warms igloos.
# a knife is a tool with a sharp edge that is used to cut things.
#
# Chunk 431
#
# modern knives consist of a handle and a blade usually made of metal.
# knives have also been used as weapons and instruments in rituals.
# a knife can be used to attack by slashing stabbing or throwing .
# lentils are the seeds of a plant of the legume family.
# lentils can be red green brown black or yellow.
# lentils are commonly used in indian and mediterranean cuisines.
#
# Chunk 437
#
# lentils are cooked by boiling and are a great source of protein.
# lettuce is a biennial plant often grown in temperate climates as a leaf vegetable.
# lettuce can be eaten cold and raw in salads and other dishes or cooked.
# lettuce is considered fairly easy to grow and a suitable crop for beginners.
# most lettuce leaves taste bitter but some are bred to remove the bitterness.
# a library is a place where a collection of books documents and media is kept.
#
# Chunk 443
#
# librarians work at libraries and are experts at finding and organizing information.
# people can go to public libraries and borrow books to take home for several weeks.
# academic libraries support scholarly research and have specialized books.
# a log cabin is a small house built from round logs.
# log cabin is a symbol of american frontier life and humble origins.
# log cabins were used as first shelters by european settlers.
#
# Chunk 449
#
# log cabins were built using logs with notch joints at the ends.
# a man is a male human adult.
# a boy becomes a man after passing through puberty.
# manhood is associated with masculinity and virility.
# men differ from women in height weight and body structure.
# milk is a white liquid produced by female mammals to feed their young.
#
# Chunk 455
#
# newborn animals must be fed milk before they can eat solid food.
# dairy products such as cheese and butter are made from milk.
# liquid produced from soybeans and coconuts is sometimes called milk.
# mosquitos are thin small flying insects that emit a high-pitched sound.
# mosquitoes have mouthparts for piercing the skin of plants and animals.
# female mosquitoes bite people and animals and suck their blood for protein.
#
# Chunk 461
#
# mosquito bites can spread yellow fever malaria and other parasite diseases.
# a mountain is a landform that rises steeply above surrounding land.
# mountains rise higher than hills and sometimes have snow at the top.
# a range of mountains forms due to tectonic plate collision.
# mountaineers are people who climb or hike up mountains.
# the mouth is the face cavity we put food in when we eat.
#
# Chunk 467
#
# the mouth has teeth to chew food and mix it with saliva.
# the mouth is also used for kissing and talking.
# speech sounds are controlled by tongue placement in the mouth.
# a mug is a sturdy cup with a handle for drinking hot liquids.
# a mug is normally ceramic but can also be made of metal or glass.
# a mug is thick and has a ring base for thermal insulation.
#
# Chunk 473
#
# mugs can be plain or have drawings imprinted or carved on them.
# murder is the unlawful killing of another human being with intent.
# murder a serious crime because it deprives the victim of their existence.
# killing in self-defense accidentally or in war is not considered murder.
# a convicted murderer is often given a life sentence or the death penalty.
# orange juice is a drink made from the liquid in orange pulp.
#
# Chunk 479
#
# orange juice has a sweet acid taste and contains a lot of vitamin c.
# freshly squeezed orange juice often contains pulp as well.
# orange juice is often drunk at breakfast from a glass.
# a parrot is a bird that lives in warm and tropical regions.
# parrots have brightly-colored feathers and a sharp curved beak.
# parrots can imitate the human voice if they hear it repeatedly.
#
# Chunk 485
#
# their appearance and abilities makes them popular pets.
# a peach is an orange-yellow fruit with a characteristic smell.
# the skin of a peach is thin and covered in small fine hairs.
# peaches have a large red-brown stone inside which contains the seed.
# peaches are sweet and delicate and must be harvested after ripening.
# the piano is a popular musical instrument played by means of a keyboard.
#
# Chunk 491
#
# pressing a piano key causes a felt-tipped hammer to hit a vibrating steel string.
# the piano has an enormous note range and pedals to change the sound quality.
# the piano repertoire is large and famous pianists can give solo concerts.
# piranhas are small ferocious fish that live in south american rivers.
# piranhas live and attack in schools and are most active during the day.
# piranhas have very sharp teeth and are opportunistic carnivores.
#
# Chunk 497
#
# piranhas eat fish insects lizards mammals and carrion.
# the raspberry is a fruit that grows in forest clearings or fields.
# a single raspberry consists of many small fruits joined together.
# raspberries are eaten by themselves or cooked with sugar into jam.
# leaves of the raspberry are used fresh or dried in herbal teas.
# a raven is a large black bird that thrives in many climates.
#
# Chunk 503
#
# ravens feed on carrion insects berries or small animals .
# ravens have large brains and are capable of problem solving.
# in folklore ravens are birds of ill-omen and also tricksters .
# a refrigerator is a cooling device used to contain and preserve food.
# some refrigerators can have a small compartment at freezing temperature.
# a refrigerator can have shelves and small compartments for different types of food.
#
# Chunk 509
#
# a refrigerator is generally white and people often put magnets on its surface.
# a rifle is a firearm that rests on the shoulder and has a barrel with twisting grooves.
# the grooves make the bullets spin around the rifle axis as they fly through the air.
# rifles are used in hunting and shooting sports sometimes with scopes.
# assault rifles can fire in bursts and are the standard infantry weapon.
# salmon is a fish that migrates from fresh water to the ocean and back to spawn.
#
# Chunk 515
#
# salmon flesh is orange or red and has high protein content and a nice taste.
# salmon can be eaten raw in sushi or cooked by grilling poaching or in other ways.
# salmon is the most common farmed fish though it can also be caught in the wild.
# a saw is a tool that uses a hard blade or abrasive wire to cut hard materials.
# the small sharp points along the cutting side of the saw are called the teeth.
# saws can be worked by hand or powered by an electric motor or gas engine.
#
# Chunk 521
#
# saws are used extensively in forestry construction carpentry and medicine.
# a scientist studies and produces new knowledge about the physical world.
# a scientist creates hypotheses and does experiments to test them.
# physics chemistry and biology are classic examples of sciences.
# scientists publish their research in journals and conferences.
# scissors are a two-bladed instrument used for cutting.
#
# Chunk 527
#
# the blades are usually metallic with plastic or metal handles.
# depending on the size and format scissors can cut paper hair or fabric.
# shears are large scissors used for cutting shrubs or pieces of metal.
# a screwdriver is a tool for inserting and tightening screws into something.
# screwdrivers can also be used to remove screws after they are inserted.
# the screwdriver tip applies the torque from rotating the handle.
#
# Chunk 533
#
# the two major types of screwdrivers are phillips and flathead.
# a shark is a large fish with a cartilage skeleton.
# sharks have streamlined bodies with a large dorsal fin.
# most sharks predate on fish and mammals with powerful jaws.
# sharks have very keen senses and can detect electrical fields.
# a ship is a large vehicle that floats and travels on water.
#
# Chunk 539
#
# a ship can be powered in the ocean by sails steam or diesel engines.
# ships are used to fish in the ocean and to transport cargo containers.
# cruise ships are floating hotels that take people between cities.
# a shoe is clothing for the foot with a sole an outsole and a heel.
# shoes are usually made of leather canvas rubber or plastic.
# women's shoes often have high heels and come in many styles and colors.
#
# Chunk 545
#
# a sneaker is a shoe for sports and athletic activity.
# a soldier is a member of the national armed forces who fights on land.
# a soldier in the militia must wear a uniform usually camouflage.
# in a volunteer army a soldier is paid for his or her work.
# a soldier fights using weapons such as rifles and grenades.
# spears are weapons that consist of a pole and sharpened head at one end.
#
# Chunk 551
#
# spears were the most common personal weapon before the advent of firearms.
# spears were used for stabbing or throwing when fighting in war.
# some native people still use the spear for hunting and fishing.
# spiders are insects with eight legs that make silk.
# spiders build webs with silk and use them to catch insects.
# spiders use venomous fangs to paralyse their stuck prey.
#
# Chunk 557
#
# spiders can be as small as a coin or as big as a bird.
# swamps are low spongy land subject to frequent inundation.
# a swamp is covered with shallow water mud and vegetation.
# swamps are nesting and breeding grounds for birds and reptiles.
# farmers often drain swamps to produce fertile arable land .
# a sweater is a heavy garment worn on the torso for warmth.
#
# Chunk 563
#
# sweaters are often knitted from wool but cotton is also common.
# a sweater that opens down the front is called a cardigan.
# sweaters differ in cut collar and sleeve shape as well as decoration.
# a table is a piece of furniture with a flat surface and legs.
# there are usually chairs around a table for people to sit.
# people set cutlery plates and food on a table to eat a meal together.
#
# Chunk 569
#
# tables are also used as surfaces to work or write on.
# a television is an appliance with a screen that displays moving images.
# televisions are mostly used for watching programs or films.
# they are used to play videogames when connected to a game console.
# television content can be broadcast or received via cable or internet.
# theft is the taking of person's property without their consent.
#
# Chunk 575
#
# thieves steal to own something or to sell it to receivers.
# theft is a crime and can be punishable with jail or fines.
# industrial espionage is theft of ideas and intellectual property.
# a toaster is a kitchen appliance for toasting bread using heating elements.
# pop-up toasters toast the bread placed in a slot and eject it once done.
# toaster ovens have a door on the side a tray within and temperature control.
#
# Chunk 581
#
# they allow bread to be cooked with toppings like garlic or cheese.
# the tomato is a shiny and smooth red fruit with a savory taste.
# a tomato softens and changes color from green to red as it gets more ripe.
# tomatoes can be used to make salads soup or ketchup as well as sauce.
# there are many varieties of tomato with different sizes and tastes.
# a train is a connected series of cars that moves between stations on a track.
#
# Chunk 587
#
# the train is pulled by a locomotive powered by diesel or electricity.
# a freight train transports containers of goods or fuel over long distances.
# commuter trains transport people between suburbs and stations inside a city.
# a train station is a place where passengers get on or off a train.
# train stations have counters or machines for purchasing tickets.
# there are waiting rooms and places to eat in a station.
#
# Chunk 593
#
# passengers or cargo trains enter from a platform next to the line.
# a tropical cyclone is a storm formed over warm tropical sea.
# cyclones can produce very powerful winds and torrential rain.
# tropical cyclone can also cause high waves and coastal flooding.
# a tropical cyclone can move inland and seriously damage property.
# the violin is an instrument with four strings that is played with a bow.
#
# Chunk 599
#
# violin is the smallest and highest pitched instrument in its family.
# a violinist holds the instrument between the chin and the collarbone.
# different notes are made by fingering the neck with one hand while bowing.
# vultures are scavenging birds feeding mostly on the carcasses of dead animals.
# many vultures have a bald head without feathers for losing heat.
# vultures use their large wings to soar for miles without flapping.
#
# Chunk 605
#
# vultures seldom attack healthy animals but may kill the wounded or sick.
# a wall is a solid structure that defines and sometimes protects an area.
# walls delineate a building support the roof and divide the space into rooms.
# walls are usually made of stone brick or cement as well as drywall.
# retaining walls provide a barrier to movement of earth stone or water.
# water is the most common liquid on earth covering 70% of its area.
#
# Chunk 611
#
# plants animals and people must drink water in order to live.
# water freezes at a low temperature and becomes solid ice.
# rain is water that falls from clouds in the sky which are condensed vapor.
# a whale is a very large mammal that lives in the ocean.
# whales breathe through blowholes on their heads when surfacing.
# the blubber in a whale serves as an energy reservoir and as insulation.
#
# Chunk 617
#
# whales have been hunted for meat whale oil and ambergris.
# a window is a transparent opening in a wall to let light through.
# a typical window is made of sheets of glass held in place by frames.
# when open a window will also let air and sound through.
# some windows have multiple panes to increase insulation inside.
# a woman is a female human adult.
#
# Chunk 623
#
# a woman is stereotypically seen as a caregiver.
# a woman can become pregnant and bear children.
# a woman has different reproductive organs than a man.

# %% [markdown]
# These sentences were copied into chatGPT, paraphrases were generated and pasted into the file called: chatGPT_perturbedNLP_paraphrase.xlsx
#
#
# This excel was converted into a csv and the chatGPT materials were compiled and filtered using: filter_chatGPT_materials.py
#
#
# This file stored chatGPT_perturbedNLP_paraphrase_compiled_for-manual-selection.csv
#
#
# Which underwent manual selection and editing. The merged outcome of this was: chatGPT_perturbedNLP_paraphrase_compiled_for-manual-selection_GT_CK_merge.csv
#
#
# Which was then cleaned up in compile_materials_post_man_selection.py

# %% [markdown]
# # Make chatGPT paraphrase into a neuralNLP benchmark

# %%
# We want to sub in the paraphrased sentences in col 'sentence_paraphrase_post_inspection_stripped' in the 'sentence' col in the Pereira stimset. 
stimuli_gpt = pd.read_csv(f'standalone_scripts/stimuli_creation/chatGPT_csvs/Pereira2018_stimulus_set_chatGPT.csv')

# %%
assert(stimuli_gpt.sentence_original.values == stimuli_df.sentence.values).all()
assert(stimuli_gpt.stimulus_id.values == stimuli_df.stimulus_id.values).all()
assert(len(stimuli_gpt.sentence_paraphrase_post_inspection_stripped.values) == len(stimuli_df.sentence.values))

# %%
assert(stimuli_gpt['sentence_paraphrase_post_inspection_stripped'].nunique() == len(stimuli_df))

# %%
# Assert that all is lower-case
assert(stimuli_gpt['sentence_paraphrase_post_inspection_stripped'].apply(lambda sent: sent.islower()).all())

# %%
# Sub in the paraphrased sentences into the stimuli df "sentence"

# %%
stimuli_df_copy = stimuli_df.copy(deep=True)

# %%
sentence_paraphrase = stimuli_gpt['sentence_paraphrase_post_inspection_stripped'].tolist()

# %%
sentence_paraphrase
# Out:
# ['beekeeping plays a role in conserving local ecosystems.',
#  'conserving regional vegetation that provides pollen is of the utmost importance for beekeepers.',
#  'this form of agriculture which is passive in nature does not necessitate removal of native plants for crop cultivation.',
#  'beekeepers are against the use of pesticides on crops as they could harm the honeybees.',
#  'artisanal beekeepers go to great lengths for their craft but their product is worth it.',
#  'artisanal honey-making values quality and uniqueness over quantity and uniformity.',
#  'to achieve the best quality honey beekeepers closely monitor their honeybee populations.',
#  'by exploring the lands and observing nectar patterns they are able to collect the honey effectively.',
#  'as the beekeeper begins to access the hive the drone of 40000 bees fills the air.',
#  'the beekeeper inspects the honey stores the availability of pollen and the bee nursery.',
#  "despite crawling on his unprotected arms and hands the bees don't sting because of their peaceful demeanor.",
#  'i have a persistent dream about taking exams despite no longer being in college.',
#  "my dream is about being on the day of a final exam and realizing i haven't attended any classes.",
#  'not a single reading assignment has been completed by me.',
#  'the same bad dream is experienced by numerous other individuals i know.',
#  'participants in the study documented their dream experiences from the prior night each morning.',
#  'they jotted down their memory of dreams and outlined the dream and the corresponding emotional intensity.',
#  'after that the participants categorized each dream such as a dream of flying a negative dream or a scary dream.',
#  'the mind is as busy at night while we sleep as it is during wakefulness.',
#  'throughout the night we experience dream cycles that last approximately ninety minutes each.',
#  'dreams can contain a mix of images emotions tales and bizarre combinations of characters and settings.',
#  'when i made the decision to start playing cards the situation worsened.',
#  'gambling was something i had to do and i had already spent nearly $10000 on it.',
#  'my friends were tired of seeing me squander my savings on gambling.',
#  'the worst part was the terror of leaving a casino after losing money i did not own.',
#  'it is challenging to acquire accurate data on the social and economic effects of legalized gambling.',
#  'certain studies suggest that having a casino nearby increases the likelihood of gambling problems.',
#  'personal bankruptcies and marriage problems may also be related to gambling.',
#  'over the last generation there has been a significant expansion of legalized gambling.',
#  'most states have implemented lotteries and many have established casinos as well.',
#  'gambling has become a substantial yet disputed industry.',
#  'a kitchen window was shattered by the house being shaken by the wind from the hurricane.',
#  'we quickly went in got some food closed the door and left the kitchen to the hurricane.',
#  'i was afraid that our house would be torn from its foundation.',
#  'with the house being shaken by the wind we eventually fell asleep while huddled on the couch.',
#  'hurricanes can detach tree limbs and extract houses from their foundations.',
#  'they bring heavy rains that can cause floods and mudslides.',
#  'hurricanes can produce a surge which is a wall of ocean water that moves onto land.',
#  'scientists employ multiple techniques to search for evidence of ancient hurricanes.',
#  'the most severe storms left layers of wind-blown sand from beaches at the bottom of coastal lakes.',
#  'the growth rings of trees drenched by passing hurricanes show a record of each storm.',
#  'the flavor preferences for american ice cream vary in different countries it is exported to.',
#  'many individuals appreciate ice cream flavored with local specialty ingredients.',
#  'some tropical regions enjoy vanilla ice cream topped with ripe bananas and mangos.',
#  'as a child i recall making ice cream at home.',
#  'the cream mixture was placed into a frozen container then we started turning the crank to cool it.',
#  'the hand crank could not be turned anymore once it froze enough.',
#  'to harden i put the partially frozen container of ice cream into the freezer.',
#  'the mixture that makes up ice cream is comprised of milk or cream sugar flavorings and air.',
#  'butterfat in milk and cream is responsible for giving it its velvety texture.',
#  'high-end ice cream is rich with butterfat and has natural flavorings.',
#  'the chair on the riding lawn mower makes my back ache when i use it.',
#  'i operate the machine using two levers in front of me.',
#  'the blades underneath the lawn mower cleanly sever every blade of grass.',
#  'mowing the lawn has been a long process that has taught me patience.',
#  'a lawn mower is a machine equipped with revolving blades for cutting grass to a uniform height.',
#  'the blades may either be powered by hand or by a motor.',
#  'the primary energy source utilized in lawn mowers is a compact gasoline engine.',
#  'electric lawnmowers are friendlier to the environment due to the absence of emissions.',
#  'furthermore they are cheaper to run and require less upkeep.',
#  'electric lawn mowers and ordinary toasters consume the same amount of electricity.',
#  'spacewalk training for astronauts is extensive and time-consuming.',
#  'a substantial portion of their training takes place underwater.',
#  'they may spend 8 to 10 hours in a pool for every hour they will spend in space.',
#  'to carry out repair and construction work on the outside of the space station astronauts practice.',
#  'shuttle flight commanders are always pilots and a substantial number of them have military test pilot experience.',
#  'other astronauts have training as physicians engineers and researchers and can perform experiments in space.',
#  'young men exclusively constituted the early crews while modern-day astronauts are considerably more diverse.',
#  'the team of astronauts moved together towards the exterior of the space shuttle.',
#  'they carried the necessary tools to fix the damaged part on the large telescope.',
#  'the first astronaut loosened the bolts on the pipe and the second installed the new part.',
#  'experimental artists have been using computers in art for quite a while.',
#  'with computers becoming more accessible and prevalent computer graphics have become part of the mainstream art world.',
#  'a few computer science conferences host art exhibitions showcasing the cutting-edge graphics technology.',
#  'new conferences have emerged with the specific aim of bridging the gap between the two cultures.',
#  'working alongside doctors the computer graphics specialist produces visualizations of medical conditions and surgical procedures.',
#  'she employs digital animation to clarify internal body structures for physicians.',
#  'looking at internal structures through animation on a screen is much more comprehensible than studying x-rays.',
#  'digital animation has become an influential educational tool.',
#  'as the field of computer graphics expands it is important to examine if graphics actually benefit students.',
#  'research indicates that visually appealing and engaging digital images can be productive in the classroom.',
#  'the driving force behind his enrollment in law school was a tired trope.',
#  'he sought to effect change for the better.',
#  'he remembered a time at law school when he and the program director pulled an all-nighter.',
#  'the petition for several evicted families was finally completed at dawn.',
#  'the cost of legal education has been steadily rising for the past four decades.',
#  'the cost of attending private law school has quadrupled since the 1970s.',
#  'the market for law school and new lawyers could collapse at some point.',
#  'many law school faculty members have limited experience in legal practice.',
#  'the primary focus of professors is publishing review articles in reputable law journals.',
#  'classes on theoretical topics such as property law in feudal england are frequently taught in law schools.',
#  'the role of pharmacists in preventive care is growing.',
#  "pharmacists are increasingly serving as primary healthcare advisors due to people's frequent visits to pharmacies.",
#  'pharmacists are knowledgeable about public health and can offer helpful insights.',
#  'pharmacists are frequently sought out by physicians for their knowledge of medication side effects.',
#  'dispensing of prescription drugs and advice on their safe use is a role of pharmacists.',
#  'they are also responsible for conducting health screenings and administering vaccines.',
#  'becoming a pharmacist requires obtaining a professional degree and passing two exams.',
#  'i feel like the pharmacy profession chose me as much as i chose it.',
#  'as a child i was drawn to the neatly organized bottles in pharmacies.',
#  'making a difference in the lives of my patients is what i love about my job.',
#  'individual reactions to potentially stressful situations vary per person.',
#  'unemployment may cause one person to feel upset while another may experience stress from working full-time.',
#  'there are common stressors such as getting stuck in traffic.',
#  'traumatic stressors include significant events such as divorce and loss of a child.',
#  'some individuals are capable of adapting to various stress levels.',
#  "if not managed properly stress can have negative effects on one's health.",
#  'keep in mind whether stress is harmful or beneficial depends on how you react to it.',
#  'i felt worried and stressed when my company was undergoing downsizing.',
#  'i experienced an accelerated heart rate for no reason and moments of dizziness.',
#  'to manage my stress level i started practicing yoga.',
#  'the man donned a tuxedo that was jet black and featured satin stripes.',
#  'it was fashioned with top-notch material in a contemporary style.',
#  "the tuxedo hugged the man's body as if it were tailored just for him.",
#  'it seemed like it was handpicked by a style expert for a formal occasion.',
#  'although tuxedos remain popular modern grooms are expressing their individuality through their wedding attire.',
#  'cutting-edge fashion for weddings features jackets of a shorter length for men.',
#  'colorful shirts and satin ties are being used by grooms to add flair to their tuxedos.',
#  'a tailless jacket with black silk lapels is known as a tuxedo jacket.',
#  'the trousers worn for a black tie occasion should blend seamlessly with the tuxedo jacket.',
#  'a plain white shirt must be worn and the black tie complementing the jacket lapels is necessary.',
#  'the concert pianist lost her sight as an adult.',
#  "the pianist's blindness was caused by a genetic ailment that progressively affected her eyesight.",
#  'she informed interviewers that being blind was an asset for a pianist.',
#  'she had no visual distractions allowing her to concentrate fully on her music.',
#  'the government determines blindness as vision that is insufficient for normal life activities.',
#  'the definition of legal blindness enables the focusing of resources towards those who fit the criteria.',
#  "this definition may exclude individuals who have vision problems but don't meet the legal standard.",
#  'in developing nations blindness in children is frequently caused by infectious diseases and malnutrition.',
#  'prevention of these causes is frequently possible through medication and vitamin supplements.',
#  'genetic issues are a more probable cause of blindness in developed nations.',
#  'the precise way a taste reaches from the mouth to the brain is unknown.',
#  'scientists theorize that the process starts when food molecules touch taste bud cells.',
#  'the taste bud cell conveys the taste information to the taste nerves found underneath it.',
#  'it was previously thought that each taste bud only responded to one of the four fundamental tastes.',
#  "for instance a taste bud located at the tongue's tip was believed to only respond when sweet food was eaten.",
#  'scientists now believe that a single taste bud can be responsive to all of the main tastes.',
#  'due to my poor sense of taste i tend to consume foods with very pronounced flavors.',
#  'i am a fan of hot sauce and i drink my coffee black therefore it is quite bitter.',
#  'my taste for sweetness is weak therefore i put extra sugar in my cookies.',
#  'hip fractures are a real issue for older individuals.',
#  'the patients are plagued with the ache of the break and the challenging healing process.',
#  "the patient's family must adapt to the loss of independence.",
#  'significant hospitalization time and expenses are incurred by society as a result of hip fractures.',
#  'during the race i heard a sound similar to someone snapping their fingers.',
#  'i felt a crunch and immediately recognized that i had a broken foot.',
#  'every step was like walking on spikes.',
#  "the x-ray at the doctor's office revealed the fracture clearly.",
#  'there are several different types of bone fractures.',
#  'simple fractures are when the bone is broken but the skin is not.',
#  'the skin has been punctured by the broken bone in open or compound fractures causing an open wound.',
#  'new ear piercings can become contaminated if they are not maintained properly.',
#  'tenderness swelling or redness around the earlobe are indications of infection.',
#  'clean the area and apply some ointment if the symptoms are observed.',
#  'if the redness and swelling persist seek the advice of your healthcare provider.',
#  'a local hospital has introduced new measures to decrease infections.',
#  'they have implemented better hand hygiene practices and separated those who are infected from other patients.',
#  'the new measures have led to a reduction in infection rates at the hospital.',
#  'scrubbing a wound with soap or alcohol slows down the healing process making it more vulnerable to infections.',
#  'band-aids can trap heat and moisture which can raise the risk of infection.',
#  'the good news is that skin infections are typically easy to treat once diagnosed.',
#  'modern opera originated in the late sixteenth century.',
#  'it started out as an attempt to revive and emulate greek tragic theater.',
#  'the pioneers of opera chose ancient tales as the subjects for their works.',
#  'as opera evolved it expanded into different sources of stories and musical styles.',
#  'opera is a type of art where performers including singers and musicians put on a show that blends music and words.',
#  'it incorporates many elements of spoken theater such as acting scenery and costumes.',
#  'performances are usually held in opera houses and backed by orchestras.',
#  'the opera singer has worked diligently to be cast in the upcoming performance.',
#  'her role entails more than just singing.',
#  'acting stage presence and musical interpretation are all key elements.',
#  'however her clear powerful voice is the highlight of the performance.',
#  'a painter has to consider many factors while working on a painting.',
#  'strong design elements such as composition and lighting must be included.',
#  'the painter must execute the brushwork with mastery.',
#  "most of all the painting should convey a part of the painter's soul.",
#  'in bygone days painters were viewed more as skilled artisans than imaginative artists.',
#  'yet painters of renown enjoyed the same social standing as scholars and members of the royal court.',
#  'they signed their pieces selected the themes and representations and built personal connections with those who commissioned them.',
#  'as a painter i realized the significance of focusing less on the particular scene and more on the painting itself.',
#  'the eye of an artist is not like a camera lens that must capture everything within its field of vision.',
#  'i discovered that nature provides useful information but not always necessary for a good painting.',
#  'the eagle owl is an awe-inspiring bird.',
#  'it has ear flaps that resemble horns and stand upright.',
#  'its big orange eyes are creepy and look like they could penetrate right through you.',
#  'this bird hunts at night flying quickly and quietly through the dark.',
#  'despite some owl species facing endangerment others are flourishing.',
#  'the barred owl has expanded its range beyond its original territory.',
#  "logging appears to have played a role in the barred owl's spread.",
#  'the owl perched on a sturdy branch holding on tight with its claws.',
#  'she folded her wings against her body and settled down partly closing an eye.',
#  'she appeared like a statue except for the gleam in her eyes.',
#  'the sight of a polar bear moving across ice floes is disconcerting.',
#  "it's a frightening experience to be in the cold waters directly beneath the massive animal.",
#  'giant paws descended on the ice as the polar bear hunted its quarry overhead.',
#  'as a member of the film crew for a polar bear documentary i devoted months to capturing these shots.',
#  'polar bears are one of the few exceptions where animals will attack people for reasons beyond fear or misunderstanding.',
#  'living in an environment with limited food resources they might attack due to hunger.',
#  'they will advance cautiously towards people making sure to conserve their energy.',
#  "seals are a crucial part of the polar bear's food supply.",
#  "when hunting they will either wait near a seal's breathing hole or track seals lounging on the ice.",
#  'the polar bear will creep silently forward and remain motionless when the seal surveys its surroundings.',
#  'defense was not the primary purpose for the construction of medieval castles.',
#  'its primary aim was to assert dominance over its surroundings.',
#  'a castle could easily govern territories within reach in a single day.',
#  "during an invasion everything from the peasants to the livestock and properties could be secured inside the castle's fortifications.",
#  'dramatic castles in awe-inspiring locations are a reminder of the stormy history of many areas.',
#  'presently they perch on rocky cliffs that overlook charming villages and picturesque landscapes.',
#  'historically they have been the site of battles schemes and conspiracies.',
#  'upon leaving the railway station we spotted our hotel towering above us a stunning castle built on a cliff.',
#  'the outer walls shielded an inner courtyard located hundreds of feet above the river.',
#  'our tower rooms had a breathtaking but somewhat frightening view.',
#  "after climbing up the pyramid's side for fifty feet the man gestured for me to enter a small black opening.",
#  'this took me to the heart of the pyramid.',
#  'i trailed him through the steep dark and tight passage.',
#  'the air inside the pyramid was heavy and had a chalky odor.',
#  "pyramids represented not just the tomb of the king but also the nation's pride.",
#  'the effort the pyramid builders put into their work is evident.',
#  'the stones that comprised the pyramid were meticulously fitted and polished until the structure glimmered.',
#  'architects are still trying to decipher the secrets behind the construction of pyramids.',
#  "some believe that ramps were constructed within the pyramid's walls to move stone blocks.",
#  'speculation suggests the exterior walls of the pyramid had ramps with a zigzag design.',
#  'courage and strength are necessary even for beginners of rock climbing.',
#  'learners of rock climbing can start by trying their hand at scrambling on big boulders.',
#  'as they gain confidence new climbers can then advance to using ropes to climb steep rock faces.',
#  'all the boys in the group had never tried rock climbing before.',
#  'fear of heights was common among many.',
#  'they felt more relaxed when someone else checked their knots and harnesses.',
#  'the adults arranged climbing trails fitting for novices.',
#  'rock climbing has a style known as free-climbing.',
#  'the rock climber uses only their ability and muscle power to go up a rock surface.',
#  'only ropes and bolts are utilized as equipment.',
#  'they are intended solely to catch the climber if she falls.',
#  'i warily descended the dangerous path that my companions persuaded me to ski on.',
#  'i made a wrong turn and ended up falling.',
#  'i eventually came to a halt on a level part of the incline.',
#  "my ski equipment couldn't be located and my poles were stuck in a snow drift uphill.",
#  'a significant advantage of professional skiers is their utilization of ski poles.',
#  'the correct use of ski poles enhances balance and adds style to skiing.',
#  'it reduces the requirement for upper body movements to restore lost balance while skiing.',
#  'modern ski designs and stronger boots facilitate quicker turns for skiers.',
#  'but quicker and closer turns amplify the twisting pressure on the legs.',
#  'this has resulted in a higher number of injuries particularly to the knee ligaments.',
#  'a portable musical instrument featuring two keyboards is called an accordion.',
#  'one keyboard is for playing single notes the other for chordal accompaniment.',
#  'the accordion produces sound by the bellows pushing air through the reeds.',
#  'an accordionist manipulates both keyboards while alternately opening and closing the bellows.',
#  'an apartment is a housing unit within a larger building that is self-contained.',
#  'an apartment may consist of one or more rooms a kitchen and a bathroom.',
#  'apartments can be designed for either single people or families.',
#  'the building may have amenities such as a garage laundry service or storage.',
#  'apples a type of fruit come in green red or yellow varieties.',
#  'an apple has a thin exterior a juicy sweet interior and seeds.',
#  'some apples that are very tart are utilized in cider production.',
#  'apples can be consumed fresh or prepared through roasting or baking.',
#  'arson involves intentionally setting fire to a building or wild area.',
#  'a fire investigation aims to determine if the fire was accidental or intentional.',
#  'arson may be committed to cause harm to others or to collect insurance.',
#  'the level of the crime is determined by the presence of harm to individuals.',
#  'a vehicle with wheels for transporting passengers is called an automobile or car.',
#  'the power source for a car can be gasoline or electric.',
#  'the driver controls the car on roads while other passengers simply sit.',
#  'automobiles come in varying sizes door configurations and types of trunk.',
#  'the axe is a tool used for dividing and cutting wood.',
#  'typically an axe comprises of a handle affixed to a head.',
#  'historically axe heads were crafted from stone and then metal.',
#  'axes are employed by woodcutters and firemen for entering buildings.',
#  'bananas are elongated fruits that grow in clusters and have a soft edible interior.',
#  'a ripe banana is either yellow red or purple in color and often has dark spots.',
#  'tropical countries including india and ecuador are the leading producers.',
#  'in many countries unripe bananas and plantains are a staple food often prepared like potatoes.',
#  'a bed is a piece of furniture used as a place to rest or engage in sexual activities.',
#  'a typical bed includes a mattress box spring and bedding items such as sheets pillows and covers.',
#  'in airbeds the mattress is filled with air while in waterbeds it is filled with water.',
#  'another kind of bed is a hammock which is a fabric sling hung above the ground.',
#  'a bee is a six-legged insect with a black and yellow body capable of flying.',
#  'bees help to spread pollen when they are collecting nectar to make honey.',
#  'bees are known for their social behavior and live in communities located inside hives.',
#  'if threatened many types of bees can attack with their stingers.',
#  'a two-wheeled machine powered by the pedalling of a rider is called a bicycle.',
#  'the rider pedals the bicycle while seated on the saddle to move it forward.',
#  "the rubber tires on the bicycle's wheels contain an inner tube with air.",
#  'bicycles are utilized for transportation leisure and competitive racing.',
#  'a blacksmith forms objects by working with hot iron or steel.',
#  'a blacksmith shapes hot iron by striking it with a hammer on an anvil.',
#  'blacksmiths wear a sturdy apron and manipulate the metal using tongs.',
#  'blacksmiths craft items such as weapons horseshoes and metal furniture.',
#  'a blender is a kitchen tool utilized to blend ingredients or puree food.',
#  'a rotating blade is situated in the base of a glass or plastic container in blenders.',
#  'blenders are frequently used to create milk shakes and smoothies.',
#  'blenders can also be utilized to make cocktails with crushed ice.',
#  'a boy is a young male child who has not yet reached puberty.',
#  'the term boy is used to distinguish male children from female children.',
#  'rough play and fighting among themselves are activities that boys traditionally enjoy.',
#  'an adult male who acts childishly is often called a boy.',
#  'the cabbage family includes the plant known as broccoli.',
#  'broccoli has a green head shaped like a flower and a sturdy stem.',
#  'broccoli is abundant in vitamins fiber and other important nutrients.',
#  'boiling stir-frying or consuming raw are possible ways to prepare broccoli.',
#  'butterflies are insects with four wings that allow them to fly.',
#  'bright colors and unique patterns adorn the wings of many butterflies.',
#  'caterpillars undergo a transformation known as metamorphosis to become butterflies.',
#  'people collect butterflies due to their beautifully colored wings.',
#  'a carpenter is a skilled worker or an artist who creates objects using wood.',
#  'carpenters construct and fix homes furnishings boats and other items.',
#  'the tools employed by carpenters include hammers saws pliers and planes.',
#  'carpenters who make and repair musical instruments are known as luthiers.',
#  'small furry animals with four legs and a tail are called cats.',
#  'licking their fur is how cats keep themselves clean.',
#  'cats hunt birds or mice but are often fed by their owners.',
#  'the claws of cats can be retracted to maintain their sharpness.',
#  'a chair is a piece of furniture meant for people to sit on.',
#  'legs provide support for a raised seat above the floor in chairs.',
#  'a chair may include arm and back supports and a cushion.',
#  'seats are stationary chairs that can be found in vehicles or locations such as theaters.',
#  'the clarinet is a type of woodwind musical instrument.',
#  'the clarinet is characterized as a black tubular instrument with a flared bottom.',
#  'the keys and holes are used by the player to choose notes.',
#  'the clarinet is employed in both jazz and classical music styles.',
#  'a fish known as cod resides in the chilly regions of the atlantic ocean.',
#  'cooked cod flesh is easily flaked white in color and has a mild flavor.',
#  'fish and chips are made from fresh cod while salted cod is favored for complex dishes.',
#  'the practice of catching salting and trading cod dates back to the viking era.',
#  'the seeds of the coffee plant known as coffee beans are used to make coffee.',
#  'coffee is widely consumed in many countries and is typically served warm.',
#  'caffeine a mild stimulant is found in coffee and helps people stay awake.',
#  "coffee is one of the world's top seven legal agricultural exports.",
#  'a desert is a region that receives almost no rainfall.',
#  'hot deserts are often filled with sand dunes or rocks.',
#  'some plants and animals have evolved to survive in desert environments.',
#  'the sahara in northern africa is the largest hot desert in the world.',
#  'a desk is a piece of furniture designed to be used as a workspace often with a computer.',
#  'a desk is typically made from materials like metal plastic or wood and features a flat top.',
#  'desks usually come equipped with drawers for holding papers and office supplies.',
#  'a cubicle is a workspace consisting of a desk surrounded by partitions on three sides.',
#  'a door is a movable barrier utilized to control access to an enclosed space.',
#  'to control entry locks are a common feature of most doors.',
#  'doors are usually opened by pulling or pushing a handle after being unlocked.',
#  'there are various types of doors including sliding and revolving doors.',
#  'dresses are articles of clothing that are sometimes favored by women.',
#  'a dress can be considered a shirt connected to a skirt of the same material.',
#  'formal events such as weddings or dances often call for dresses to be worn.',
#  'a dress can make it difficult to engage in activities like climbing stairs or biking.',
#  'driving under the influence of alcohol is referred to as drunk driving.',
#  'in the majority of the world drunk driving is considered a criminal offense.',
#  'drunk driving is a factor in nearly half of all vehicle-related deaths.',
#  'field sobriety and breath tests are used to catch drunk drivers.',
#  'a drought is a persistent lack of water caused by a lack of rainfall.',
#  'drought leads to cessation of growth and death of crops and plants.',
#  'areas can eventually transform into deserts and experience famine during an extreme drought.',
#  'due to dust bowls large numbers of people are forced to relocate.',
#  'eagles are birds of prey that hunt during daylight hours and have good vision.',
#  'eagles possess hooked beaks for tearing flesh sturdy legs and claws that are keen.',
#  'eagles reside in eyries and some species feed on fish while others prey on small mammals.',
#  'the bald eagle has a head that is pure white and is the national bird of the united states.',
#  'earthquakes cause the ground to shake and can bring down buildings and other structures.',
#  'shaking can also lead to landslides and trigger volcanic activity.',
#  "earthquakes are usually the result of energy being released in the earth's crust.",
#  'earthquakes at sea can generate tsunamis by displacing the ocean floor.',
#  'elephants are the largest terrestrial mammals which can weigh many tons.',
#  'an elephant has a trunk which is its long nose that can pick up things.',
#  'elephants have tusks made of ivory which they use to move objects or dig in trees.',
#  'to cool the blood in their large ears and bodies elephants flap their ears.',
#  'the eye is responsible for detecting light and transmitting it to the visual cortex.',
#  'animals often have complex eyes that can recognize color motion and texture.',
#  'the fovea is the center of the eye and the most sensitive part in humans.',
#  'compound eyes consisting of eye units facing multiple directions are present in insects.',
#  'land used to cultivate plants or rear animals for food is known as a farm.',
#  'farmers are responsible for running the farm and determining what crops to produce.',
#  'a farm typically includes a residence for farmers a silo and a barn.',
#  'many farmers who share the land and equipment operate a cooperative.',
#  'each hand of primates usually has four fingers and a thumb.',
#  'fingers are employed for activities such as grasping writing grooming and such.',
#  'the fingertips possess sensitivity to temperature pressure and vibration.',
#  'the finger tip is protected by the nail which can be grown or decorated.',
#  'when water overflows and submerges inhabited land it is referred to as a flood.',
#  'flooding is often the result of intense precipitation a fast-melting snowpack or earthquakes at sea.',
#  'a river can flood by flowing out of its channel or breaking dams and levees.',
#  'people usually evacuate during a flood and the water can spread diseases.',
#  'a floor is a horizontal surface inside a building meant for walking.',
#  'different materials used for flooring include concrete tile linoleum or wooden floorboards.',
#  'carpets are a popular addition to floors as they offer comfort and soundproofing.',
#  'pipes and electrical wiring are often located under the floor in buildings.',
#  'a foot is the body part located at the end of a leg.',
#  'the feet are utilized for walking running and standing straight.',
#  'the feet can be used for kicking both in athletic and martial contexts.',
#  'in some cultures there are regulations on foot-related behavior.',
#  'a dense collection of trees with a significant amount of canopy coverage characterizes a forest.',
#  'forest classification is determined by the climatic conditions such as temperature and rainfall.',
#  'forests are home to different trees and animals as well as plants growing on the ground.',
#  'trees are cleared indiscriminately without regard for replenishment in deforestation.',
#  'a fork is an eating utensil with a handle and several prongs for spearing food.',
#  'forks are frequently constructed of metal or disposable plastic.',
#  'forks are employed to elevate food to the mouth or as a holder while cutting food.',
#  'forks are a typical utensil in western cultures with specific designs for different foods.',
#  'a frying pan is characterized by its shallow design sloping sides and handle.',
#  'food can be fried seared and browned in a frying pan.',
#  'the food is cooked on the bottom of the pan which is covered in oil.',
#  'frying pans can be made from iron or steel covered in teflon.',
#  'a girl is a young female human who has not reached adulthood.',
#  "the change from a girl's body to a woman's body occurs during puberty.",
#  'dolls and social games are often liked by girls.',
#  'girls may grow their hair long and wear dresses and skirts.',
#  'a glove is a type of clothing that covers the hand and fingers.',
#  'wool or waterproof lined gloves are made to keep hands warm.',
#  'disposable gloves made of rubber or latex are utilized to guard against germs or chemicals.',
#  'a mitten is a type of glove where all four fingers are enclosed together.',
#  'a hammer is a tool utilized to apply force to an object.',
#  'driving nails into wood is a common use for a hammer.',
#  'the claw on the head is useful for removing nails.',
#  'the shape of the head and handle length differentiate hammers from one another.',
#  'an explosive used as a weapon against individuals is known as a hand grenade.',
#  'hand grenades are tossed and timed to detonate shortly thereafter.',
#  'grenades can also be launched from rifles or shoulder-mounted launchers.',
#  'tear gas grenades are thrown into the center of a group to cause it to scatter.',
#  'a horse is a large mammal with four long powerful legs and hooves.',
#  'horses are typically brown or gray and have a mane and tail on their neck.',
#  'horses have been utilized for purposes such as draft work transportation and recreation.',
#  'a person can sit on a horse as it walks trots or gallops.',
#  'people visit hospitals to receive treatment for illness or injury.',
#  'hospitals are staffed by doctors surgeons and nurses who are professionals.',
#  'certain patients visit the place to receive specialized diagnosis or treatment and depart the same day.',
#  'some operations or treatments require patients to stay there for several weeks.',
#  'a house is a building or structure meant for permanent living quarters for individuals or families.',
#  'the walls and roof of a house serve to protect from rain and cold with windows to let in light.',
#  'a residence has various rooms for activities like cooking sleeping and washing.',
#  'people usually go to work outside the home and come back in the evenings to eat and sleep.',
#  'an igloo is a domicile made from blocks of snow by the inuit people.',
#  'igloos are typically built in areas where snow covers the ground for most of the time.',
#  'the shape of an igloo is typically that of a dome with an entrance through a tunnel.',
#  "snow's air pockets provide insulation and warmth inside the igloo is generated by body heat.",
#  'a tool with a sharp edge for cutting objects is referred to as a knife.',
#  'modern knives typically feature a handle and a blade made of metal.',
#  'knives have been employed both as weapons and in rituals as instruments.',
#  'attacking with a knife can be done by stabbing tossing or slashing.',
#  'lentils are the seeds of a plant belonging to the legume family.',
#  'lentils come in various colors including red green brown black and yellow.',
#  'lentils are a common ingredient in indian and mediterranean cuisine.',
#  'lentils are a nutritious source of protein and are prepared by boiling them.',
#  'a biennial plant often grown as a leaf vegetable in temperate climates is lettuce.',
#  'lettuce can either be eaten uncooked and cold in dishes like salads or it can be cooked.',
#  'growing lettuce is considered relatively simple making it a great choice for beginner gardeners.',
#  'although the majority of lettuce leaves are bitter some varieties have been developed without bitterness.',
#  'a collection of books documents and various forms of media are stored in a library.',
#  'librarians are employees of libraries and are knowledgeable about locating and organizing information.',
#  'public libraries allow patrons to take books home for several weeks after borrowing them.',
#  'specialized books can be found at academic libraries which support scholarly research.',
#  'a log cabin is a compact dwelling constructed using round logs.',
#  'the log cabin is considered a hallmark of the american frontier experience.',
#  'the first shelters for european settlers in america were log cabins.',
#  'log cabins were constructed using logs that were joined at the ends using notch joints.',
#  'a man is a mature male human.',
#  'the transition from boy to man occurs after puberty.',
#  'masculinity and virility are characteristic of manhood.',
#  'height weight and body structure differ between men and women.',
#  'milk is a fluid secreted by female mammals to nourish their young.',
#  'young animals need to be nursed with milk until they can consume solid food.',
#  'cheese and butter are dairy products that are made using milk.',
#  'a liquid produced from soybeans and coconuts is sometimes referred to as milk.',
#  'mosquitos are tiny slender flying insects that produce a shrill sound.',
#  'mouthparts on mosquitoes enable them to penetrate the skin of plants and animals.',
#  'female mosquitoes feed on the blood of people and animals by biting them.',
#  'yellow fever malaria and other parasitic diseases can be transmitted by mosquito bites.',
#  'a mountain is a terrain feature that rises abruptly from the surrounding lands.',
#  'high-rising landforms that sometimes have snow on their peaks are known as mountains.',
#  'tectonic plates colliding results in a chain of mountains being formed.',
#  'mountaineers are adventurous individuals who engage in ascending mountains.',
#  'the mouth is the entrance to the digestive system where food is consumed.',
#  'the mouth is equipped with teeth for breaking down food by chewing.',
#  'talking and kissing are also performed using the mouth.',
#  'the position of the tongue inside the mouth determines the speech sounds.',
#  'a mug is a sturdy drinking cup with a handle for hot liquids.',
#  'a mug can be crafted from ceramics or it may be comprised of metal or glass.',
#  'a mug is designed to be thick with a circular base for efficient heat insulation.',
#  'a mug may have drawings imprinted or carved onto its surface or be left plain.',
#  'murder is defined as the intentional killing of a human being.',
#  'murder is considered a serious crime because it denies the victim the right to life.',
#  'killing occurring in self-defense unintentionally or in war are not regarded as murder.',
#  'convicted murderers are often given a sentence of life in prison or the death penalty.',
#  'orange juice is a beverage made from the juice extracted from oranges.',
#  'orange juice is characterized by its sweet and acidic flavor and is also packed with vitamin c.',
#  'fresh orange juice often includes bits of pulp.',
#  'orange juice is frequently consumed from a glass especially at breakfast time.',
#  'parrots are birds that are commonly found in warm and tropical areas.',
#  'parrots are known for their brightly colored feathers and hooked beaks.',
#  'if parrots are exposed to human voices frequently they can mimic them.',
#  'their unique appearance and abilities make parrots popular as pets.',
#  'a peach is a fruit with orange-yellow color and a distinctive aroma.',
#  'the surface of a peach is fragile and covered in delicate minute hairs.',
#  'the heart of a peach has a large brownish-red seed-containing stone.',
#  'peaches must be harvested after they have become sweet and delicate through ripening.',
#  'the piano is a commonly used musical instrument operated by a keyboard.',
#  'when a piano key is pressed a hammer tipped with felt strikes a vibrating steel string.',
#  'the piano has a vast range of notes and pedals to alter the tone.',
#  'because of the rich piano repertoire famous pianists can give solo concerts.',
#  'piranhas are vicious small fish found in rivers of south america.',
#  'piranhas hunt and attack in groups and they are most energetic during daylight hours.',
#  'piranhas have incredibly sharp teeth and are opportunistic meat-eaters.',
#  'piranhas feed on fish insects reptiles mammals and carrion.',
#  'raspberries grow in forest clearings or in fields and are a type of fruit.',
#  'one raspberry is formed by the joining of many small fruits.',
#  'raspberries can be consumed plain or used to make sweet sugary jam.',
#  'fresh or dried raspberry leaves can be used to make herbal teas.',
#  'a raven is a large black bird that thrives in various climates.',
#  'ravens feed on dead animals insects small creatures or fruit.',
#  'ravens have impressive cognitive abilities and can solve problems.',
#  'in folklore ravens are often associated with misfortune and cunning.',
#  'a refrigerator is utilized to keep food fresh and its temperature regulated.',
#  'some refrigerators come with a small compartment that maintains a freezing temperature.',
#  'a refrigerator may have shelves and small compartments to store different types of food.',
#  'refrigerators are generally white and people often place magnets on their surface.',
#  'a shoulder-supported firearm with a barrel featuring spiral grooves is referred to as a rifle.',
#  'the grooves on the rifle cause the bullets to rotate around its axis while in flight.',
#  'hunting and shooting sports often utilize rifles sometimes with the aid of scopes.',
#  'standard infantry weapons are the assault rifles which can fire in short bursts.',
#  'the salmon fish species migrates from freshwater to the ocean to reproduce and then returns.',
#  'salmon flesh with its high protein content and good taste is either orange or red.',
#  'salmon can be consumed raw in sushi or prepared by cooking methods such as grilling or poaching.',
#  'the most frequently farmed fish is salmon though it can also be caught in the wild.',
#  'the saw is a tool that cuts through tough materials using a hard blade or abrasive wire.',
#  "the tiny pointed blades along the cutting edge of the saw are known as the saw's teeth.",
#  'saws can be operated manually or with the help of an electrical motor or gasoline engine.',
#  'saws are commonly used in the fields of construction forestry carpentry and medicine.',
#  "a scientist's work involves discovering new information about the physical world.",
#  'scientists develop theories and conduct experiments to verify them.',
#  'physics chemistry and biology are well-known fields of science.',
#  'scientists publish their findings in academic journals and conferences.',
#  'scissors are a cutting tool consisting of two blades.',
#  'they typically have metal blades and plastic or metal handles.',
#  'depending on the type and design scissors can be used to cut paper hair or cloth.',
#  'large scissors known as shears are used for cutting shrubs or metal.',
#  'a screwdriver is a tool used for inserting screws and tightening them.',
#  'the screwdriver can be used to both insert and remove screws.',
#  "the screwdriver's tip transmits the rotational force from the handle.",
#  'phillips and flathead are the two primary types of screwdrivers.',
#  'sharks are large fish that have skeletons made of cartilage.',
#  'sharks have a sleek body with a large dorsal fin on top.',
#  'a majority of sharks hunt for fish and mammals utilizing their strong jaws.',
#  'sharks possess highly developed senses and can detect electrical signals.',
#  'a ship is a massive vehicle designed to float on water.',
#  'a ship can be propelled through the ocean by either sails steam or diesel engines.',
#  'ships are utilized for fishing in the ocean and for carrying cargo containers.',
#  'cruise ships are large floating hotels that transport passengers between cities.',
#  'footwear consisting of a sole outsole and heel is known as a shoe.',
#  'the materials used for shoes can include leather canvas rubber and plastic.',
#  'female shoes may have high heels and are available in various styles and colors.',
#  'sneakers are shoes made for athletic activities and sports.',
#  'a member of the military who engages in land-based combat is known as a soldier.',
#  'militiamen are usually required to wear a uniform often with camouflage.',
#  'in a volunteer military soldiers are compensated for their services.',
#  'in combat soldiers employ weapons such as rifles and grenades.',
#  'spears are composed of a long pole with a sharp head at one end.',
#  'the spear was the weapon of choice for individuals before firearms came about.',
#  'in war the spear was utilized for both stabbing and throwing.',
#  'some indigenous communities still use spears for fishing and hunting.',
#  'insects that have eight legs and make silk are called spiders.',
#  'webs are constructed by spiders using silk to trap insects.',
#  'their prey is paralyzed by spiders using venomous fangs.',
#  'the size of spiders can range from tiny like a coin to big like a bird.',
#  'swamps are inundated lowlands with spongy soil.',
#  'a swamp is characterized by shallow water mud and vegetation.',
#  'swamps serve as nesting and breeding grounds for birds and reptiles.',
#  'swamps are often transformed into arable land by draining them.',
#  'a garment worn for warmth on the torso is called a sweater.',
#  'wool and cotton are both materials used to make sweaters.',
#  'a cardigan is a type of sweater that opens in the front.',
#  'sweaters can differ in terms of cut collar sleeve shape and decoration.',
#  'a table is a piece of furniture with a flat surface and supporting legs.',
#  'chairs are often placed near tables for individuals to sit.',
#  'dining utensils dishes and food are placed on a table for group meals.',
#  'a table can be used as a writing or work surface.',
#  'a television is a device with a screen that shows moving images.',
#  'televisions are primarily used to watch movies or programs.',
#  'when connected to a game console televisions can be used to play video games.',
#  'television content can be broadcast or transmitted via cable or the internet.',
#  "theft is the act of taking someone's property without their permission.",
#  "burglars take what doesn't belong to them for personal gain or for reselling.",
#  'stealing is a criminal act that can lead to jail time or fines.',
#  'industrial espionage involves the thievery of intellectual property and concepts.',
#  'bread can be toasted using a kitchen appliance known as a toaster.',
#  'toast made using a pop-up toaster toasts bread in a slot and ejects it when done.',
#  'toaster ovens have temperature regulation a door on the side and a tray within.',
#  'they enable the preparation of bread with toppings such as garlic or cheese.',
#  'the tomato is a shiny smooth and red fruit that has a savory taste.',
#  'as a tomato becomes more mature it changes color from green to red and becomes softer.',
#  'tomatoes can be made into salads soup ketchup or used as a sauce.',
#  'with various sizes and flavors there are many varieties of tomatoes.',
#  'a train is a series of rail vehicles that run on a track between stations.',
#  'the locomotive powered by either diesel or electricity pulls the train.',
#  'a freight train carries containers of goods and fuel over long distances.',
#  'commuter trains are trains that move people between suburban locations and city stations.',
#  'a train station is a location where individuals get on or off a train.',
#  'train stations offer ticket counters or vending machines for ticket purchase.',
#  'a station comprises waiting areas and dining facilities.',
#  'passengers or cargo trains arrive at a platform alongside the tracks.',
#  'tropical cyclones are storms that arise over warm tropical oceans.',
#  'tropical cyclones are known for their strong winds and heavy rainfall.',
#  'coastal flooding and high waves can be caused by tropical cyclones.',
#  'a tropical cyclone that moves inland can cause significant damage to property.',
#  'the violin is a stringed instrument that is played using a bow.',
#  'the violin is the smallest and possesses the highest pitch in its family.',
#  'the violin is positioned between the chin and collarbone by the violinist.',
#  'one hand is used to finger the neck while bowing thus producing different notes.',
#  'vultures are birds that primarily feed on dead animal carcasses.',
#  'the heads of many vultures are bald without feathers to prevent overheating.',
#  'large wings allow vultures to soar for miles without flapping.',
#  'while healthy animals are usually safe vultures may kill wounded or sick animals.',
#  'a wall is a sturdy structure that outlines and sometimes safeguards an area.',
#  'the building is defined by its walls which also support the roof and separate rooms.',
#  'walls are typically constructed from materials such as stone brick cement or drywall.',
#  'retaining walls obstruct the motion of earth stone or water.',
#  'water the most abundant liquid on earth covers 70% of its surface.',
#  'without access to water plants animals and humans cannot survive.',
#  'water becomes solid ice when it freezes at a low temperature.',
#  'the formation of rain occurs when water vapor in the clouds condenses into liquid form.',
#  'the ocean is the habitat of whales which are very large mammals.',
#  'whales use blowholes located on their heads to breathe when they surface.',
#  'the blubber on a whale functions as both a source of energy and insulation.',
#  'hunting of whales has taken place for their meat whale oil and ambergris.',
#  'a window is a see-through opening in a wall that allows light to enter.',
#  'a standard window typically consists of glass panels held in place by a frame.',
#  'when opened a window will also admit air and sounds from the outside.',
#  'multiple glass panes in a window can improve insulation within a building.',
#  'a woman is a female human who has reached adulthood.',
#  'women are often depicted as caretakers in society.',
#  'women are capable of pregnancy and delivering offspring.',
#  'the reproductive systems of women differ from those of men.']

# %%
stimuli_df_copy['sentence'] = sentence_paraphrase

# %%
stimuli_df_copy.sentence.values # Great, they have final periods and apostrophes
# Out:
# array(['beekeeping plays a role in conserving local ecosystems.',
#        'conserving regional vegetation that provides pollen is of the utmost importance for beekeepers.',
#        'this form of agriculture which is passive in nature does not necessitate removal of native plants for crop cultivation.',
#        'beekeepers are against the use of pesticides on crops as they could harm the honeybees.',
#        'artisanal beekeepers go to great lengths for their craft but their product is worth it.',
#        'artisanal honey-making values quality and uniqueness over quantity and uniformity.',
#        'to achieve the best quality honey beekeepers closely monitor their honeybee populations.',
#        'by exploring the lands and observing nectar patterns they are able to collect the honey effectively.',
#        'as the beekeeper begins to access the hive the drone of 40000 bees fills the air.',
#        'the beekeeper inspects the honey stores the availability of pollen and the bee nursery.',
#        "despite crawling on his unprotected arms and hands the bees don't sting because of their peaceful demeanor.",
#        'i have a persistent dream about taking exams despite no longer being in college.',
#        "my dream is about being on the day of a final exam and realizing i haven't attended any classes.",
#        'not a single reading assignment has been completed by me.',
#        'the same bad dream is experienced by numerous other individuals i know.',
#        'participants in the study documented their dream experiences from the prior night each morning.',
#        'they jotted down their memory of dreams and outlined the dream and the corresponding emotional intensity.',
#        'after that the participants categorized each dream such as a dream of flying a negative dream or a scary dream.',
#        'the mind is as busy at night while we sleep as it is during wakefulness.',
#        'throughout the night we experience dream cycles that last approximately ninety minutes each.',
#        'dreams can contain a mix of images emotions tales and bizarre combinations of characters and settings.',
#        'when i made the decision to start playing cards the situation worsened.',
#        'gambling was something i had to do and i had already spent nearly $10000 on it.',
#        'my friends were tired of seeing me squander my savings on gambling.',
#        'the worst part was the terror of leaving a casino after losing money i did not own.',
#        'it is challenging to acquire accurate data on the social and economic effects of legalized gambling.',
#        'certain studies suggest that having a casino nearby increases the likelihood of gambling problems.',
#        'personal bankruptcies and marriage problems may also be related to gambling.',
#        'over the last generation there has been a significant expansion of legalized gambling.',
#        'most states have implemented lotteries and many have established casinos as well.',
#        'gambling has become a substantial yet disputed industry.',
#        'a kitchen window was shattered by the house being shaken by the wind from the hurricane.',
#        'we quickly went in got some food closed the door and left the kitchen to the hurricane.',
#        'i was afraid that our house would be torn from its foundation.',
#        'with the house being shaken by the wind we eventually fell asleep while huddled on the couch.',
#        'hurricanes can detach tree limbs and extract houses from their foundations.',
#        'they bring heavy rains that can cause floods and mudslides.',
#        'hurricanes can produce a surge which is a wall of ocean water that moves onto land.',
#        'scientists employ multiple techniques to search for evidence of ancient hurricanes.',
#        'the most severe storms left layers of wind-blown sand from beaches at the bottom of coastal lakes.',
#        'the growth rings of trees drenched by passing hurricanes show a record of each storm.',
#        'the flavor preferences for american ice cream vary in different countries it is exported to.',
#        'many individuals appreciate ice cream flavored with local specialty ingredients.',
#        'some tropical regions enjoy vanilla ice cream topped with ripe bananas and mangos.',
#        'as a child i recall making ice cream at home.',
#        'the cream mixture was placed into a frozen container then we started turning the crank to cool it.',
#        'the hand crank could not be turned anymore once it froze enough.',
#        'to harden i put the partially frozen container of ice cream into the freezer.',
#        'the mixture that makes up ice cream is comprised of milk or cream sugar flavorings and air.',
#        'butterfat in milk and cream is responsible for giving it its velvety texture.',
#        'high-end ice cream is rich with butterfat and has natural flavorings.',
#        'the chair on the riding lawn mower makes my back ache when i use it.',
#        'i operate the machine using two levers in front of me.',
#        'the blades underneath the lawn mower cleanly sever every blade of grass.',
#        'mowing the lawn has been a long process that has taught me patience.',
#        'a lawn mower is a machine equipped with revolving blades for cutting grass to a uniform height.',
#        'the blades may either be powered by hand or by a motor.',
#        'the primary energy source utilized in lawn mowers is a compact gasoline engine.',
#        'electric lawnmowers are friendlier to the environment due to the absence of emissions.',
#        'furthermore they are cheaper to run and require less upkeep.',
#        'electric lawn mowers and ordinary toasters consume the same amount of electricity.',
#        'spacewalk training for astronauts is extensive and time-consuming.',
#        'a substantial portion of their training takes place underwater.',
#        'they may spend 8 to 10 hours in a pool for every hour they will spend in space.',
#        'to carry out repair and construction work on the outside of the space station astronauts practice.',
#        'shuttle flight commanders are always pilots and a substantial number of them have military test pilot experience.',
#        'other astronauts have training as physicians engineers and researchers and can perform experiments in space.',
#        'young men exclusively constituted the early crews while modern-day astronauts are considerably more diverse.',
#        'the team of astronauts moved together towards the exterior of the space shuttle.',
#        'they carried the necessary tools to fix the damaged part on the large telescope.',
#        'the first astronaut loosened the bolts on the pipe and the second installed the new part.',
#        'experimental artists have been using computers in art for quite a while.',
#        'with computers becoming more accessible and prevalent computer graphics have become part of the mainstream art world.',
#        'a few computer science conferences host art exhibitions showcasing the cutting-edge graphics technology.',
#        'new conferences have emerged with the specific aim of bridging the gap between the two cultures.',
#        'working alongside doctors the computer graphics specialist produces visualizations of medical conditions and surgical procedures.',
#        'she employs digital animation to clarify internal body structures for physicians.',
#        'looking at internal structures through animation on a screen is much more comprehensible than studying x-rays.',
#        'digital animation has become an influential educational tool.',
#        'as the field of computer graphics expands it is important to examine if graphics actually benefit students.',
#        'research indicates that visually appealing and engaging digital images can be productive in the classroom.',
#        'the driving force behind his enrollment in law school was a tired trope.',
#        'he sought to effect change for the better.',
#        'he remembered a time at law school when he and the program director pulled an all-nighter.',
#        'the petition for several evicted families was finally completed at dawn.',
#        'the cost of legal education has been steadily rising for the past four decades.',
#        'the cost of attending private law school has quadrupled since the 1970s.',
#        'the market for law school and new lawyers could collapse at some point.',
#        'many law school faculty members have limited experience in legal practice.',
#        'the primary focus of professors is publishing review articles in reputable law journals.',
#        'classes on theoretical topics such as property law in feudal england are frequently taught in law schools.',
#        'the role of pharmacists in preventive care is growing.',
#        "pharmacists are increasingly serving as primary healthcare advisors due to people's frequent visits to pharmacies.",
#        'pharmacists are knowledgeable about public health and can offer helpful insights.',
#        'pharmacists are frequently sought out by physicians for their knowledge of medication side effects.',
#        'dispensing of prescription drugs and advice on their safe use is a role of pharmacists.',
#        'they are also responsible for conducting health screenings and administering vaccines.',
#        'becoming a pharmacist requires obtaining a professional degree and passing two exams.',
#        'i feel like the pharmacy profession chose me as much as i chose it.',
#        'as a child i was drawn to the neatly organized bottles in pharmacies.',
#        'making a difference in the lives of my patients is what i love about my job.',
#        'individual reactions to potentially stressful situations vary per person.',
#        'unemployment may cause one person to feel upset while another may experience stress from working full-time.',
#        'there are common stressors such as getting stuck in traffic.',
#        'traumatic stressors include significant events such as divorce and loss of a child.',
#        'some individuals are capable of adapting to various stress levels.',
#        "if not managed properly stress can have negative effects on one's health.",
#        'keep in mind whether stress is harmful or beneficial depends on how you react to it.',
#        'i felt worried and stressed when my company was undergoing downsizing.',
#        'i experienced an accelerated heart rate for no reason and moments of dizziness.',
#        'to manage my stress level i started practicing yoga.',
#        'the man donned a tuxedo that was jet black and featured satin stripes.',
#        'it was fashioned with top-notch material in a contemporary style.',
#        "the tuxedo hugged the man's body as if it were tailored just for him.",
#        'it seemed like it was handpicked by a style expert for a formal occasion.',
#        'although tuxedos remain popular modern grooms are expressing their individuality through their wedding attire.',
#        'cutting-edge fashion for weddings features jackets of a shorter length for men.',
#        'colorful shirts and satin ties are being used by grooms to add flair to their tuxedos.',
#        'a tailless jacket with black silk lapels is known as a tuxedo jacket.',
#        'the trousers worn for a black tie occasion should blend seamlessly with the tuxedo jacket.',
#        'a plain white shirt must be worn and the black tie complementing the jacket lapels is necessary.',
#        'the concert pianist lost her sight as an adult.',
#        "the pianist's blindness was caused by a genetic ailment that progressively affected her eyesight.",
#        'she informed interviewers that being blind was an asset for a pianist.',
#        'she had no visual distractions allowing her to concentrate fully on her music.',
#        'the government determines blindness as vision that is insufficient for normal life activities.',
#        'the definition of legal blindness enables the focusing of resources towards those who fit the criteria.',
#        "this definition may exclude individuals who have vision problems but don't meet the legal standard.",
#        'in developing nations blindness in children is frequently caused by infectious diseases and malnutrition.',
#        'prevention of these causes is frequently possible through medication and vitamin supplements.',
#        'genetic issues are a more probable cause of blindness in developed nations.',
#        'the precise way a taste reaches from the mouth to the brain is unknown.',
#        'scientists theorize that the process starts when food molecules touch taste bud cells.',
#        'the taste bud cell conveys the taste information to the taste nerves found underneath it.',
#        'it was previously thought that each taste bud only responded to one of the four fundamental tastes.',
#        "for instance a taste bud located at the tongue's tip was believed to only respond when sweet food was eaten.",
#        'scientists now believe that a single taste bud can be responsive to all of the main tastes.',
#        'due to my poor sense of taste i tend to consume foods with very pronounced flavors.',
#        'i am a fan of hot sauce and i drink my coffee black therefore it is quite bitter.',
#        'my taste for sweetness is weak therefore i put extra sugar in my cookies.',
#        'hip fractures are a real issue for older individuals.',
#        'the patients are plagued with the ache of the break and the challenging healing process.',
#        "the patient's family must adapt to the loss of independence.",
#        'significant hospitalization time and expenses are incurred by society as a result of hip fractures.',
#        'during the race i heard a sound similar to someone snapping their fingers.',
#        'i felt a crunch and immediately recognized that i had a broken foot.',
#        'every step was like walking on spikes.',
#        "the x-ray at the doctor's office revealed the fracture clearly.",
#        'there are several different types of bone fractures.',
#        'simple fractures are when the bone is broken but the skin is not.',
#        'the skin has been punctured by the broken bone in open or compound fractures causing an open wound.',
#        'new ear piercings can become contaminated if they are not maintained properly.',
#        'tenderness swelling or redness around the earlobe are indications of infection.',
#        'clean the area and apply some ointment if the symptoms are observed.',
#        'if the redness and swelling persist seek the advice of your healthcare provider.',
#        'a local hospital has introduced new measures to decrease infections.',
#        'they have implemented better hand hygiene practices and separated those who are infected from other patients.',
#        'the new measures have led to a reduction in infection rates at the hospital.',
#        'scrubbing a wound with soap or alcohol slows down the healing process making it more vulnerable to infections.',
#        'band-aids can trap heat and moisture which can raise the risk of infection.',
#        'the good news is that skin infections are typically easy to treat once diagnosed.',
#        'modern opera originated in the late sixteenth century.',
#        'it started out as an attempt to revive and emulate greek tragic theater.',
#        'the pioneers of opera chose ancient tales as the subjects for their works.',
#        'as opera evolved it expanded into different sources of stories and musical styles.',
#        'opera is a type of art where performers including singers and musicians put on a show that blends music and words.',
#        'it incorporates many elements of spoken theater such as acting scenery and costumes.',
#        'performances are usually held in opera houses and backed by orchestras.',
#        'the opera singer has worked diligently to be cast in the upcoming performance.',
#        'her role entails more than just singing.',
#        'acting stage presence and musical interpretation are all key elements.',
#        'however her clear powerful voice is the highlight of the performance.',
#        'a painter has to consider many factors while working on a painting.',
#        'strong design elements such as composition and lighting must be included.',
#        'the painter must execute the brushwork with mastery.',
#        "most of all the painting should convey a part of the painter's soul.",
#        'in bygone days painters were viewed more as skilled artisans than imaginative artists.',
#        'yet painters of renown enjoyed the same social standing as scholars and members of the royal court.',
#        'they signed their pieces selected the themes and representations and built personal connections with those who commissioned them.',
#        'as a painter i realized the significance of focusing less on the particular scene and more on the painting itself.',
#        'the eye of an artist is not like a camera lens that must capture everything within its field of vision.',
#        'i discovered that nature provides useful information but not always necessary for a good painting.',
#        'the eagle owl is an awe-inspiring bird.',
#        'it has ear flaps that resemble horns and stand upright.',
#        'its big orange eyes are creepy and look like they could penetrate right through you.',
#        'this bird hunts at night flying quickly and quietly through the dark.',
#        'despite some owl species facing endangerment others are flourishing.',
#        'the barred owl has expanded its range beyond its original territory.',
#        "logging appears to have played a role in the barred owl's spread.",
#        'the owl perched on a sturdy branch holding on tight with its claws.',
#        'she folded her wings against her body and settled down partly closing an eye.',
#        'she appeared like a statue except for the gleam in her eyes.',
#        'the sight of a polar bear moving across ice floes is disconcerting.',
#        "it's a frightening experience to be in the cold waters directly beneath the massive animal.",
#        'giant paws descended on the ice as the polar bear hunted its quarry overhead.',
#        'as a member of the film crew for a polar bear documentary i devoted months to capturing these shots.',
#        'polar bears are one of the few exceptions where animals will attack people for reasons beyond fear or misunderstanding.',
#        'living in an environment with limited food resources they might attack due to hunger.',
#        'they will advance cautiously towards people making sure to conserve their energy.',
#        "seals are a crucial part of the polar bear's food supply.",
#        "when hunting they will either wait near a seal's breathing hole or track seals lounging on the ice.",
#        'the polar bear will creep silently forward and remain motionless when the seal surveys its surroundings.',
#        'defense was not the primary purpose for the construction of medieval castles.',
#        'its primary aim was to assert dominance over its surroundings.',
#        'a castle could easily govern territories within reach in a single day.',
#        "during an invasion everything from the peasants to the livestock and properties could be secured inside the castle's fortifications.",
#        'dramatic castles in awe-inspiring locations are a reminder of the stormy history of many areas.',
#        'presently they perch on rocky cliffs that overlook charming villages and picturesque landscapes.',
#        'historically they have been the site of battles schemes and conspiracies.',
#        'upon leaving the railway station we spotted our hotel towering above us a stunning castle built on a cliff.',
#        'the outer walls shielded an inner courtyard located hundreds of feet above the river.',
#        'our tower rooms had a breathtaking but somewhat frightening view.',
#        "after climbing up the pyramid's side for fifty feet the man gestured for me to enter a small black opening.",
#        'this took me to the heart of the pyramid.',
#        'i trailed him through the steep dark and tight passage.',
#        'the air inside the pyramid was heavy and had a chalky odor.',
#        "pyramids represented not just the tomb of the king but also the nation's pride.",
#        'the effort the pyramid builders put into their work is evident.',
#        'the stones that comprised the pyramid were meticulously fitted and polished until the structure glimmered.',
#        'architects are still trying to decipher the secrets behind the construction of pyramids.',
#        "some believe that ramps were constructed within the pyramid's walls to move stone blocks.",
#        'speculation suggests the exterior walls of the pyramid had ramps with a zigzag design.',
#        'courage and strength are necessary even for beginners of rock climbing.',
#        'learners of rock climbing can start by trying their hand at scrambling on big boulders.',
#        'as they gain confidence new climbers can then advance to using ropes to climb steep rock faces.',
#        'all the boys in the group had never tried rock climbing before.',
#        'fear of heights was common among many.',
#        'they felt more relaxed when someone else checked their knots and harnesses.',
#        'the adults arranged climbing trails fitting for novices.',
#        'rock climbing has a style known as free-climbing.',
#        'the rock climber uses only their ability and muscle power to go up a rock surface.',
#        'only ropes and bolts are utilized as equipment.',
#        'they are intended solely to catch the climber if she falls.',
#        'i warily descended the dangerous path that my companions persuaded me to ski on.',
#        'i made a wrong turn and ended up falling.',
#        'i eventually came to a halt on a level part of the incline.',
#        "my ski equipment couldn't be located and my poles were stuck in a snow drift uphill.",
#        'a significant advantage of professional skiers is their utilization of ski poles.',
#        'the correct use of ski poles enhances balance and adds style to skiing.',
#        'it reduces the requirement for upper body movements to restore lost balance while skiing.',
#        'modern ski designs and stronger boots facilitate quicker turns for skiers.',
#        'but quicker and closer turns amplify the twisting pressure on the legs.',
#        'this has resulted in a higher number of injuries particularly to the knee ligaments.',
#        'a portable musical instrument featuring two keyboards is called an accordion.',
#        'one keyboard is for playing single notes the other for chordal accompaniment.',
#        'the accordion produces sound by the bellows pushing air through the reeds.',
#        'an accordionist manipulates both keyboards while alternately opening and closing the bellows.',
#        'an apartment is a housing unit within a larger building that is self-contained.',
#        'an apartment may consist of one or more rooms a kitchen and a bathroom.',
#        'apartments can be designed for either single people or families.',
#        'the building may have amenities such as a garage laundry service or storage.',
#        'apples a type of fruit come in green red or yellow varieties.',
#        'an apple has a thin exterior a juicy sweet interior and seeds.',
#        'some apples that are very tart are utilized in cider production.',
#        'apples can be consumed fresh or prepared through roasting or baking.',
#        'arson involves intentionally setting fire to a building or wild area.',
#        'a fire investigation aims to determine if the fire was accidental or intentional.',
#        'arson may be committed to cause harm to others or to collect insurance.',
#        'the level of the crime is determined by the presence of harm to individuals.',
#        'a vehicle with wheels for transporting passengers is called an automobile or car.',
#        'the power source for a car can be gasoline or electric.',
#        'the driver controls the car on roads while other passengers simply sit.',
#        'automobiles come in varying sizes door configurations and types of trunk.',
#        'the axe is a tool used for dividing and cutting wood.',
#        'typically an axe comprises of a handle affixed to a head.',
#        'historically axe heads were crafted from stone and then metal.',
#        'axes are employed by woodcutters and firemen for entering buildings.',
#        'bananas are elongated fruits that grow in clusters and have a soft edible interior.',
#        'a ripe banana is either yellow red or purple in color and often has dark spots.',
#        'tropical countries including india and ecuador are the leading producers.',
#        'in many countries unripe bananas and plantains are a staple food often prepared like potatoes.',
#        'a bed is a piece of furniture used as a place to rest or engage in sexual activities.',
#        'a typical bed includes a mattress box spring and bedding items such as sheets pillows and covers.',
#        'in airbeds the mattress is filled with air while in waterbeds it is filled with water.',
#        'another kind of bed is a hammock which is a fabric sling hung above the ground.',
#        'a bee is a six-legged insect with a black and yellow body capable of flying.',
#        'bees help to spread pollen when they are collecting nectar to make honey.',
#        'bees are known for their social behavior and live in communities located inside hives.',
#        'if threatened many types of bees can attack with their stingers.',
#        'a two-wheeled machine powered by the pedalling of a rider is called a bicycle.',
#        'the rider pedals the bicycle while seated on the saddle to move it forward.',
#        "the rubber tires on the bicycle's wheels contain an inner tube with air.",
#        'bicycles are utilized for transportation leisure and competitive racing.',
#        'a blacksmith forms objects by working with hot iron or steel.',
#        'a blacksmith shapes hot iron by striking it with a hammer on an anvil.',
#        'blacksmiths wear a sturdy apron and manipulate the metal using tongs.',
#        'blacksmiths craft items such as weapons horseshoes and metal furniture.',
#        'a blender is a kitchen tool utilized to blend ingredients or puree food.',
#        'a rotating blade is situated in the base of a glass or plastic container in blenders.',
#        'blenders are frequently used to create milk shakes and smoothies.',
#        'blenders can also be utilized to make cocktails with crushed ice.',
#        'a boy is a young male child who has not yet reached puberty.',
#        'the term boy is used to distinguish male children from female children.',
#        'rough play and fighting among themselves are activities that boys traditionally enjoy.',
#        'an adult male who acts childishly is often called a boy.',
#        'the cabbage family includes the plant known as broccoli.',
#        'broccoli has a green head shaped like a flower and a sturdy stem.',
#        'broccoli is abundant in vitamins fiber and other important nutrients.',
#        'boiling stir-frying or consuming raw are possible ways to prepare broccoli.',
#        'butterflies are insects with four wings that allow them to fly.',
#        'bright colors and unique patterns adorn the wings of many butterflies.',
#        'caterpillars undergo a transformation known as metamorphosis to become butterflies.',
#        'people collect butterflies due to their beautifully colored wings.',
#        'a carpenter is a skilled worker or an artist who creates objects using wood.',
#        'carpenters construct and fix homes furnishings boats and other items.',
#        'the tools employed by carpenters include hammers saws pliers and planes.',
#        'carpenters who make and repair musical instruments are known as luthiers.',
#        'small furry animals with four legs and a tail are called cats.',
#        'licking their fur is how cats keep themselves clean.',
#        'cats hunt birds or mice but are often fed by their owners.',
#        'the claws of cats can be retracted to maintain their sharpness.',
#        'a chair is a piece of furniture meant for people to sit on.',
#        'legs provide support for a raised seat above the floor in chairs.',
#        'a chair may include arm and back supports and a cushion.',
#        'seats are stationary chairs that can be found in vehicles or locations such as theaters.',
#        'the clarinet is a type of woodwind musical instrument.',
#        'the clarinet is characterized as a black tubular instrument with a flared bottom.',
#        'the keys and holes are used by the player to choose notes.',
#        'the clarinet is employed in both jazz and classical music styles.',
#        'a fish known as cod resides in the chilly regions of the atlantic ocean.',
#        'cooked cod flesh is easily flaked white in color and has a mild flavor.',
#        'fish and chips are made from fresh cod while salted cod is favored for complex dishes.',
#        'the practice of catching salting and trading cod dates back to the viking era.',
#        'the seeds of the coffee plant known as coffee beans are used to make coffee.',
#        'coffee is widely consumed in many countries and is typically served warm.',
#        'caffeine a mild stimulant is found in coffee and helps people stay awake.',
#        "coffee is one of the world's top seven legal agricultural exports.",
#        'a desert is a region that receives almost no rainfall.',
#        'hot deserts are often filled with sand dunes or rocks.',
#        'some plants and animals have evolved to survive in desert environments.',
#        'the sahara in northern africa is the largest hot desert in the world.',
#        'a desk is a piece of furniture designed to be used as a workspace often with a computer.',
#        'a desk is typically made from materials like metal plastic or wood and features a flat top.',
#        'desks usually come equipped with drawers for holding papers and office supplies.',
#        'a cubicle is a workspace consisting of a desk surrounded by partitions on three sides.',
#        'a door is a movable barrier utilized to control access to an enclosed space.',
#        'to control entry locks are a common feature of most doors.',
#        'doors are usually opened by pulling or pushing a handle after being unlocked.',
#        'there are various types of doors including sliding and revolving doors.',
#        'dresses are articles of clothing that are sometimes favored by women.',
#        'a dress can be considered a shirt connected to a skirt of the same material.',
#        'formal events such as weddings or dances often call for dresses to be worn.',
#        'a dress can make it difficult to engage in activities like climbing stairs or biking.',
#        'driving under the influence of alcohol is referred to as drunk driving.',
#        'in the majority of the world drunk driving is considered a criminal offense.',
#        'drunk driving is a factor in nearly half of all vehicle-related deaths.',
#        'field sobriety and breath tests are used to catch drunk drivers.',
#        'a drought is a persistent lack of water caused by a lack of rainfall.',
#        'drought leads to cessation of growth and death of crops and plants.',
#        'areas can eventually transform into deserts and experience famine during an extreme drought.',
#        'due to dust bowls large numbers of people are forced to relocate.',
#        'eagles are birds of prey that hunt during daylight hours and have good vision.',
#        'eagles possess hooked beaks for tearing flesh sturdy legs and claws that are keen.',
#        'eagles reside in eyries and some species feed on fish while others prey on small mammals.',
#        'the bald eagle has a head that is pure white and is the national bird of the united states.',
#        'earthquakes cause the ground to shake and can bring down buildings and other structures.',
#        'shaking can also lead to landslides and trigger volcanic activity.',
#        "earthquakes are usually the result of energy being released in the earth's crust.",
#        'earthquakes at sea can generate tsunamis by displacing the ocean floor.',
#        'elephants are the largest terrestrial mammals which can weigh many tons.',
#        'an elephant has a trunk which is its long nose that can pick up things.',
#        'elephants have tusks made of ivory which they use to move objects or dig in trees.',
#        'to cool the blood in their large ears and bodies elephants flap their ears.',
#        'the eye is responsible for detecting light and transmitting it to the visual cortex.',
#        'animals often have complex eyes that can recognize color motion and texture.',
#        'the fovea is the center of the eye and the most sensitive part in humans.',
#        'compound eyes consisting of eye units facing multiple directions are present in insects.',
#        'land used to cultivate plants or rear animals for food is known as a farm.',
#        'farmers are responsible for running the farm and determining what crops to produce.',
#        'a farm typically includes a residence for farmers a silo and a barn.',
#        'many farmers who share the land and equipment operate a cooperative.',
#        'each hand of primates usually has four fingers and a thumb.',
#        'fingers are employed for activities such as grasping writing grooming and such.',
#        'the fingertips possess sensitivity to temperature pressure and vibration.',
#        'the finger tip is protected by the nail which can be grown or decorated.',
#        'when water overflows and submerges inhabited land it is referred to as a flood.',
#        'flooding is often the result of intense precipitation a fast-melting snowpack or earthquakes at sea.',
#        'a river can flood by flowing out of its channel or breaking dams and levees.',
#        'people usually evacuate during a flood and the water can spread diseases.',
#        'a floor is a horizontal surface inside a building meant for walking.',
#        'different materials used for flooring include concrete tile linoleum or wooden floorboards.',
#        'carpets are a popular addition to floors as they offer comfort and soundproofing.',
#        'pipes and electrical wiring are often located under the floor in buildings.',
#        'a foot is the body part located at the end of a leg.',
#        'the feet are utilized for walking running and standing straight.',
#        'the feet can be used for kicking both in athletic and martial contexts.',
#        'in some cultures there are regulations on foot-related behavior.',
#        'a dense collection of trees with a significant amount of canopy coverage characterizes a forest.',
#        'forest classification is determined by the climatic conditions such as temperature and rainfall.',
#        'forests are home to different trees and animals as well as plants growing on the ground.',
#        'trees are cleared indiscriminately without regard for replenishment in deforestation.',
#        'a fork is an eating utensil with a handle and several prongs for spearing food.',
#        'forks are frequently constructed of metal or disposable plastic.',
#        'forks are employed to elevate food to the mouth or as a holder while cutting food.',
#        'forks are a typical utensil in western cultures with specific designs for different foods.',
#        'a frying pan is characterized by its shallow design sloping sides and handle.',
#        'food can be fried seared and browned in a frying pan.',
#        'the food is cooked on the bottom of the pan which is covered in oil.',
#        'frying pans can be made from iron or steel covered in teflon.',
#        'a girl is a young female human who has not reached adulthood.',
#        "the change from a girl's body to a woman's body occurs during puberty.",
#        'dolls and social games are often liked by girls.',
#        'girls may grow their hair long and wear dresses and skirts.',
#        'a glove is a type of clothing that covers the hand and fingers.',
#        'wool or waterproof lined gloves are made to keep hands warm.',
#        'disposable gloves made of rubber or latex are utilized to guard against germs or chemicals.',
#        'a mitten is a type of glove where all four fingers are enclosed together.',
#        'a hammer is a tool utilized to apply force to an object.',
#        'driving nails into wood is a common use for a hammer.',
#        'the claw on the head is useful for removing nails.',
#        'the shape of the head and handle length differentiate hammers from one another.',
#        'an explosive used as a weapon against individuals is known as a hand grenade.',
#        'hand grenades are tossed and timed to detonate shortly thereafter.',
#        'grenades can also be launched from rifles or shoulder-mounted launchers.',
#        'tear gas grenades are thrown into the center of a group to cause it to scatter.',
#        'a horse is a large mammal with four long powerful legs and hooves.',
#        'horses are typically brown or gray and have a mane and tail on their neck.',
#        'horses have been utilized for purposes such as draft work transportation and recreation.',
#        'a person can sit on a horse as it walks trots or gallops.',
#        'people visit hospitals to receive treatment for illness or injury.',
#        'hospitals are staffed by doctors surgeons and nurses who are professionals.',
#        'certain patients visit the place to receive specialized diagnosis or treatment and depart the same day.',
#        'some operations or treatments require patients to stay there for several weeks.',
#        'a house is a building or structure meant for permanent living quarters for individuals or families.',
#        'the walls and roof of a house serve to protect from rain and cold with windows to let in light.',
#        'a residence has various rooms for activities like cooking sleeping and washing.',
#        'people usually go to work outside the home and come back in the evenings to eat and sleep.',
#        'an igloo is a domicile made from blocks of snow by the inuit people.',
#        'igloos are typically built in areas where snow covers the ground for most of the time.',
#        'the shape of an igloo is typically that of a dome with an entrance through a tunnel.',
#        "snow's air pockets provide insulation and warmth inside the igloo is generated by body heat.",
#        'a tool with a sharp edge for cutting objects is referred to as a knife.',
#        'modern knives typically feature a handle and a blade made of metal.',
#        'knives have been employed both as weapons and in rituals as instruments.',
#        'attacking with a knife can be done by stabbing tossing or slashing.',
#        'lentils are the seeds of a plant belonging to the legume family.',
#        'lentils come in various colors including red green brown black and yellow.',
#        'lentils are a common ingredient in indian and mediterranean cuisine.',
#        'lentils are a nutritious source of protein and are prepared by boiling them.',
#        'a biennial plant often grown as a leaf vegetable in temperate climates is lettuce.',
#        'lettuce can either be eaten uncooked and cold in dishes like salads or it can be cooked.',
#        'growing lettuce is considered relatively simple making it a great choice for beginner gardeners.',
#        'although the majority of lettuce leaves are bitter some varieties have been developed without bitterness.',
#        'a collection of books documents and various forms of media are stored in a library.',
#        'librarians are employees of libraries and are knowledgeable about locating and organizing information.',
#        'public libraries allow patrons to take books home for several weeks after borrowing them.',
#        'specialized books can be found at academic libraries which support scholarly research.',
#        'a log cabin is a compact dwelling constructed using round logs.',
#        'the log cabin is considered a hallmark of the american frontier experience.',
#        'the first shelters for european settlers in america were log cabins.',
#        'log cabins were constructed using logs that were joined at the ends using notch joints.',
#        'a man is a mature male human.',
#        'the transition from boy to man occurs after puberty.',
#        'masculinity and virility are characteristic of manhood.',
#        'height weight and body structure differ between men and women.',
#        'milk is a fluid secreted by female mammals to nourish their young.',
#        'young animals need to be nursed with milk until they can consume solid food.',
#        'cheese and butter are dairy products that are made using milk.',
#        'a liquid produced from soybeans and coconuts is sometimes referred to as milk.',
#        'mosquitos are tiny slender flying insects that produce a shrill sound.',
#        'mouthparts on mosquitoes enable them to penetrate the skin of plants and animals.',
#        'female mosquitoes feed on the blood of people and animals by biting them.',
#        'yellow fever malaria and other parasitic diseases can be transmitted by mosquito bites.',
#        'a mountain is a terrain feature that rises abruptly from the surrounding lands.',
#        'high-rising landforms that sometimes have snow on their peaks are known as mountains.',
#        'tectonic plates colliding results in a chain of mountains being formed.',
#        'mountaineers are adventurous individuals who engage in ascending mountains.',
#        'the mouth is the entrance to the digestive system where food is consumed.',
#        'the mouth is equipped with teeth for breaking down food by chewing.',
#        'talking and kissing are also performed using the mouth.',
#        'the position of the tongue inside the mouth determines the speech sounds.',
#        'a mug is a sturdy drinking cup with a handle for hot liquids.',
#        'a mug can be crafted from ceramics or it may be comprised of metal or glass.',
#        'a mug is designed to be thick with a circular base for efficient heat insulation.',
#        'a mug may have drawings imprinted or carved onto its surface or be left plain.',
#        'murder is defined as the intentional killing of a human being.',
#        'murder is considered a serious crime because it denies the victim the right to life.',
#        'killing occurring in self-defense unintentionally or in war are not regarded as murder.',
#        'convicted murderers are often given a sentence of life in prison or the death penalty.',
#        'orange juice is a beverage made from the juice extracted from oranges.',
#        'orange juice is characterized by its sweet and acidic flavor and is also packed with vitamin c.',
#        'fresh orange juice often includes bits of pulp.',
#        'orange juice is frequently consumed from a glass especially at breakfast time.',
#        'parrots are birds that are commonly found in warm and tropical areas.',
#        'parrots are known for their brightly colored feathers and hooked beaks.',
#        'if parrots are exposed to human voices frequently they can mimic them.',
#        'their unique appearance and abilities make parrots popular as pets.',
#        'a peach is a fruit with orange-yellow color and a distinctive aroma.',
#        'the surface of a peach is fragile and covered in delicate minute hairs.',
#        'the heart of a peach has a large brownish-red seed-containing stone.',
#        'peaches must be harvested after they have become sweet and delicate through ripening.',
#        'the piano is a commonly used musical instrument operated by a keyboard.',
#        'when a piano key is pressed a hammer tipped with felt strikes a vibrating steel string.',
#        'the piano has a vast range of notes and pedals to alter the tone.',
#        'because of the rich piano repertoire famous pianists can give solo concerts.',
#        'piranhas are vicious small fish found in rivers of south america.',
#        'piranhas hunt and attack in groups and they are most energetic during daylight hours.',
#        'piranhas have incredibly sharp teeth and are opportunistic meat-eaters.',
#        'piranhas feed on fish insects reptiles mammals and carrion.',
#        'raspberries grow in forest clearings or in fields and are a type of fruit.',
#        'one raspberry is formed by the joining of many small fruits.',
#        'raspberries can be consumed plain or used to make sweet sugary jam.',
#        'fresh or dried raspberry leaves can be used to make herbal teas.',
#        'a raven is a large black bird that thrives in various climates.',
#        'ravens feed on dead animals insects small creatures or fruit.',
#        'ravens have impressive cognitive abilities and can solve problems.',
#        'in folklore ravens are often associated with misfortune and cunning.',
#        'a refrigerator is utilized to keep food fresh and its temperature regulated.',
#        'some refrigerators come with a small compartment that maintains a freezing temperature.',
#        'a refrigerator may have shelves and small compartments to store different types of food.',
#        'refrigerators are generally white and people often place magnets on their surface.',
#        'a shoulder-supported firearm with a barrel featuring spiral grooves is referred to as a rifle.',
#        'the grooves on the rifle cause the bullets to rotate around its axis while in flight.',
#        'hunting and shooting sports often utilize rifles sometimes with the aid of scopes.',
#        'standard infantry weapons are the assault rifles which can fire in short bursts.',
#        'the salmon fish species migrates from freshwater to the ocean to reproduce and then returns.',
#        'salmon flesh with its high protein content and good taste is either orange or red.',
#        'salmon can be consumed raw in sushi or prepared by cooking methods such as grilling or poaching.',
#        'the most frequently farmed fish is salmon though it can also be caught in the wild.',
#        'the saw is a tool that cuts through tough materials using a hard blade or abrasive wire.',
#        "the tiny pointed blades along the cutting edge of the saw are known as the saw's teeth.",
#        'saws can be operated manually or with the help of an electrical motor or gasoline engine.',
#        'saws are commonly used in the fields of construction forestry carpentry and medicine.',
#        "a scientist's work involves discovering new information about the physical world.",
#        'scientists develop theories and conduct experiments to verify them.',
#        'physics chemistry and biology are well-known fields of science.',
#        'scientists publish their findings in academic journals and conferences.',
#        'scissors are a cutting tool consisting of two blades.',
#        'they typically have metal blades and plastic or metal handles.',
#        'depending on the type and design scissors can be used to cut paper hair or cloth.',
#        'large scissors known as shears are used for cutting shrubs or metal.',
#        'a screwdriver is a tool used for inserting screws and tightening them.',
#        'the screwdriver can be used to both insert and remove screws.',
#        "the screwdriver's tip transmits the rotational force from the handle.",
#        'phillips and flathead are the two primary types of screwdrivers.',
#        'sharks are large fish that have skeletons made of cartilage.',
#        'sharks have a sleek body with a large dorsal fin on top.',
#        'a majority of sharks hunt for fish and mammals utilizing their strong jaws.',
#        'sharks possess highly developed senses and can detect electrical signals.',
#        'a ship is a massive vehicle designed to float on water.',
#        'a ship can be propelled through the ocean by either sails steam or diesel engines.',
#        'ships are utilized for fishing in the ocean and for carrying cargo containers.',
#        'cruise ships are large floating hotels that transport passengers between cities.',
#        'footwear consisting of a sole outsole and heel is known as a shoe.',
#        'the materials used for shoes can include leather canvas rubber and plastic.',
#        'female shoes may have high heels and are available in various styles and colors.',
#        'sneakers are shoes made for athletic activities and sports.',
#        'a member of the military who engages in land-based combat is known as a soldier.',
#        'militiamen are usually required to wear a uniform often with camouflage.',
#        'in a volunteer military soldiers are compensated for their services.',
#        'in combat soldiers employ weapons such as rifles and grenades.',
#        'spears are composed of a long pole with a sharp head at one end.',
#        'the spear was the weapon of choice for individuals before firearms came about.',
#        'in war the spear was utilized for both stabbing and throwing.',
#        'some indigenous communities still use spears for fishing and hunting.',
#        'insects that have eight legs and make silk are called spiders.',
#        'webs are constructed by spiders using silk to trap insects.',
#        'their prey is paralyzed by spiders using venomous fangs.',
#        'the size of spiders can range from tiny like a coin to big like a bird.',
#        'swamps are inundated lowlands with spongy soil.',
#        'a swamp is characterized by shallow water mud and vegetation.',
#        'swamps serve as nesting and breeding grounds for birds and reptiles.',
#        'swamps are often transformed into arable land by draining them.',
#        'a garment worn for warmth on the torso is called a sweater.',
#        'wool and cotton are both materials used to make sweaters.',
#        'a cardigan is a type of sweater that opens in the front.',
#        'sweaters can differ in terms of cut collar sleeve shape and decoration.',
#        'a table is a piece of furniture with a flat surface and supporting legs.',
#        'chairs are often placed near tables for individuals to sit.',
#        'dining utensils dishes and food are placed on a table for group meals.',
#        'a table can be used as a writing or work surface.',
#        'a television is a device with a screen that shows moving images.',
#        'televisions are primarily used to watch movies or programs.',
#        'when connected to a game console televisions can be used to play video games.',
#        'television content can be broadcast or transmitted via cable or the internet.',
#        "theft is the act of taking someone's property without their permission.",
#        "burglars take what doesn't belong to them for personal gain or for reselling.",
#        'stealing is a criminal act that can lead to jail time or fines.',
#        'industrial espionage involves the thievery of intellectual property and concepts.',
#        'bread can be toasted using a kitchen appliance known as a toaster.',
#        'toast made using a pop-up toaster toasts bread in a slot and ejects it when done.',
#        'toaster ovens have temperature regulation a door on the side and a tray within.',
#        'they enable the preparation of bread with toppings such as garlic or cheese.',
#        'the tomato is a shiny smooth and red fruit that has a savory taste.',
#        'as a tomato becomes more mature it changes color from green to red and becomes softer.',
#        'tomatoes can be made into salads soup ketchup or used as a sauce.',
#        'with various sizes and flavors there are many varieties of tomatoes.',
#        'a train is a series of rail vehicles that run on a track between stations.',
#        'the locomotive powered by either diesel or electricity pulls the train.',
#        'a freight train carries containers of goods and fuel over long distances.',
#        'commuter trains are trains that move people between suburban locations and city stations.',
#        'a train station is a location where individuals get on or off a train.',
#        'train stations offer ticket counters or vending machines for ticket purchase.',
#        'a station comprises waiting areas and dining facilities.',
#        'passengers or cargo trains arrive at a platform alongside the tracks.',
#        'tropical cyclones are storms that arise over warm tropical oceans.',
#        'tropical cyclones are known for their strong winds and heavy rainfall.',
#        'coastal flooding and high waves can be caused by tropical cyclones.',
#        'a tropical cyclone that moves inland can cause significant damage to property.',
#        'the violin is a stringed instrument that is played using a bow.',
#        'the violin is the smallest and possesses the highest pitch in its family.',
#        'the violin is positioned between the chin and collarbone by the violinist.',
#        'one hand is used to finger the neck while bowing thus producing different notes.',
#        'vultures are birds that primarily feed on dead animal carcasses.',
#        'the heads of many vultures are bald without feathers to prevent overheating.',
#        'large wings allow vultures to soar for miles without flapping.',
#        'while healthy animals are usually safe vultures may kill wounded or sick animals.',
#        'a wall is a sturdy structure that outlines and sometimes safeguards an area.',
#        'the building is defined by its walls which also support the roof and separate rooms.',
#        'walls are typically constructed from materials such as stone brick cement or drywall.',
#        'retaining walls obstruct the motion of earth stone or water.',
#        'water the most abundant liquid on earth covers 70% of its surface.',
#        'without access to water plants animals and humans cannot survive.',
#        'water becomes solid ice when it freezes at a low temperature.',
#        'the formation of rain occurs when water vapor in the clouds condenses into liquid form.',
#        'the ocean is the habitat of whales which are very large mammals.',
#        'whales use blowholes located on their heads to breathe when they surface.',
#        'the blubber on a whale functions as both a source of energy and insulation.',
#        'hunting of whales has taken place for their meat whale oil and ambergris.',
#        'a window is a see-through opening in a wall that allows light to enter.',
#        'a standard window typically consists of glass panels held in place by a frame.',
#        'when opened a window will also admit air and sounds from the outside.',
#        'multiple glass panes in a window can improve insulation within a building.',
#        'a woman is a female human who has reached adulthood.',
#        'women are often depicted as caretakers in society.',
#        'women are capable of pregnancy and delivering offspring.',
#        'the reproductive systems of women differ from those of men.'],
#       dtype=object)

# %%
os.chdir('/om/user/gretatu/perturbed-neural-nlp/standalone_scripts/stimuli_creation/')

# %%
# os.mkdir('chatGPT_stimuli_dfs')

# %%
save = True

# %%
os.getcwd()
# Out:
# '/om/user/gretatu/perturbed-neural-nlp/standalone_scripts/stimuli_creation'

# %%
if save:
    fname = f"chatGPT_stimuli_dfs/stimuli_chatGPT.pkl"
    with open(fname, 'wb') as fout:
        pickle.dump(stimuli_df_copy, fout)
