# %% [markdown]
# # Script for creating word-order manipulation datasets from the Pereira2018 fMRI stimuli

# %%
import re
from pathlib import Path
from os.path import abspath
import os
import numpy as np
import random
import pickle
import csv
import subprocess

# %%
print(os.getcwd())
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/perturbed-neural-nlp/ressources/stimuli_creation

# %%
importpath = abspath('../..')
os.chdir(importpath)
print(os.getcwd())
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/perturbed-neural-nlp

# %%
#add seeds for reproducability
np.random.seed(42)
random.seed(42)

# %% [markdown]
# # Load base stimulus dataframe (Pereira 2018)

# %%
from neural_nlp.benchmarks.neural import *
import neural_nlp
from neural_nlp.stimuli import StimulusSet
import xarray as xr

benchmark_pool = [
    # primary benchmarks
    ('Pereira2018-encoding', PereiraEncoding),
]
benchmark_pool = {identifier: LazyLoad(lambda identifier=identifier, ctr=ctr: ctr(identifier=identifier))
                  for identifier, ctr in benchmark_pool}

# fetch stimulus set
benchmark = benchmark_pool['Pereira2018-encoding']
stimuli_df = benchmark._target_assembly.attrs['stimulus_set']
stimuli_df
# Out:
# Loading lookup from /om2/user/ckauf/anaconda/envs/perturbedenv/lib/python3.6/site-packages/brainio_collection/lookup.csv
# /rdma/vast-rdma/vast/cpl/ckauf/perturbed-neural-nlp/neural_nlp/../ressources/stimuli
#
#
#  We're running in the NEW version of the implementations.py script.
# /om2/user/ckauf/anaconda/envs/perturbedenv/lib/python3.6/site-packages/brainio_base/assemblies.py:224: FutureWarning: The inplace argument has been deprecated and will be removed in a future version of xarray.
#   xr_data.set_index(append=True, inplace=True, **coords_d)
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture, it does not ...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                   A woman is a female human adult.           380
# 624    A woman is stereotypically seen as a caregiver.           381
# 625     A woman can become pregnant and bear children.           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
# [627 rows x 8 columns]

# %%
# benchmark content
benchmark._target_assembly.values.shape
benchmark._target_assembly.coords
# Out:
# Coordinates:
#   * presentation      (presentation) MultiIndex
#   - stimulus_num      (presentation) int64 0 0 1 1 2 2 3 ... 12 12 13 13 14 14
#   - passage_index     (presentation) int64 1 1 1 1 1 1 1 1 2 ... 3 4 4 4 4 4 4 4
#   - passage_label     (presentation) object 'Accordion' ... 'dreams'
#   - passage_category  (presentation) object 'music' 'beekeeping' ... 'dreams'
#   - stimulus_id       (presentation) object '384sentences.0' ... '243sentences.14'
#   - story             (presentation) object '384sentences.music' ... '243sentences.dreams'
#   - experiment        (presentation) object '384sentences' ... '243sentences'
#   * neuroid           (neuroid) MultiIndex
#   - subject           (neuroid) object '018' '018' '018' ... '018' '018' '018'
#   - voxel_num         (neuroid) int64 28 29 31 32 38 42 ... 152 153 154 159 160
#   - atlas             (neuroid) object 'language' 'language' ... 'language'
#   - filter_strategy   (neuroid) object '' '' '' '' '' '' ... '' '' '' '' '' ''
#   - atlas_selection   (neuroid) object 'from90to100prcnt' ... 'from90to100prcnt'
#   - roi               (neuroid) object 'LH_AntTemp' ... 'LH_AntTemp'
#   - indices_in_3d     (neuroid) int64 72505 72506 72584 ... 87754 87831 87832
#   - col_to_coord_1    (neuroid) int64 62 63 62 63 63 63 63 ... 65 62 63 64 62 63
#   - col_to_coord_2    (neuroid) int64 63 63 64 64 65 66 63 ... 65 66 66 66 67 67
#   - col_to_coord_3    (neuroid) int64 10 10 10 10 10 10 11 ... 12 12 12 12 12 12
#   - neuroid_id        (neuroid) object '018.28' '018.29' ... '018.159' '018.160'

# %% [markdown]
# # Create different perturbed versions of the benchmark

# %%
stimuli_path = os.path.join(os.getcwd(),'ressources/stimuli_creation')
os.chdir(stimuli_path)
print(os.getcwd())

savedir = abspath('../scrambled_stimuli_dfs')
print(savedir)
os.makedirs(savedir, exist_ok=True)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/perturbed-neural-nlp/ressources/stimuli_creation
# /rdma/vast-rdma/vast/cpl/ckauf/perturbed-neural-nlp/ressources/scrambled_stimuli_dfs

# %% [markdown]
# # Scrambling | Mollica et al. (2020)

# %% [markdown]
# ## 1. Create stable PMI scrambled dataset versions (Mollica et al. 2020)

# %% [markdown]
# `The below cell calls a python script with input stimuli files already hardcoded!`

# %%
! python permute_sentences.py
# Out:
# stim_243sentences
# 0	beekeeping encourages the conservation of local habitats
# 1	beekeeping encourages the conservation of habitats local
# 2	encourages beekeeping the conservation of habitats local
# 3	beekeeping conservation encourages the of habitats local
# 4	conservation beekeeping encourages the of habitats local
# 5	conservation beekeeping encourages the habitats of local
# 6	conservation encourages beekeeping of the habitats local
# 7	beekeeping conservation of encourages habitats local the
# 0	it is in every beekeeper's interest to conserve local plants that produce pollen
# 1	it is in every beekeeper's interest to conserve local plants produce that pollen
# 2	it in is every beekeeper's interest to conserve local plants produce that pollen
# 3	in it is every beekeeper's interest to conserve local plants produce that pollen
# 4	in it is every beekeeper's interest to conserve local plants produce pollen that
# 5	in it is every interest beekeeper's to conserve local plants produce pollen that
# 6	in it is interest every beekeeper's to conserve local plants produce pollen that
# 7	in every it is interest beekeeper's to conserve plants local that pollen produce
# 0	as a passive form of agriculture it does not require that native vegetation be cleared to make way for crops
# 1	as a passive of form agriculture it does not require that native vegetation be cleared to make way for crops
# 2	a as passive of form agriculture it does not require that native vegetation be cleared to make way for crops
# 3	a as passive of form agriculture it does require not that native vegetation be cleared to make way for crops
# 4	a as passive of form agriculture it require does not that native vegetation be cleared to make way for crops
# 5	a as passive agriculture of form it does require not that native vegetation be cleared to make way for crops
# 6	a as passive agriculture of form it does require not that native vegetation be cleared to make for way crops
# 7	a as agriculture passive of form it does require not that native vegetation be cleared to make for way crops
# 0	beekeepers also discourage the use of pesticides on crops because they could kill the honeybees
# 1	beekeepers also discourage the use of pesticides on crops because could they kill the honeybees
# 2	beekeepers discourage also the use of pesticides on crops because could they kill the honeybees
# 3	discourage beekeepers also the use of pesticides on crops because could they kill the honeybees
# 4	discourage beekeepers also the use of pesticides on crops because could kill they the honeybees
# 5	discourage beekeepers also the of use pesticides on crops because could kill they the honeybees
# 6	discourage beekeepers also of the use pesticides on crops because could kill they the honeybees
# 7	discourage the beekeepers also of use pesticides on because crops they kill could the honeybees
# 0	artisanal beekeepers go to extremes for their craft but their product is worth the effort
# 1	artisanal beekeepers go to extremes for their craft but their is product worth the effort
# 2	artisanal go beekeepers to extremes for their craft but their is product worth the effort
# 3	go artisanal beekeepers to extremes for their craft but their is product worth the effort
# 4	go artisanal beekeepers to extremes for their craft but their is worth product the effort
# 5	go artisanal beekeepers to for extremes their craft but their is worth product the effort
# 6	go artisanal beekeepers for to extremes their craft but their is worth product the effort
# 7	go to artisanal beekeepers for extremes their craft their but product worth is the effort
# 0	artisanal honey-making emphasizes quality and character over quantity and consistency
# 1	artisanal emphasizes honey-making quality and character over quantity and consistency
# 2	emphasizes artisanal honey-making quality and character over quantity and consistency
# 3	emphasizes artisanal honey-making quality character and over quantity and consistency
# 4	emphasizes artisanal honey-making character quality and over quantity and consistency
# 5	emphasizes quality artisanal honey-making character and over quantity and consistency
# 6	emphasizes quality artisanal honey-making character and over quantity consistency and
# 7	emphasizes quality artisanal honey-making character and quantity over consistency and
# 0	to produce the finest honey beekeepers become micromanagers of their honeybees
# 1	to the produce finest honey beekeepers become micromanagers of their honeybees
# 2	the to produce finest honey beekeepers become micromanagers of their honeybees
# 3	the to produce finest beekeepers honey become micromanagers of their honeybees
# 4	the to produce beekeepers finest honey become micromanagers of their honeybees
# 5	the finest to produce beekeepers honey become micromanagers of their honeybees
# 6	the finest to produce beekeepers honey become micromanagers their of honeybees
# 7	the to finest produce beekeepers honey micromanagers become their honeybees of
# 0	they scout the fields know when nectar flows and select the best ways to extract honey
# 1	they scout the fields know when nectar flows and select best the ways to extract honey
# 2	they the scout fields know when nectar flows and select best the ways to extract honey
# 3	the they scout fields know when nectar flows and select best the ways to extract honey
# 4	the they scout fields know when nectar flows and select best ways the to extract honey
# 5	the they scout fields when know nectar flows and select best ways the to extract honey
# 6	the they scout when fields know nectar flows and select best ways the to extract honey
# 7	the fields they scout when know nectar flows and select the ways best to honey extract
# 0	as the beekeeper opens the hive the deep hum of 40000 bees fills the air
# 1	as the beekeeper opens the hive the deep hum of bees 40000 fills the air
# 2	as beekeeper the opens the hive the deep hum of bees 40000 fills the air
# 3	beekeeper as the opens the hive the deep hum of bees 40000 fills the air
# 4	beekeeper as the opens the hive the deep hum of bees fills 40000 the air
# 5	beekeeper as the opens hive the the deep hum of bees fills 40000 the air
# 6	beekeeper as the hive opens the the deep hum of bees fills 40000 the air
# 7	beekeeper opens as the hive the the deep of hum 40000 fills bees the air
# 0	the beekeeper checks honey stores pollen supplies and the bee nursery
# 1	the checks beekeeper honey stores pollen supplies and the bee nursery
# 2	checks the beekeeper honey stores pollen supplies and the bee nursery
# 3	checks the beekeeper honey pollen stores supplies and the bee nursery
# 4	checks the beekeeper pollen honey stores supplies and the bee nursery
# 5	checks honey the beekeeper pollen stores supplies and the bee nursery
# 6	checks honey the beekeeper pollen stores supplies and bee the nursery
# 7	checks the honey beekeeper pollen stores and supplies bee nursery the
# 0	bees crawl across his bare arms and hands but they don't sting because they're gentle
# 1	bees crawl across his bare arms and hands but they sting don't because they're gentle
# 2	bees across crawl his bare arms and hands but they sting don't because they're gentle
# 3	across bees crawl his bare arms and hands but they sting don't because they're gentle
# 4	across bees crawl his bare arms and hands but they sting because don't they're gentle
# 5	across bees crawl his arms bare and hands but they sting because don't they're gentle
# 6	across bees crawl arms his bare and hands but they sting because don't they're gentle
# 7	across his bees crawl arms bare and hands they but don't because sting they're gentle
# 0	i have a recurring dream about exams even though i'm no longer in college
# 1	i have a recurring dream about exams even though i'm longer no in college
# 2	i a have recurring dream about exams even though i'm longer no in college
# 3	a i have recurring dream about exams even though i'm longer no in college
# 4	a i have recurring dream about exams even though i'm longer in no college
# 5	a i have recurring about dream exams even though i'm longer in no college
# 6	a i have about recurring dream exams even though i'm longer in no college
# 7	a recurring i have about dream exams even i'm though no in longer college
# 0	in my dream it's the day of my final exam and i suddenly realize i've never gone to class
# 1	in my dream the it's day of my final exam and i suddenly realize i've never gone to class
# 2	my in dream the it's day of my final exam and i suddenly realize i've never gone to class
# 3	my in dream the it's day of my exam final and i suddenly realize i've never gone to class
# 4	my in dream the it's day of exam my final and i suddenly realize i've never gone to class
# 5	my in dream day the it's of my exam final and i suddenly realize i've never gone to class
# 6	my in dream day the it's of my exam final and i suddenly realize i've never gone class to
# 7	my in day dream the it's of my exam final and i suddenly realize i've never gone class to
# 0	i've never even done any of the reading assignments
# 1	i've even never done any of the reading assignments
# 2	even i've never done any of the reading assignments
# 3	even i've never done of any the reading assignments
# 4	even i've never of done any the reading assignments
# 5	even done i've never of any the reading assignments
# 6	even done i've never of any reading the assignments
# 7	even done i've of never any reading the assignments
# 0	i know many other people who have the same nightmare
# 1	i many know other people who have the same nightmare
# 2	many i know other people who have the same nightmare
# 3	many i know other who people have the same nightmare
# 4	many i know who other people have the same nightmare
# 5	many other i know who people have the same nightmare
# 6	many other i know who people have the nightmare same
# 7	many other i know who people the have nightmare same
# 0	each morning participants in the study had to write down their dream experience from the previous night
# 1	each morning participants the in study had to write down their dream experience from the previous night
# 2	morning each participants the in study had to write down their dream experience from the previous night
# 3	morning each participants the in study had to down write their dream experience from the previous night
# 4	morning each participants the in study had down to write their dream experience from the previous night
# 5	morning each participants study the in had to down write their dream experience from the previous night
# 6	morning each study participants the in had to down write their dream experience from the previous night
# 7	morning each study participants the in had to down write their dream experience the from previous night
# 0	they recorded if they recalled any dreams and described each dream and its emotional intensity
# 1	they recorded if they recalled any dreams and described each and dream its emotional intensity
# 2	they if recorded they recalled any dreams and described each and dream its emotional intensity
# 3	if they recorded they recalled any dreams and described each and dream its emotional intensity
# 4	if they recorded they recalled any dreams and described each and its dream emotional intensity
# 5	if they recorded they any recalled dreams and described each and its dream emotional intensity
# 6	if they recorded any they recalled dreams and described each and its dream emotional intensity
# 7	if they they recorded any recalled dreams and each described dream its and emotional intensity
# 0	participants then assigned each dream to a category such as a flying dream a bad dream or a nightmare
# 1	participants then assigned dream each to a category such as a flying dream a bad dream or a nightmare
# 2	then participants assigned dream each to a category such as a flying dream a bad dream or a nightmare
# 3	then participants assigned dream each to a category as such a flying dream a bad dream or a nightmare
# 4	then participants assigned dream each to a as category such a flying dream a bad dream or a nightmare
# 5	then participants assigned to dream each a category as such a flying dream a bad dream or a nightmare
# 6	then participants assigned to dream each a category as such a flying dream a bad dream or nightmare a
# 7	then participants to assigned dream each a category as such a flying dream a bad dream or nightmare a
# 0	every night while we sleep our minds are as active as when we are awake
# 1	every night while we sleep our minds are as active when as we are awake
# 2	every while night we sleep our minds are as active when as we are awake
# 3	while every night we sleep our minds are as active when as we are awake
# 4	while every night we sleep our minds are as active when we as are awake
# 5	while every night we our sleep minds are as active when we as are awake
# 6	while every night our we sleep minds are as active when we as are awake
# 7	while we every night our sleep minds are active as as we when are awake
# 0	we dream throughout the night in cycles of about ninety minutes each
# 1	we dream throughout the night in cycles of about ninety each minutes
# 2	we throughout dream the night in cycles of about ninety each minutes
# 3	throughout we dream the night in cycles of about ninety each minutes
# 4	throughout we dream the in night cycles of about ninety each minutes
# 5	throughout we dream in the night cycles of about ninety each minutes
# 6	throughout the we dream in night cycles of about ninety each minutes
# 7	throughout we the dream in night of cycles ninety minutes about each
# 0	images feelings stories and strange combinations of characters and places can fill our dreams
# 1	images feelings stories and strange combinations of characters and places fill can our dreams
# 2	images stories feelings and strange combinations of characters and places fill can our dreams
# 3	stories images feelings and strange combinations of characters and places fill can our dreams
# 4	stories images feelings and strange combinations of characters and places fill our can dreams
# 5	stories images feelings and combinations strange of characters and places fill our can dreams
# 6	stories images feelings combinations and strange of characters and places fill our can dreams
# 7	stories and images feelings combinations strange of characters places and can our fill dreams
# 0	when i decided to start playing cards things went from bad to worse
# 1	when i decided to start playing cards things went from to bad worse
# 2	when decided i to start playing cards things went from to bad worse
# 3	decided when i to start playing cards things went from to bad worse
# 4	decided when i to start playing cards things went from to worse bad
# 5	decided when i to playing start cards things went from to worse bad
# 6	decided when i playing to start cards things went from to worse bad
# 7	decided to when i playing start cards things from went bad worse to
# 0	gambling was something i had to do and i had already spent close to $10000 doing it
# 1	gambling was something had i to do and i had already spent close to $10000 doing it
# 2	was gambling something had i to do and i had already spent close to $10000 doing it
# 3	was gambling something had i to do and had i already spent close to $10000 doing it
# 4	was gambling something had i to do had and i already spent close to $10000 doing it
# 5	was gambling something to had i do and had i already spent close to $10000 doing it
# 6	was gambling to something had i do and had i already spent close to $10000 doing it
# 7	was gambling to something had i do and had i already spent close $10000 to doing it
# 0	my friends were sick of watching me gamble my savings away
# 1	my were friends sick of watching me gamble my savings away
# 2	were my friends sick of watching me gamble my savings away
# 3	were my friends sick watching of me gamble my savings away
# 4	were my friends watching sick of me gamble my savings away
# 5	were sick my friends watching of me gamble my savings away
# 6	were sick my friends watching of me gamble savings my away
# 7	were my sick friends watching of gamble me savings away my
# 0	the hardest part was the horror of leaving a casino after losing money i did not have
# 1	the hardest part the was horror of leaving a casino after losing money i did not have
# 2	hardest the part the was horror of leaving a casino after losing money i did not have
# 3	hardest the part the was horror of leaving casino a after losing money i did not have
# 4	hardest the part the was horror of casino leaving a after losing money i did not have
# 5	hardest the part horror the was of leaving casino a after losing money i did not have
# 6	hardest the horror part the was of leaving casino a after losing money i did not have
# 7	hardest the horror part the was of leaving casino a after losing money did i not have
# 0	good data on the social and economic effects of legalized gambling are hard to come by
# 1	good data on the social and economic effects of legalized are gambling hard to come by
# 2	good on data the social and economic effects of legalized are gambling hard to come by
# 3	on good data the social and economic effects of legalized are gambling hard to come by
# 4	on good data the social and economic effects of legalized are hard gambling to come by
# 5	on good data the and social economic effects of legalized are hard gambling to come by
# 6	on good data and the social economic effects of legalized are hard gambling to come by
# 7	on the good data and social economic effects of legalized gambling hard are to by come
# 0	some studies indicate that having a casino nearby makes gambling problems more likely
# 1	some studies indicate that having a casino nearby makes gambling more problems likely
# 2	some indicate studies that having a casino nearby makes gambling more problems likely
# 3	indicate some studies that having a casino nearby makes gambling more problems likely
# 4	indicate some studies that having a casino nearby makes gambling more likely problems
# 5	indicate some studies that a having casino nearby makes gambling more likely problems
# 6	indicate some studies a that having casino nearby makes gambling more likely problems
# 7	indicate that some studies a having casino nearby gambling makes problems likely more
# 0	gambling may also be associated with personal bankruptcies and marriage problems
# 1	gambling also may be associated with personal bankruptcies and marriage problems
# 2	also gambling may be associated with personal bankruptcies and marriage problems
# 3	also gambling may be with associated personal bankruptcies and marriage problems
# 4	also gambling may with be associated personal bankruptcies and marriage problems
# 5	also be gambling may with associated personal bankruptcies and marriage problems
# 6	also be gambling may with associated personal bankruptcies marriage and problems
# 7	also gambling be may with associated bankruptcies personal marriage problems and
# 0	over the past generation there has been a dramatic expansion of legalized gambling
# 1	over the past generation there has been a dramatic expansion legalized of gambling
# 2	over past the generation there has been a dramatic expansion legalized of gambling
# 3	past over the generation there has been a dramatic expansion legalized of gambling
# 4	past over the generation there has been a dramatic expansion legalized gambling of
# 5	past over the generation has there been a dramatic expansion legalized gambling of
# 6	past over the has generation there been a dramatic expansion legalized gambling of
# 7	past generation over the has there been a expansion dramatic of gambling legalized
# 0	most states have instituted lotteries and many have casinos as well
# 1	most have states instituted lotteries and many have casinos as well
# 2	have most states instituted lotteries and many have casinos as well
# 3	have most states instituted and lotteries many have casinos as well
# 4	have most states and instituted lotteries many have casinos as well
# 5	have instituted most states and lotteries many have casinos as well
# 6	have instituted most states and lotteries many have as casinos well
# 7	have most instituted states and lotteries have many as well casinos
# 0	gambling has become very big but controversial business
# 1	gambling has become very big controversial but business
# 2	has gambling become very big controversial but business
# 3	gambling very has become big controversial but business
# 4	very gambling has become big controversial but business
# 5	very gambling has become controversial big but business
# 6	very has gambling big become controversial but business
# 7	gambling very big has controversial but become business
# 0	the wind from the hurricane shook the house shattering a window in the kitchen
# 1	the wind from the hurricane shook the house shattering a in window the kitchen
# 2	the from wind the hurricane shook the house shattering a in window the kitchen
# 3	from the wind the hurricane shook the house shattering a in window the kitchen
# 4	from the wind the hurricane shook the house shattering a in the window kitchen
# 5	from the wind the shook hurricane the house shattering a in the window kitchen
# 6	from the wind shook the hurricane the house shattering a in the window kitchen
# 7	from the the wind shook hurricane the house a shattering window the in kitchen
# 0	we ran in grabbed some food slammed the door and surrendered the kitchen to the hurricane
# 1	we ran in grabbed some food slammed the door and the surrendered kitchen to the hurricane
# 2	we in ran grabbed some food slammed the door and the surrendered kitchen to the hurricane
# 3	in we ran grabbed some food slammed the door and the surrendered kitchen to the hurricane
# 4	in we ran grabbed some food slammed the door and the kitchen surrendered to the hurricane
# 5	in we ran grabbed food some slammed the door and the kitchen surrendered to the hurricane
# 6	in we ran food grabbed some slammed the door and the kitchen surrendered to the hurricane
# 7	in grabbed we ran food some slammed the door and surrendered kitchen the to hurricane the
# 0	i was afraid our house would be ripped from its foundation
# 1	i afraid was our house would be ripped from its foundation
# 2	afraid i was our house would be ripped from its foundation
# 3	afraid i was our would house be ripped from its foundation
# 4	afraid i was would our house be ripped from its foundation
# 5	afraid our i was would house be ripped from its foundation
# 6	afraid our i was would house be ripped its from foundation
# 7	afraid i our was would house ripped be its foundation from
# 0	later that night with the wind shaking the house we fell asleep huddled on the sofa
# 1	later that night with the wind shaking the house we asleep fell huddled on the sofa
# 2	later night that with the wind shaking the house we asleep fell huddled on the sofa
# 3	night later that with the wind shaking the house we asleep fell huddled on the sofa
# 4	night later that with the wind shaking the house we asleep huddled fell on the sofa
# 5	night later that with wind the shaking the house we asleep huddled fell on the sofa
# 6	night later that wind with the shaking the house we asleep huddled fell on the sofa
# 7	night with later that wind the shaking the house we fell huddled asleep on sofa the
# 0	hurricanes can tear limbs off of trees and suck houses off their foundations
# 1	hurricanes can tear limbs off of trees and suck houses their off foundations
# 2	hurricanes tear can limbs off of trees and suck houses their off foundations
# 3	tear hurricanes can limbs off of trees and suck houses their off foundations
# 4	tear hurricanes can limbs off of trees and suck houses their foundations off
# 5	tear hurricanes can limbs of off trees and suck houses their foundations off
# 6	tear hurricanes can of limbs off trees and suck houses their foundations off
# 7	tear limbs hurricanes can of off trees and houses suck off foundations their
# 0	they dump heavy rains that can trigger floods and mudslides
# 1	they heavy dump rains that can trigger floods and mudslides
# 2	heavy they dump rains that can trigger floods and mudslides
# 3	heavy they dump rains can that trigger floods and mudslides
# 4	heavy they dump can rains that trigger floods and mudslides
# 5	heavy rains they dump can that trigger floods and mudslides
# 6	heavy rains they dump can that trigger floods mudslides and
# 7	heavy rains they dump can that floods trigger mudslides and
# 0	hurricanes can also bring a storm surge a wall of ocean water that lurches onto land
# 1	hurricanes can also bring a storm surge a wall of water ocean that lurches onto land
# 2	hurricanes also can bring a storm surge a wall of water ocean that lurches onto land
# 3	also hurricanes can bring a storm surge a wall of water ocean that lurches onto land
# 4	also hurricanes can bring a storm surge a wall of water that ocean lurches onto land
# 5	also hurricanes can bring storm a surge a wall of water that ocean lurches onto land
# 6	also hurricanes can storm bring a surge a wall of water that ocean lurches onto land
# 7	also bring hurricanes can storm a surge a wall of ocean that water lurches land onto
# 0	scientists use several methods to look for evidence of ancient hurricanes
# 1	scientists several use methods to look for evidence of ancient hurricanes
# 2	several scientists use methods to look for evidence of ancient hurricanes
# 3	several scientists use methods look to for evidence of ancient hurricanes
# 4	several scientists use look methods to for evidence of ancient hurricanes
# 5	several methods scientists use look to for evidence of ancient hurricanes
# 6	several methods scientists use look to for evidence ancient of hurricanes
# 7	several scientists methods use look to evidence for ancient hurricanes of
# 0	the strongest storms deposited layers of windblown beach sand at the bottoms of coastal lakes
# 1	the strongest storms deposited layers of windblown beach sand at bottoms the of coastal lakes
# 2	the storms strongest deposited layers of windblown beach sand at bottoms the of coastal lakes
# 3	storms the strongest deposited layers of windblown beach sand at bottoms the of coastal lakes
# 4	storms the strongest deposited layers of windblown beach sand at bottoms of the coastal lakes
# 5	storms the strongest deposited of layers windblown beach sand at bottoms of the coastal lakes
# 6	storms the strongest of deposited layers windblown beach sand at bottoms of the coastal lakes
# 7	storms deposited the strongest of layers windblown beach at sand the of bottoms coastal lakes
# 0	trees drenched by passing hurricanes preserve a record of each storm in their growth rings
# 1	trees drenched by passing hurricanes preserve a record of each in storm their growth rings
# 2	trees by drenched passing hurricanes preserve a record of each in storm their growth rings
# 3	by trees drenched passing hurricanes preserve a record of each in storm their growth rings
# 4	by trees drenched passing hurricanes preserve a record of each in their storm growth rings
# 5	by trees drenched passing preserve hurricanes a record of each in their storm growth rings
# 6	by trees drenched preserve passing hurricanes a record of each in their storm growth rings
# 7	by passing trees drenched preserve hurricanes a record each of storm their in growth rings
# 0	american ice cream is exported around the world but different countries have different preferences
# 1	american ice cream is exported around the world but different have countries different preferences
# 2	american cream ice is exported around the world but different have countries different preferences
# 3	cream american ice is exported around the world but different have countries different preferences
# 4	cream american ice is exported around the world but different have different countries preferences
# 5	cream american ice is around exported the world but different have different countries preferences
# 6	cream american ice around is exported the world but different have different countries preferences
# 7	cream is american ice around exported the world different but countries different have preferences
# 0	many people enjoy their ice cream flavored with local delicacies
# 1	many enjoy people their ice cream flavored with local delicacies
# 2	enjoy many people their ice cream flavored with local delicacies
# 3	enjoy many people their cream ice flavored with local delicacies
# 4	enjoy many people cream their ice flavored with local delicacies
# 5	enjoy their many people cream ice flavored with local delicacies
# 6	enjoy their many people cream ice flavored with delicacies local
# 7	enjoy their many people cream ice with flavored delicacies local
# 0	in some tropical places vanilla ice cream is topped with bananas and fresh mangos
# 1	in some tropical places vanilla ice cream is topped with and bananas fresh mangos
# 2	in tropical some places vanilla ice cream is topped with and bananas fresh mangos
# 3	tropical in some places vanilla ice cream is topped with and bananas fresh mangos
# 4	tropical in some places vanilla ice cream is topped with and fresh bananas mangos
# 5	tropical in some places ice vanilla cream is topped with and fresh bananas mangos
# 6	tropical in some ice places vanilla cream is topped with and fresh bananas mangos
# 7	tropical places in some ice vanilla cream is with topped bananas fresh and mangos
# 0	i remember making ice cream at home as a child
# 1	i making remember ice cream at home as a child
# 2	making i remember ice cream at home as a child
# 3	making i remember ice at cream home as a child
# 4	making i remember at ice cream home as a child
# 5	making ice i remember at cream home as a child
# 6	making ice i remember at cream home as child a
# 7	making ice i remember at cream as home child a
# 0	we poured the cream mixture into a frozen tub then start turning the crank to expose it to the cold
# 1	we poured the mixture cream into a frozen tub then start turning the crank to expose it to the cold
# 2	poured we the mixture cream into a frozen tub then start turning the crank to expose it to the cold
# 3	poured we the mixture cream into a frozen then tub start turning the crank to expose it to the cold
# 4	poured we the mixture cream into a then frozen tub start turning the crank to expose it to the cold
# 5	poured we the into mixture cream a frozen then tub start turning the crank to expose it to the cold
# 6	poured we the into mixture cream a frozen then tub start turning the crank to expose it the to cold
# 7	poured we into the mixture cream a frozen then tub start turning the crank to expose it the to cold
# 0	eventually it froze enough that i couldn't turn the hand crank any more
# 1	eventually it froze enough that i couldn't turn the hand any crank more
# 2	eventually froze it enough that i couldn't turn the hand any crank more
# 3	froze eventually it enough that i couldn't turn the hand any crank more
# 4	froze eventually it enough that i couldn't turn the hand any more crank
# 5	froze eventually it enough i that couldn't turn the hand any more crank
# 6	froze eventually it i enough that couldn't turn the hand any more crank
# 7	froze enough eventually it i that couldn't turn hand the crank more any
# 0	then i put the container of half-frozen ice cream into the freezer to harden
# 1	then i put the container of half-frozen ice cream into freezer the to harden
# 2	then put i the container of half-frozen ice cream into freezer the to harden
# 3	put then i the container of half-frozen ice cream into freezer the to harden
# 4	put then i the container of half-frozen ice cream into freezer to the harden
# 5	put then i the of container half-frozen ice cream into freezer to the harden
# 6	put then i of the container half-frozen ice cream into freezer to the harden
# 7	put the then i of container half-frozen ice into cream the to freezer harden
# 0	ice cream is a mixture of milk or cream sugar flavorings and up to half whipped-in air
# 1	ice cream is mixture a of milk or cream sugar flavorings and up to half whipped-in air
# 2	cream ice is mixture a of milk or cream sugar flavorings and up to half whipped-in air
# 3	cream ice is mixture a of milk or sugar cream flavorings and up to half whipped-in air
# 4	cream ice is mixture a of milk sugar or cream flavorings and up to half whipped-in air
# 5	cream ice is of mixture a milk or sugar cream flavorings and up to half whipped-in air
# 6	cream ice of is mixture a milk or sugar cream flavorings and up to half whipped-in air
# 7	cream ice of is mixture a milk or sugar cream flavorings and up half to whipped-in air
# 0	the butterfat in milk and cream is what makes it smooth and silky
# 1	the butterfat in milk and cream is what makes it and smooth silky
# 2	the in butterfat milk and cream is what makes it and smooth silky
# 3	in the butterfat milk and cream is what makes it and smooth silky
# 4	in the butterfat milk and cream is what makes it and silky smooth
# 5	in the butterfat milk cream and is what makes it and silky smooth
# 6	in the butterfat cream milk and is what makes it and silky smooth
# 7	in milk the butterfat cream and is what it makes smooth silky and
# 0	high-priced premium ice cream is loaded with butterfat and natural flavorings
# 1	high-priced ice premium cream is loaded with butterfat and natural flavorings
# 2	ice high-priced premium cream is loaded with butterfat and natural flavorings
# 3	ice high-priced premium cream loaded is with butterfat and natural flavorings
# 4	ice high-priced premium loaded cream is with butterfat and natural flavorings
# 5	ice cream high-priced premium loaded is with butterfat and natural flavorings
# 6	ice cream high-priced premium loaded is with butterfat natural and flavorings
# 7	ice high-priced cream premium loaded is butterfat with natural flavorings and
# 0	when i use the riding lawn mower the uncomfortable chair makes my back hurt
# 1	when i use the riding lawn mower the uncomfortable chair my makes back hurt
# 2	when use i the riding lawn mower the uncomfortable chair my makes back hurt
# 3	use when i the riding lawn mower the uncomfortable chair my makes back hurt
# 4	use when i the riding lawn mower the uncomfortable chair my back makes hurt
# 5	use when i the lawn riding mower the uncomfortable chair my back makes hurt
# 6	use when i lawn the riding mower the uncomfortable chair my back makes hurt
# 7	use the when i lawn riding mower the chair uncomfortable makes back my hurt
# 0	i use the two levers in front of me to control the machine
# 1	i use the two levers in front of me to the control machine
# 2	i the use two levers in front of me to the control machine
# 3	the i use two levers in front of me to the control machine
# 4	the i use two levers in front of me to the machine control
# 5	the i use two in levers front of me to the machine control
# 6	the i use in two levers front of me to the machine control
# 7	the two i use in levers front of to me control machine the
# 0	the sharp blades underneath the lawn mower precisely sever each blade of grass
# 1	the sharp blades underneath the lawn mower precisely sever each of blade grass
# 2	the blades sharp underneath the lawn mower precisely sever each of blade grass
# 3	blades the sharp underneath the lawn mower precisely sever each of blade grass
# 4	blades the sharp underneath the lawn mower precisely sever each of grass blade
# 5	blades the sharp underneath lawn the mower precisely sever each of grass blade
# 6	blades the sharp lawn underneath the mower precisely sever each of grass blade
# 7	blades underneath the sharp lawn the mower precisely each sever blade grass of
# 0	mowing the lawn is a long task and it has taught me patience
# 1	mowing the lawn is a long task and it has me taught patience
# 2	mowing lawn the is a long task and it has me taught patience
# 3	lawn mowing the is a long task and it has me taught patience
# 4	lawn mowing the is a long task and it has me patience taught
# 5	lawn mowing the is long a task and it has me patience taught
# 6	lawn mowing the long is a task and it has me patience taught
# 7	lawn is mowing the long a task and has it taught patience me
# 0	a lawn mower is a machine with revolving blades that cut grass to an even height
# 1	a lawn mower is a machine with revolving blades that grass cut to an even height
# 2	a mower lawn is a machine with revolving blades that grass cut to an even height
# 3	mower a lawn is a machine with revolving blades that grass cut to an even height
# 4	mower a lawn is a machine with revolving blades that grass to cut an even height
# 5	mower a lawn is machine a with revolving blades that grass to cut an even height
# 6	mower a lawn machine is a with revolving blades that grass to cut an even height
# 7	mower is a lawn machine a with revolving blades that cut to grass an height even
# 0	the blades may be powered by muscle or the machine may have a motor
# 1	the blades may be powered by muscle or the machine have may a motor
# 2	the may blades be powered by muscle or the machine have may a motor
# 3	may the blades be powered by muscle or the machine have may a motor
# 4	may the blades be powered by muscle or the machine have a may motor
# 5	may the blades be by powered muscle or the machine have a may motor
# 6	may the blades by be powered muscle or the machine have a may motor
# 7	may be the blades by powered muscle or machine the may a have motor
# 0	the most common power source for lawn mowers is a small gas engine
# 1	the most common power source for lawn mowers is a gas small engine
# 2	the common most power source for lawn mowers is a gas small engine
# 3	common the most power source for lawn mowers is a gas small engine
# 4	common the most power source for lawn mowers is a gas engine small
# 5	common the most power for source lawn mowers is a gas engine small
# 6	common the most for power source lawn mowers is a gas engine small
# 7	common power the most for source lawn mowers a is small engine gas
# 0	electric lawnmowers are better for the environment because they do not create emissions
# 1	electric lawnmowers are better for the environment because they do create not emissions
# 2	electric are lawnmowers better for the environment because they do create not emissions
# 3	are electric lawnmowers better for the environment because they do create not emissions
# 4	are electric lawnmowers better for the environment because they do create emissions not
# 5	are electric lawnmowers better the for environment because they do create emissions not
# 6	are electric lawnmowers the better for environment because they do create emissions not
# 7	are better electric lawnmowers the for environment because do they not emissions create
# 0	they also need less maintenance and are less expensive to run
# 1	they need also less maintenance and are less expensive to run
# 2	need they also less maintenance and are less expensive to run
# 3	need they also less and maintenance are less expensive to run
# 4	need they also and less maintenance are less expensive to run
# 5	need less they also and maintenance are less expensive to run
# 6	need less they also and maintenance are less to expensive run
# 7	need they less also and maintenance less are to run expensive
# 0	electric lawn mowers use as much electricity as an ordinary toaster
# 1	electric mowers lawn use as much electricity as an ordinary toaster
# 2	mowers electric lawn use as much electricity as an ordinary toaster
# 3	mowers electric lawn use much as electricity as an ordinary toaster
# 4	mowers electric lawn much use as electricity as an ordinary toaster
# 5	mowers use electric lawn much as electricity as an ordinary toaster
# 6	mowers use electric lawn much as electricity as ordinary an toaster
# 7	mowers electric use lawn much as as electricity ordinary toaster an
# 0	astronauts train a long time for their spacewalks
# 1	astronauts train a long time their for spacewalks
# 2	train astronauts a long time their for spacewalks
# 3	astronauts long train a time their for spacewalks
# 4	long astronauts train a time their for spacewalks
# 5	long astronauts train a their time for spacewalks
# 6	long train astronauts time a their for spacewalks
# 7	astronauts long time train their for a spacewalks
# 0	much of their training is conducted underwater
# 1	much of their training is underwater conducted
# 2	of much their training is underwater conducted
# 3	much training of their is underwater conducted
# 4	training much of their is underwater conducted
# 5	training much of their underwater is conducted
# 6	training of much is their underwater conducted
# 7	much training is of underwater conducted their
# 0	they may spend 8 to 10 hours in the pool for every hour they will spend floating in space
# 1	they may spend to 8 10 hours in the pool for every hour they will spend floating in space
# 2	may they spend to 8 10 hours in the pool for every hour they will spend floating in space
# 3	may they spend to 8 10 hours in pool the for every hour they will spend floating in space
# 4	may they spend to 8 10 hours pool in the for every hour they will spend floating in space
# 5	may they spend 10 to 8 hours in pool the for every hour they will spend floating in space
# 6	may they spend 10 to 8 hours in pool the for every hour they will spend floating space in
# 7	may they 10 spend to 8 hours in pool the for every hour they will spend floating space in
# 0	astronauts practice to be able to perform construction and repair work on the outside of the space station
# 1	astronauts practice to able be to perform construction and repair work on the outside of the space station
# 2	practice astronauts to able be to perform construction and repair work on the outside of the space station
# 3	practice astronauts to able be to perform construction repair and work on the outside of the space station
# 4	practice astronauts to able be to perform repair construction and work on the outside of the space station
# 5	practice astronauts to to able be perform construction repair and work on the outside of the space station
# 6	practice astronauts to to able be perform construction repair and work on the outside of the space station
# 7	practice astronauts to to able be perform construction repair and work on the of outside the space station
# 0	the commanders of shuttle flights are always pilots and many have backgrounds as military test pilots
# 1	the commanders of shuttle flights are always pilots and many backgrounds have as military test pilots
# 2	the of commanders shuttle flights are always pilots and many backgrounds have as military test pilots
# 3	of the commanders shuttle flights are always pilots and many backgrounds have as military test pilots
# 4	of the commanders shuttle flights are always pilots and many backgrounds as have military test pilots
# 5	of the commanders shuttle are flights always pilots and many backgrounds as have military test pilots
# 6	of the commanders are shuttle flights always pilots and many backgrounds as have military test pilots
# 7	of shuttle the commanders are flights always pilots and many have as backgrounds military pilots test
# 0	other astronauts are trained as doctors engineers and scientists who can run experiments in space
# 1	other astronauts are trained as doctors engineers and scientists who run can experiments in space
# 2	other are astronauts trained as doctors engineers and scientists who run can experiments in space
# 3	are other astronauts trained as doctors engineers and scientists who run can experiments in space
# 4	are other astronauts trained as doctors engineers and scientists who run experiments can in space
# 5	are other astronauts trained doctors as engineers and scientists who run experiments can in space
# 6	are other astronauts doctors trained as engineers and scientists who run experiments can in space
# 7	are trained other astronauts doctors as engineers and who scientists can experiments run in space
# 0	early crews were all young men but astronauts now are much more diverse
# 1	early crews were all young men but astronauts now are more much diverse
# 2	early were crews all young men but astronauts now are more much diverse
# 3	were early crews all young men but astronauts now are more much diverse
# 4	were early crews all young men but astronauts now are more diverse much
# 5	were early crews all men young but astronauts now are more diverse much
# 6	were early crews men all young but astronauts now are more diverse much
# 7	were all early crews men young but astronauts are now much diverse more
# 0	the team of astronauts floated out together to the exterior of the space shuttle
# 1	the team of astronauts floated out together to the exterior the of space shuttle
# 2	the of team astronauts floated out together to the exterior the of space shuttle
# 3	of the team astronauts floated out together to the exterior the of space shuttle
# 4	of the team astronauts floated out together to the exterior the space of shuttle
# 5	of the team astronauts out floated together to the exterior the space of shuttle
# 6	of the team out astronauts floated together to the exterior the space of shuttle
# 7	of astronauts the team out floated together to exterior the of space the shuttle
# 0	they carried tools needed to repair the broken part on the huge telescope
# 1	they carried tools needed to repair the broken part on huge the telescope
# 2	they tools carried needed to repair the broken part on huge the telescope
# 3	tools they carried needed to repair the broken part on huge the telescope
# 4	tools they carried needed to repair the broken part on huge telescope the
# 5	tools they carried needed repair to the broken part on huge telescope the
# 6	tools they carried repair needed to the broken part on huge telescope the
# 7	tools needed they carried repair to the broken on part the telescope huge
# 0	one astronaut loosened the bolts on the pipe while the other fitted the replacement part into place
# 1	one astronaut loosened bolts the on the pipe while the other fitted the replacement part into place
# 2	astronaut one loosened bolts the on the pipe while the other fitted the replacement part into place
# 3	astronaut one loosened bolts the on the pipe the while other fitted the replacement part into place
# 4	astronaut one loosened bolts the on the the pipe while other fitted the replacement part into place
# 5	astronaut one loosened on bolts the the pipe the while other fitted the replacement part into place
# 6	astronaut one on loosened bolts the the pipe the while other fitted the replacement part into place
# 7	astronaut one on loosened bolts the the pipe the while other fitted the part replacement into place
# 0	computers have been used in art for a long time by experimental artists
# 1	computers have been used in art for a long time experimental by artists
# 2	computers been have used in art for a long time experimental by artists
# 3	been computers have used in art for a long time experimental by artists
# 4	been computers have used in art for a long time experimental artists by
# 5	been computers have used art in for a long time experimental artists by
# 6	been computers have art used in for a long time experimental artists by
# 7	been used computers have art in for a time long by artists experimental
# 0	now that computers are more affordable and widespread computer graphics have entered the mainstream art world
# 1	now that computers are more affordable and widespread computer graphics entered have the mainstream art world
# 2	now computers that are more affordable and widespread computer graphics entered have the mainstream art world
# 3	computers now that are more affordable and widespread computer graphics entered have the mainstream art world
# 4	computers now that are more affordable and widespread computer graphics entered the have mainstream art world
# 5	computers now that are affordable more and widespread computer graphics entered the have mainstream art world
# 6	computers now that affordable are more and widespread computer graphics entered the have mainstream art world
# 7	computers are now that affordable more and widespread computer graphics have the entered mainstream world art
# 0	some computer science conferences have art exhibitions that showcase the latest graphics technology
# 1	some computer science conferences have art exhibitions that showcase the graphics latest technology
# 2	some science computer conferences have art exhibitions that showcase the graphics latest technology
# 3	science some computer conferences have art exhibitions that showcase the graphics latest technology
# 4	science some computer conferences have art exhibitions that showcase the graphics technology latest
# 5	science some computer conferences art have exhibitions that showcase the graphics technology latest
# 6	science some computer art conferences have exhibitions that showcase the graphics technology latest
# ...
# 5	produce very cyclones can winds powerful and torrential rain
# 6	produce very cyclones can winds powerful torrential and rain
# 7	produce very cyclones winds can powerful torrential and rain
# 0	tropical cyclone can also cause high waves and coastal flooding
# 1	tropical can cyclone also cause high waves and coastal flooding
# 2	can tropical cyclone also cause high waves and coastal flooding
# 3	can tropical cyclone also high cause waves and coastal flooding
# 4	can tropical cyclone high also cause waves and coastal flooding
# 5	can also tropical cyclone high cause waves and coastal flooding
# 6	can also tropical cyclone high cause waves and flooding coastal
# 7	can also tropical cyclone high cause and waves flooding coastal
# 0	a tropical cyclone can move inland and seriously damage property
# 1	a cyclone tropical can move inland and seriously damage property
# 2	cyclone a tropical can move inland and seriously damage property
# 3	cyclone a tropical can inland move and seriously damage property
# 4	cyclone a tropical inland can move and seriously damage property
# 5	cyclone can a tropical inland move and seriously damage property
# 6	cyclone can a tropical inland move and seriously property damage
# 7	cyclone can a tropical inland move seriously and property damage
# 0	the violin is an instrument with four strings that is played with a bow
# 1	the violin is an instrument with four strings that is with played a bow
# 2	the is violin an instrument with four strings that is with played a bow
# 3	is the violin an instrument with four strings that is with played a bow
# 4	is the violin an instrument with four strings that is with a played bow
# 5	is the violin an with instrument four strings that is with a played bow
# 6	is the violin with an instrument four strings that is with a played bow
# 7	is an the violin with instrument four strings is that played a with bow
# 0	violin is the smallest and highest pitched instrument in its family
# 1	violin the is smallest and highest pitched instrument in its family
# 2	the violin is smallest and highest pitched instrument in its family
# 3	the violin is smallest highest and pitched instrument in its family
# 4	the violin is highest smallest and pitched instrument in its family
# 5	the smallest violin is highest and pitched instrument in its family
# 6	the smallest violin is highest and pitched instrument its in family
# 7	the violin smallest is highest and instrument pitched its family in
# 0	a violinist holds the instrument between the chin and the collarbone
# 1	a holds violinist the instrument between the chin and the collarbone
# 2	holds a violinist the instrument between the chin and the collarbone
# 3	holds a violinist the between instrument the chin and the collarbone
# 4	holds a violinist between the instrument the chin and the collarbone
# 5	holds the a violinist between instrument the chin and the collarbone
# 6	holds the a violinist between instrument the chin the and collarbone
# 7	holds a the violinist between instrument chin the the collarbone and
# 0	different notes are made by fingering the neck with one hand while bowing
# 1	different notes are made by fingering the neck with one while hand bowing
# 2	different are notes made by fingering the neck with one while hand bowing
# 3	are different notes made by fingering the neck with one while hand bowing
# 4	are different notes made by fingering the neck with one while bowing hand
# 5	are different notes made fingering by the neck with one while bowing hand
# 6	are different notes fingering made by the neck with one while bowing hand
# 7	are made different notes fingering by the neck one with hand bowing while
# 0	vultures are scavenging birds feeding mostly on the carcasses of dead animals
# 1	vultures are scavenging birds feeding mostly on the carcasses of animals dead
# 2	vultures scavenging are birds feeding mostly on the carcasses of animals dead
# 3	scavenging vultures are birds feeding mostly on the carcasses of animals dead
# 4	scavenging vultures are birds mostly feeding on the carcasses of animals dead
# 5	scavenging vultures are mostly birds feeding on the carcasses of animals dead
# 6	scavenging birds vultures are mostly feeding on the carcasses of animals dead
# 7	scavenging vultures birds are mostly feeding the on of dead carcasses animals
# 0	many vultures have a bald head without feathers for losing heat
# 1	many have vultures a bald head without feathers for losing heat
# 2	have many vultures a bald head without feathers for losing heat
# 3	have many vultures a head bald without feathers for losing heat
# 4	have many vultures head a bald without feathers for losing heat
# 5	have a many vultures head bald without feathers for losing heat
# 6	have a many vultures head bald without feathers losing for heat
# 7	have many a vultures head bald feathers without losing heat for
# 0	vultures use their large wings to soar for miles without flapping
# 1	vultures their use large wings to soar for miles without flapping
# 2	their vultures use large wings to soar for miles without flapping
# 3	their vultures use large to wings soar for miles without flapping
# 4	their vultures use to large wings soar for miles without flapping
# 5	their large vultures use to wings soar for miles without flapping
# 6	their large vultures use to wings soar for without miles flapping
# 7	their vultures large use to wings for soar without flapping miles
# 0	vultures seldom attack healthy animals but may kill the wounded or sick
# 1	vultures seldom attack healthy animals but may kill the wounded sick or
# 2	vultures attack seldom healthy animals but may kill the wounded sick or
# 3	attack vultures seldom healthy animals but may kill the wounded sick or
# 4	attack vultures seldom healthy but animals may kill the wounded sick or
# 5	attack vultures seldom but healthy animals may kill the wounded sick or
# 6	attack healthy vultures seldom but animals may kill the wounded sick or
# 7	attack vultures healthy seldom but animals kill may wounded or the sick
# 0	a wall is a solid structure that defines and sometimes protects an area
# 1	a wall is a solid structure that defines and sometimes an protects area
# 2	a is wall a solid structure that defines and sometimes an protects area
# 3	is a wall a solid structure that defines and sometimes an protects area
# 4	is a wall a solid structure that defines and sometimes an area protects
# 5	is a wall a structure solid that defines and sometimes an area protects
# 6	is a wall structure a solid that defines and sometimes an area protects
# 7	is a a wall structure solid that defines sometimes and protects area an
# 0	walls delineate a building support the roof and divide the space into rooms
# 1	walls delineate a building support the roof and divide the into space rooms
# 2	walls a delineate building support the roof and divide the into space rooms
# 3	a walls delineate building support the roof and divide the into space rooms
# 4	a walls delineate building support the roof and divide the into rooms space
# 5	a walls delineate building the support roof and divide the into rooms space
# 6	a walls delineate the building support roof and divide the into rooms space
# 7	a building walls delineate the support roof and the divide space rooms into
# 0	walls are usually made of stone brick or cement as well as drywall
# 1	walls are usually made of stone brick or cement as as well drywall
# 2	walls usually are made of stone brick or cement as as well drywall
# 3	usually walls are made of stone brick or cement as as well drywall
# 4	usually walls are made of stone brick or cement as as drywall well
# 5	usually walls are made stone of brick or cement as as drywall well
# 6	usually walls are stone made of brick or cement as as drywall well
# 7	usually made walls are stone of brick or as cement well drywall as
# 0	retaining walls provide a barrier to movement of earth stone or water
# 1	retaining walls provide a barrier to movement of earth stone water or
# 2	retaining provide walls a barrier to movement of earth stone water or
# 3	provide retaining walls a barrier to movement of earth stone water or
# 4	provide retaining walls a to barrier movement of earth stone water or
# 5	provide retaining walls to a barrier movement of earth stone water or
# 6	provide a retaining walls to barrier movement of earth stone water or
# 7	provide retaining a walls to barrier of movement stone or earth water
# 0	water is the most common liquid on earth covering 70% of its area
# 1	water is the most common liquid on earth covering 70% its of area
# 2	water the is most common liquid on earth covering 70% its of area
# 3	the water is most common liquid on earth covering 70% its of area
# 4	the water is most common liquid on earth covering 70% its area of
# 5	the water is most liquid common on earth covering 70% its area of
# 6	the water is liquid most common on earth covering 70% its area of
# 7	the most water is liquid common on earth 70% covering of area its
# 0	plants animals and people must drink water in order to live
# 1	plants and animals people must drink water in order to live
# 2	and plants animals people must drink water in order to live
# 3	and plants animals people drink must water in order to live
# 4	and plants animals drink people must water in order to live
# 5	and people plants animals drink must water in order to live
# 6	and people plants animals drink must water in to order live
# 7	and plants people animals drink must in water to live order
# 0	water freezes at a low temperature and becomes solid ice
# 1	water at freezes a low temperature and becomes solid ice
# 2	at water freezes a low temperature and becomes solid ice
# 3	at water freezes a temperature low and becomes solid ice
# 4	at water freezes temperature a low and becomes solid ice
# 5	at a water freezes temperature low and becomes solid ice
# 6	at a water freezes temperature low and becomes ice solid
# 7	at a water freezes temperature low becomes and ice solid
# 0	rain is water that falls from clouds in the sky which are condensed vapor
# 1	rain is water that falls from clouds in the sky are which condensed vapor
# 2	rain water is that falls from clouds in the sky are which condensed vapor
# 3	water rain is that falls from clouds in the sky are which condensed vapor
# 4	water rain is that falls from clouds in the sky are condensed which vapor
# 5	water rain is that from falls clouds in the sky are condensed which vapor
# 6	water rain is from that falls clouds in the sky are condensed which vapor
# 7	water that rain is from falls clouds in sky the which condensed are vapor
# 0	a whale is a very large mammal that lives in the ocean
# 1	a whale is a very large mammal that lives in ocean the
# 2	a is whale a very large mammal that lives in ocean the
# 3	is a whale a very large mammal that lives in ocean the
# 4	is a whale a large very mammal that lives in ocean the
# 5	is a whale large a very mammal that lives in ocean the
# 6	is a a whale large very mammal that lives in ocean the
# 7	is a a whale large very that mammal in the lives ocean
# 0	whales breathe through blowholes on their heads when surfacing
# 1	whales through breathe blowholes on their heads when surfacing
# 2	through whales breathe blowholes on their heads when surfacing
# 3	through whales breathe blowholes their on heads when surfacing
# 4	through whales breathe their blowholes on heads when surfacing
# 5	through blowholes whales breathe their on heads when surfacing
# 6	through blowholes whales breathe their on when heads surfacing
# 7	through blowholes whales their breathe on when heads surfacing
# 0	the blubber in a whale serves as an energy reservoir and as insulation
# 1	the blubber in a whale serves as an energy reservoir as and insulation
# 2	the in blubber a whale serves as an energy reservoir as and insulation
# 3	in the blubber a whale serves as an energy reservoir as and insulation
# 4	in the blubber a whale serves as an energy reservoir as insulation and
# 5	in the blubber a serves whale as an energy reservoir as insulation and
# 6	in the blubber serves a whale as an energy reservoir as insulation and
# 7	in a the blubber serves whale as an reservoir energy and insulation as
# 0	whales have been hunted for meat whale oil and ambergris
# 1	whales been have hunted for meat whale oil and ambergris
# 2	been whales have hunted for meat whale oil and ambergris
# 3	been whales have hunted meat for whale oil and ambergris
# 4	been whales have meat hunted for whale oil and ambergris
# 5	been hunted whales have meat for whale oil and ambergris
# 6	been hunted whales have meat for whale oil ambergris and
# 7	been hunted whales have meat for oil whale ambergris and
# 0	a window is a transparent opening in a wall to let light through
# 1	a window is a transparent opening in a wall to light let through
# 2	a is window a transparent opening in a wall to light let through
# 3	is a window a transparent opening in a wall to light let through
# 4	is a window a transparent opening in a wall to light through let
# 5	is a window a opening transparent in a wall to light through let
# 6	is a window opening a transparent in a wall to light through let
# 7	is a a window opening transparent in a to wall let through light
# 0	a typical window is made of sheets of glass held in place by frames
# 1	a typical window is made of sheets of glass held place in by frames
# 2	a window typical is made of sheets of glass held place in by frames
# 3	window a typical is made of sheets of glass held place in by frames
# 4	window a typical is made of sheets of glass held place by in frames
# 5	window a typical is of made sheets of glass held place by in frames
# 6	window a typical of is made sheets of glass held place by in frames
# 7	window is a typical of made sheets of held glass in by place frames
# 0	when open a window will also let air and sound through
# 1	when a open window will also let air and sound through
# 2	a when open window will also let air and sound through
# 3	a when open window also will let air and sound through
# 4	a when open also window will let air and sound through
# 5	a window when open also will let air and sound through
# 6	a window when open also will let air sound and through
# 7	a when window open also will air let sound through and
# 0	some windows have multiple panes to increase insulation inside
# 1	some have windows multiple panes to increase insulation inside
# 2	have some windows multiple panes to increase insulation inside
# 3	have some windows multiple to panes increase insulation inside
# 4	have some windows to multiple panes increase insulation inside
# 5	have multiple some windows to panes increase insulation inside
# 6	have multiple some windows to panes insulation increase inside
# 7	have multiple some to windows panes insulation increase inside
# 0	a woman is a female human adult
# 1	a woman is a female adult human
# 2	woman a is a female adult human
# 3	a a woman is female adult human
# 4	a a woman is female adult human
# 5	a a woman is adult female human
# 6	a woman a female is adult human
# 7	a a female woman adult human is
# 0	a woman is stereotypically seen as a caregiver
# 1	a woman is stereotypically seen a as caregiver
# 2	woman a is stereotypically seen a as caregiver
# 3	a stereotypically woman is seen a as caregiver
# 4	stereotypically a woman is seen a as caregiver
# 5	stereotypically a woman is a seen as caregiver
# 6	stereotypically woman a seen is a as caregiver
# 7	a stereotypically seen woman a as is caregiver
# 0	a woman can become pregnant and bear children
# 1	a woman can become pregnant bear and children
# 2	woman a can become pregnant bear and children
# 3	a become woman can pregnant bear and children
# 4	become a woman can pregnant bear and children
# 5	become a woman can bear pregnant and children
# 6	become woman a pregnant can bear and children
# 7	a become pregnant woman bear and can children
# 0	a woman has different reproductive organs than a man
# 1	a has woman different reproductive organs than a man
# 2	has a woman different reproductive organs than a man
# 3	has a woman different organs reproductive than a man
# 4	has a woman organs different reproductive than a man
# 5	has different a woman organs reproductive than a man
# 6	has different a woman organs reproductive a than man
# 7	has different a organs woman reproductive a than man

# %% [markdown]
# `filter out conditions used in Mollica et al. (2020)`

# %%
def create_scr_lists(filename):
    with open(os.path.join(stimuli_path,filename),"r") as f:
        reader = csv.reader(f, delimiter="\t")
        sentences = list(reader)
    Original = [sentence[1] + '.' for sentence in sentences if int(sentence[0]) == 0]
    Scr1 = [sentence[1] + '.' for sentence in sentences if int(sentence[0]) == 1]
    Scr3 = [sentence[1] + '.' for sentence in sentences if int(sentence[0]) == 3]
    Scr5 = [sentence[1] + '.' for sentence in sentences if int(sentence[0]) == 5]
    Scr7 = [sentence[1] + '.' for sentence in sentences if int(sentence[0]) == 7]
    
    return(Original, Scr1, Scr3, Scr5, Scr7)

# %%
Original_243, Scr1_243, Scr3_243, Scr5_243, Scr7_243 = create_scr_lists("stim_243sentences_scrambled.txt")
Original_384, Scr1_384, Scr3_384, Scr5_384, Scr7_384 = create_scr_lists("stim_384sentences_scrambled.txt")

Original = Original_243 + Original_384
Scr1 = Scr1_243 + Scr1_384
Scr3 = Scr3_243 + Scr3_384
Scr5 = Scr5_243 + Scr5_384
Scr7 = Scr7_243 + Scr7_384

# %%
condition_names = ["Original", "Scr1", "Scr3", "Scr5", "Scr7"]
condition_lists = [Original, Scr1, Scr3, Scr5, Scr7]
condition_dict = dict(zip(condition_names, condition_lists))
condition_dict
# Out:
# {'Original': ['beekeeping encourages the conservation of local habitats.',
#   "it is in every beekeeper's interest to conserve local plants that produce pollen.",
#   'as a passive form of agriculture it does not require that native vegetation be cleared to make way for crops.',
#   'beekeepers also discourage the use of pesticides on crops because they could kill the honeybees.',
#   'artisanal beekeepers go to extremes for their craft but their product is worth the effort.',
#   'artisanal honey-making emphasizes quality and character over quantity and consistency.',
#   'to produce the finest honey beekeepers become micromanagers of their honeybees.',
#   'they scout the fields know when nectar flows and select the best ways to extract honey.',
#   'as the beekeeper opens the hive the deep hum of 40000 bees fills the air.',
#   'the beekeeper checks honey stores pollen supplies and the bee nursery.',
#   "bees crawl across his bare arms and hands but they don't sting because they're gentle.",
#   "i have a recurring dream about exams even though i'm no longer in college.",
#   "in my dream it's the day of my final exam and i suddenly realize i've never gone to class.",
#   "i've never even done any of the reading assignments.",
#   'i know many other people who have the same nightmare.',
#   'each morning participants in the study had to write down their dream experience from the previous night.',
#   'they recorded if they recalled any dreams and described each dream and its emotional intensity.',
#   'participants then assigned each dream to a category such as a flying dream a bad dream or a nightmare.',
#   'every night while we sleep our minds are as active as when we are awake.',
#   'we dream throughout the night in cycles of about ninety minutes each.',
#   'images feelings stories and strange combinations of characters and places can fill our dreams.',
#   'when i decided to start playing cards things went from bad to worse.',
#   'gambling was something i had to do and i had already spent close to $10000 doing it.',
#   'my friends were sick of watching me gamble my savings away.',
#   'the hardest part was the horror of leaving a casino after losing money i did not have.',
#   'good data on the social and economic effects of legalized gambling are hard to come by.',
#   'some studies indicate that having a casino nearby makes gambling problems more likely.',
#   'gambling may also be associated with personal bankruptcies and marriage problems.',
#   'over the past generation there has been a dramatic expansion of legalized gambling.',
#   'most states have instituted lotteries and many have casinos as well.',
#   'gambling has become very big but controversial business.',
#   'the wind from the hurricane shook the house shattering a window in the kitchen.',
#   'we ran in grabbed some food slammed the door and surrendered the kitchen to the hurricane.',
#   'i was afraid our house would be ripped from its foundation.',
#   'later that night with the wind shaking the house we fell asleep huddled on the sofa.',
#   'hurricanes can tear limbs off of trees and suck houses off their foundations.',
#   'they dump heavy rains that can trigger floods and mudslides.',
#   'hurricanes can also bring a storm surge a wall of ocean water that lurches onto land.',
#   'scientists use several methods to look for evidence of ancient hurricanes.',
#   'the strongest storms deposited layers of windblown beach sand at the bottoms of coastal lakes.',
#   'trees drenched by passing hurricanes preserve a record of each storm in their growth rings.',
#   'american ice cream is exported around the world but different countries have different preferences.',
#   'many people enjoy their ice cream flavored with local delicacies.',
#   'in some tropical places vanilla ice cream is topped with bananas and fresh mangos.',
#   'i remember making ice cream at home as a child.',
#   'we poured the cream mixture into a frozen tub then start turning the crank to expose it to the cold.',
#   "eventually it froze enough that i couldn't turn the hand crank any more.",
#   'then i put the container of half-frozen ice cream into the freezer to harden.',
#   'ice cream is a mixture of milk or cream sugar flavorings and up to half whipped-in air.',
#   'the butterfat in milk and cream is what makes it smooth and silky.',
#   'high-priced premium ice cream is loaded with butterfat and natural flavorings.',
#   'when i use the riding lawn mower the uncomfortable chair makes my back hurt.',
#   'i use the two levers in front of me to control the machine.',
#   'the sharp blades underneath the lawn mower precisely sever each blade of grass.',
#   'mowing the lawn is a long task and it has taught me patience.',
#   'a lawn mower is a machine with revolving blades that cut grass to an even height.',
#   'the blades may be powered by muscle or the machine may have a motor.',
#   'the most common power source for lawn mowers is a small gas engine.',
#   'electric lawnmowers are better for the environment because they do not create emissions.',
#   'they also need less maintenance and are less expensive to run.',
#   'electric lawn mowers use as much electricity as an ordinary toaster.',
#   'astronauts train a long time for their spacewalks.',
#   'much of their training is conducted underwater.',
#   'they may spend 8 to 10 hours in the pool for every hour they will spend floating in space.',
#   'astronauts practice to be able to perform construction and repair work on the outside of the space station.',
#   'the commanders of shuttle flights are always pilots and many have backgrounds as military test pilots.',
#   'other astronauts are trained as doctors engineers and scientists who can run experiments in space.',
#   'early crews were all young men but astronauts now are much more diverse.',
#   'the team of astronauts floated out together to the exterior of the space shuttle.',
#   'they carried tools needed to repair the broken part on the huge telescope.',
#   'one astronaut loosened the bolts on the pipe while the other fitted the replacement part into place.',
#   'computers have been used in art for a long time by experimental artists.',
#   'now that computers are more affordable and widespread computer graphics have entered the mainstream art world.',
#   'some computer science conferences have art exhibitions that showcase the latest graphics technology.',
#   'brand new conferences have sprung up that are devoted to bridging the two cultures.',
#   'the computer graphics specialist works with doctors to visualize medical conditions and surgical procedures.',
#   "she uses digital animation to help doctors understand structures within a patient's body.",
#   'seeing the internal structures in an animation on a screen is much clearer than squinting at x-rays.',
#   'modern digital animation is a powerful tool for education.',
#   'as the field of computer graphics broadens we must ask if graphics actually help students.',
#   'research does suggest that vivid and engaging digital imagery can be effective in the classroom.',
#   'the reason he came to law school in the first place was cliche.',
#   'he wanted to change things for the better.',
#   'he recalled one evening at law school when he and the program director had pulled an all-nighter.',
#   'they finally finished drafting a petition for several evicted families at sunrise.',
#   'over the past four decades the cost of legal education has gone up relentlessly.',
#   'private law school tuition increased by a factor of four since the 1970s.',
#   'the market for admission to law school and for new lawyers could eventually crash.',
#   'law school faculty often have minimal experience in actually practicing law.',
#   'professors focus on writing law review articles for prestigious journals.',
#   'law schools often emphasize the theoretical with classes on topics like property law in feudal england.',
#   'pharmacists are increasingly involved in preventive care.',
#   'they are becoming front-line health advisers because people go to pharmacies often.',
#   'pharmacists are often a good source of information about public health.',
#   'doctors consult with pharmacists because they know a lot about drug interactions and side effects.',
#   'pharmacists dispense prescription drugs to patients and offer advice about the safe use of medications.',
#   'they also conduct health and wellness screenings and provide vaccines.',
#   'pharmacists must have professional degrees and pass two exams in order to be licensed.',
#   'i think the pharmacy profession chose me as much as i chose to be a pharmacist.',
#   'i was fascinated by the neatly arranged bottles in pharmacies as a child.',
#   "i know it's cliche but i love the impact that i have on lives of my patients.",
#   'each person has his or her own response to potentially stressful situations.',
#   'one person may be devastated by unemployment while another may find working fulltime stressful.',
#   'there are everyday stresses like being stuck in traffic.',
#   'there are also traumatic stresses such as divorce or loss of a child.',
#   'some people can adapt to different levels of stress.',
#   'if not dealt with effectively though stress can take a real toll on health.',
#   "remember that it's your reaction to stress that determines if it will be harmful or beneficial.",
#   'when my company was downsizing i felt incredibly stressed and worried.',
#   'my heart would race for no reason and i even felt dizzy at times.',
#   'then i started taking yoga to try to manage my stress level.',
#   'the man wore a jet black tuxedo with satin stripes.',
#   'it was made with rich fabric cut in the latest style.',
#   'clearly he had it tailored as it fit the man perfectly.',
#   'it looked like something a professional stylist would have picked out for a formal event.',
#   "while the tuxedo is still preferred today's grooms are making personal statements in wedding attire.",
#   'shorter jackets are on the cutting edge of wedding fashion for men.',
#   'grooms are also jazzing up their tuxedos with colorful shirts and satin ties.',
#   'a tuxedo jacket is a tailless dinner jacket with black silk lapels.',
#   'black tie trousers should be a perfect match to the tuxedo jacket.',
#   'the shirt should always be plain white and the tie should be black and match the jacket lapels.',
#   'the concert pianist went blind in adulthood.',
#   'her blindness was caused by a genetic condition that slowly damaged the eyes.',
#   'she told interviewers that being blind was an advantage to a pianist.',
#   'she had no visual distractions so she could concentrate more fully on her music.',
#   'the government defines blindness as vision insufficient for the ordinary activities of life.',
#   'by establishing the parameters of legal blindness resources can be focused on the legally blind.',
#   'this may overlook those who have vision problems but who do not meet the standard.',
#   'in developing countries blindness in children is usually caused by infectious disease and nutritional deficiencies.',
#   'these causes can often be prevented by medicine and vitamin supplements.',
#   'in developed countries blindness is more likely to be caused by genetic problems.',
#   'no one really knows exactly how a taste gets from your mouth to your brain.',
#   'scientists think the process begins when a molecule of food touches a taste bud cell.',
#   'the cell carries a taste message to taste nerves beneath the cell.',
#   'it was once believed that each taste bud responded to one of the four basic tastes.',
#   'that is a taste bud on the tip of the tongue would respond only if you were eating something sweet.',
#   'scientists now think that a single taste bud can be sensitive to all of the basic tastes.',
#   "my sense of taste isn't very good so i tend to eat foods with very strong flavors.",
#   "i like lots of hot sauce and i drink my coffee with no cream so it's very bitter.",
#   "i can't even taste sweetness well so when i make cookies i add extra sugar.",
#   'hip fractures are a real problem for aging individuals.',
#   'patients are faced with the pain of the break and the difficult process of healing.',
#   "families have to adjust to the patient's loss of independence.",
#   'and for society hip fractures involve substantial expense and time in the hospital.',
#   'halfway through the race i heard a sound like someone snapping their fingers.',
#   'i felt a crunch and i knew instantly that my foot was broken.',
#   'every step felt like running on spikes.',
#   "at the doctor's office afterward the x-ray clearly showed the fracture.",
#   'there are a few different types of bone fracture.',
#   'in closed or simple fractures the bone is broken but the skin is intact.',
#   'in open or compound fractures the broken bone has punctured the skin and produced an open wound.',
#   "new ear piercings can become infected if they're not carefully cleaned.",
#   'signs of infection include tenderness swelling or redness around the earlobe.',
#   'if you see these symptoms clean the area and apply some ointment.',
#   "if the redness and swelling don't go away contact your health care provider.",
#   'a local hospital has initiated new measures to reduce infections.',
#   'they have improved hand washing habits and ensured that infected patients are isolated from other patients.',
#   'the hospital has seen infection rates drop since the new measures began.',
#   'scrubbing a wound with soap or alcohol delays healing which increases the risk of infection.',
#   'band-aids can increase the risk of infection by holding in heat and moisture.',
#   'fortunately most skin infections can easily be treated once they are diagnosed.',
#   'modern opera started at the end of the sixteenth century.',
#   'it began as an effort to rediscover and imitate greek tragic performance.',
#   'early founders of opera chose tales from antiquity for their subject matter.',
#   'later operas branched out into different sources of stories and musical traditions.',
#   'opera is an art form in which singers and musicians perform a play that combines words and music.',
#   'it incorporates many of the elements of spoken theatre such as acting scenery and costumes.',
#   'performances are typically given in an opera house and accompanied by an orchestra.',
#   'the opera singer has worked hard to win the role in the new production.',
#   'her job is not just about singing.',
#   'acting stage presence and musical interpretation are all critical.',
#   'but her pure strong voice is certainly the star of the show.',
#   'a painter must keep many elements in mind while completing a painting.',
#   'she has to use solid elements of design like strong composition and lighting.',
#   'she has to execute the brush strokes with skill.',
#   "most importantly the content of the painting should reveal a glimpse of the painter's soul.",
#   'long ago painters were employed more as skilled artisans than as creative artists.',
#   'however prominent painters had the social status of scholars and members of the royal court.',
#   'they signed their work decided on its subject and imagery and established a personal relationship with their patrons.',
#   'as a painter i learned to focus less on the actual scene and more on the painting itself.',
#   "an artist's eye is not a camera lens that has to record everything within its field of vision.",
#   'i found nature provides useful information but more than is needed for a good painting.',
#   'the eagle owl is an impressive bird.',
#   'it has ear tufts that stick up like horns.',
#   'its large orange eyes are downright creepy and look like they could pierce right through you.',
#   'this owl hunts at night flying swiftly and silently through the darkness.',
#   'while some owl species have become endangered others are thriving.',
#   'the barred owl has spread well beyond its previous habitat.',
#   "early findings suggest that logging may have facilitated the barred owl's invasion.",
#   'the owl landed on a thick branch and gripped it with her talons.',
#   'she pressed her wings to her sides and settled down half-closing an eye.',
#   'she might have been a statue but for the glow of her eyes.',
#   "it's unnerving to watch a polar bear stalk across floating sea ice.",
#   "it's even worse when you are submerged in the frigid waters directly beneath the huge animal.",
#   'overhead giant paws set down on the ice as the polar bear pursued its prey.',
#   'as part of the film crew for a polar bear documentary i spent months capturing these shots.',
#   'polar bears are one of the few animals that will attack people for reasons other than fear or confusion.',
#   'they may attack out of hunger because they live in a food-scarce environment.',
#   'they will sneak up on people slowly careful to conserve their energy.',
#   "the seal is an important part of the polar bear's diet.",
#   "when hunting they will wait by a seal's breathing hole or stalk seals that are basking on the ice.",
#   'the polar bear will crawl quietly forward and freeze in place when the seal looks around.',
#   'the medieval castle was not a structure built primarily for defense.',
#   'its purpose was to dominate its surroundings.',
#   "a castle could easily control lands within a day's walk.",
#   "during times of attack peasants livestock and property could be brought inside the castle's walls for protection.",
#   'spectacular castles in dramatic locations provide a record of the stormy history of many regions.',
#   'today they stand atop rocky cliffs overlooking beautiful landscapes and quaint villages.',
#   'in the past they were home to battles plots and intrigue.',
#   'upon leaving the train station we saw our hotel looming above a magnificent castle built on a cliff.',
#   'the thick outside walls sheltered an inner courtyard hundreds of feet above the river.',
#   'our tower rooms had an incredible but slightly scary view.',
#   'after climbing fifty feet up the side of the pyramid the man gestured me into a small black entranceway.',
#   "this led into the chamber at the pyramid's center.",
#   'i followed him down the steep dark narrow passage.',
#   'the smell inside the pyramid was chalky and the air was thick.',
#   'more than just the tomb of the king pyramids represented the pride of the nation.',
#   'the care that the pyramid builders took in their craft is evident.',
#   'the stones covering the pyramid were precisely fitted together and polished until the structure gleamed.',
#   'architects are still working to solve the mysteries of how pyramids were constructed.',
#   "some think ramps were built inside the pyramid's walls to raise stone blocks.",
#   'others speculate that ramps zigzagged up the exterior walls of the pyramid.',
#   'even beginner rock climbing takes courage and strength.',
#   'climbers who are learning the sport can try scrambling on large boulders.',
#   "once they're comfortable with that they can begin using ropes to safely climb vertical rock faces.",
#   'all of the boys on the trip were new to rock climbing.',
#   'many were afraid of heights.',
#   'having someone else check their knots and harnesses helped them calm down.',
#   'the adults set up climbing routes appropriate for beginners.',
#   'free-climbing is one particular style of rock climbing.',
#   'the climber relies solely on her skill and physical strength to ascend a rock face.',
#   'rope and bolts are the only equipment used.',
#   'they are meant only to stop the climber if she falls.',
#   'i hesitantly skied down the steep trail that my buddies convinced me to try.',
#   'i made a bad turn and i found myself tumbling down.',
#   'i finally came to a stop at a flat part of the slope.',
#   'my skis were nowhere to be found and my poles were lodged in a snow drift up the hill.',
#   'a major strength of professional skiers is how they use ski poles.',
#   'proper use of ski poles improves their balance and adds flair to their skiing.',
#   'it minimizes the need for upper body movements to regain lost balance while skiing.',
#   'new ski designs and stiffer boots let skiers turn more quickly.',
#   'but faster and tighter turns increase the twisting force on the legs.',
#   "this has led to more injuries particularly to ligaments in the skier's knee.",
#   'an accordion is a portable musical instrument with two keyboards.',
#   'one keyboard is used for individual notes the other for chords.',
#   'accordions produce sound with bellows that blow air through reeds.',
#   'an accordionist plays both keyboards while opening and closing the bellows.',
#   'an apartment is a self-contained home that is part of a building.',
#   'an apartment may have one or more rooms as well as a kitchen and a bathroom.',
#   'some apartments are for single people others for families.',
#   'the building can have a garage a laundry facility or extra storage space.',
#   'an apple is a fruit that can be green red or yellow.',
#   'apples have thin skin a crisp sweet pulp and seeds inside.',
#   'some very tart apples are used to make cider.',
#   'apples can be eaten raw roasted or baked in pies.',
#   'arson is the criminal act of burning a building or wildland.',
#   'a fire investigation determines if a fire was caused by accident or arson.',
#   'arson can be done to cause damage to others or collect insurance.',
#   'the severity of the crime depends on whether people were harmed.',
#   'an automobile or car is a wheeled vehicle for transporting passengers.',
#   'a car can be powered by a gasoline or electric engine.',
#   'the driver steers the car on roads other passengers just sit.',
#   'automobiles vary in size number of doors and the type of trunk.',
#   'the axe is a tool used to split and cut wood.',
#   'the axe usually consists of a head attached to a handle.',
#   'historically axe heads were made of stone and then metal.',
#   'axes are used by woodcutters and firemen entering buildings.',
#   'a banana is a long fruit that grows in bunchs with a soft edible inside.',
#   'a banana when ripe can be yellow purple or red and have small brown spots.',
#   'the greatest producers are tropical countries such as india or ecuador.',
#   'unripe bananas and plantains are staple foods and often cooked like potatoes.',
#   'a bed is a piece of furniture used as a place to sleep or have sex in.',
#   'a bed is made of a mattress and a box spring plus sheets pillows and covers.',
#   'in waterbeds the mattress is filled with water and in airbeds it is filled with air.',
#   'another type of bed is the hammock a fabric sling suspended above the ground.',
#   'a bee is a flying insect with a black and yellow body and six legs.',
#   'bees spread pollen between flowers as they collect nectar to make honey.',
#   'bees are social insects and live together in a colony located in a hive.',
#   'many bees have stingers and can attack if they feel threatened.',
#   'a bicycle is a vehicle with two wheels and pedals on a frame.',
#   'a bicycle is propelled by the pedalling of a cyclist on the saddle.',
#   'the wheels have rubber tires with an inner tube full of air.',
#   'people use bicycles for transportation recreation and racing.',
#   'a blacksmith creates objects by forging iron or steel.',
#   'a blacksmith hammers and bends hot iron on an anvil to change its shape.',
#   'blacksmiths wears a thick apron and handle the metal with tongs.',
#   'blacksmiths make objects like weapons horse shoes or iron furniture.',
#   'a blender is a kitchen appliance used to mix ingredients or puree food.',
#   'blenders have a glass or plastic container with a rotating blade in the bottom.',
#   'blenders are used to make milk shakes and fruit smoothies.',
#   'blenders are also used to make cold alcoholic drinks with crushed ice.',
#   'a boy is a young male child who has not undergone puberty.',
#   'the term is used to indicate sex distinctions relative to girls.',
#   'traditionally boys like to play rough games and fight with each other.',
#   'an adult male behaving immaturely is often referred to as a boy.',
#   'broccoli is a plant in the cabbage family.',
#   'broccoli has a green flower head and a thick tough stalk.',
#   'broccoli is high in vitamins fiber and other nutrients.',
#   'broccoli can be boiled stir-fried or eaten raw.',
#   'a butterfly is a flying insect with four large wings.',
#   'the wings of butterflies can be very colorful and patterned.',
#   'metamorphosis is the transformation of a caterpillar into a butterfly.',
#   'some people collect butterflies because of their colorful wings.',
#   'a carpenter is an artist or manual laborer who works with wood.',
#   'carpenters build and repair houses furniture boats and other objects.',
#   'carpenters use tools such as hammers saws pliers and planes.',
#   'a luthier is a carpenter that makes and repairs musical instruments.',
#   'cats are small furry animals with four legs and a tail.',
#   'cats like to groom themselves by licking their fur.',
#   'cats can hunt mice or birds but are often fed by their owners.',
#   'the claws of cats are retractable so that they keep sharp.',
#   'a chair is a piece of furniture designed for people to sit on.',
#   'chairs consist of a seat raised above floor level supported by legs.',
#   'chairs can also have back and arm rests as well as a cushion.',
#   'seats are fixed chairs located in vehicles or in places like cinemas.',
#   'a clarinet is a woodwind musical instrument.',
#   'a clarinet is a long black tube with a flare at the bottom.',
#   'the player chooses notes by pressing keys and holes.',
#   'the clarinet is used both in jazz and classical music.',
#   'a cod is a fish that lives in the colder areas of the atlantic.',
#   'cod flesh is white and mild-tasting and flakes easily when cooked.',
#   'fresh cod is used for fish and chips salted cod for elaborate dishes.',
#   'cod has been caught salted and traded since the time of the vikings.',
#   'coffee is made from coffee beans the seeds of the coffee plant.',
#   'coffee is a popular drink in many countries and usually served hot.',
#   'coffee contains a mild drug called caffeine that keeps people awake.',
#   "coffee is the world's seventh-largest legal agricultural export.",
#   'a desert is a natural environment where almost no rain falls.',
#   'hot deserts are usually filled with sand dunes or rocks.',
#   'some animals and plants have adapted to live in deserts.',
#   'the biggest hot desert is the sahara in northern africa.',
#   'a desk is a piece of furniture used for working at sometimes with a computer.',
#   'a desk has a flat surface and can be made of wood plastic or metal.',
#   'a desk may have drawers to store supplies and papers.',
#   'a cubicle consists of a desk surrounded by partitions on three sides.',
#   'a door is a movable barrier to entrance or exit from an enclosed area.',
#   'most doors have locks to control who gets to pass through them.',
#   'most doors are opened by pushing or pulling a handle after they are unlocked.',
#   'other types of doors can slide or consist of a revolving chamber.',
#   'a dress is a piece of clothing that women sometimes wear.',
#   'a dress is like a shirt attached to a long matching skirt.',
#   'a dress is usually worn at formal occasions such as a wedding or a dance.',
#   'it can be hard to climb stairs or ride a bike in a dress.',
#   'drunk driving is the act of driving under the effects of alcohol.',
#   'drunk driving of any vehicle is a crime in most of the world.',
#   'it plays a role in almost half of all vehicle-related deaths.',
#   'drunk drivers are caught by field sobriety and breathing tests.',
#   'a drought is a persistent shortage of the water supply caused by lack of rain.',
#   'drought will cause crops and plants to stop growing and die.',
#   'extreme drought will eventually turn areas into desert and cause famine.',
#   'large numbers of people have to migrate away from dust bowls.',
#   'eagles are large birds of prey that hunt during the day and have very good eyesight.',
#   'eagles have hooked beaks for tearing flesh strong legs and sharp talons.',
#   'eagles live in eyries and some species eat fish and others small mammals.',
#   'the bald eagle has a bright white head and is the national bird of the united states.',
#   'earthquakes shake the ground and can knock down buildings and other structures.',
#   'the shaking can also trigger landslides and volcanic activity.',
#   "most earthquakes are caused by the release of energy in the earth's crust.",
#   'an earthquake at sea can displace the seabed and cause a tsunami.',
#   'elephants are the largest kind of land mammal weighing several tons.',
#   'an elephant has a long nose called a trunk which can grab things or food.',
#   'the elephant has a pair of ivory tusks for moving objects or digging into trees.',
#   'the elephant flaps its large ears to cool the blood in them and its body.',
#   'the eye is an organ for sensing light and coding it for the visual cortex.',
#   'most animals have complex eyes which can detect color motion and texture.',
#   'the fovea is the center of the human eye and the most sensitive part of it.',
#   'insects have compound eyes made up of eye units facing in many directions.',
#   'a farm is land used to grow plants or raise animals for food.',
#   'farmers are the people who run the farm and decide what to produce.',
#   'farms usually have a house for farmers a silo and a barn.',
#   'a cooperative is a farm where many farmers share the land and equipment.',
#   'primates usually have four fingers and a thumb on each hand.',
#   'fingers are used for grasping writing grooming and other activities.',
#   'the fingertips are sensitive to temperature pressure and vibration.',
#   'the nail protects the tip of the finger and can be grown or decorated.',
#   'a flood is an overflow of an expanse of water that submerges inhabited land.',
#   'flood can be caused by heavy rain or rapid snow melt as well as earthquakes at sea.',
#   'in a flood a river will flow out of its channel or break dams and levees.',
#   'during a flood people evacuate and the contaminated water causes diseases.',
#   'a floor is a horizontal surface inside a building used for walking on.',
#   'floors may be made of bare concrete tile linoleum or wooden floorboards.',
#   'people often put carpets on a floor for comfort and to dampen noise.',
#   'in buildings the floor often has pipes and electrical wiring under it.',
#   'a foot is a body part on the end of a leg.',
#   'people use their feet when walking running or standing straight.',
#   'people also use their feet to kick in both fighting and sports.',
#   'many cultures have rules for behavior related to feet.',
#   'a forest is an area with a high density of trees and canopy cover.',
#   'the type of forest depends on temperature and rainfall in its location.',
#   'a forest ecosystem has various types of trees and animals as well as ground plants.',
#   'deforestation is the cutting down of forests disregarding regeneration.',
#   'a fork is a tool for eating solid foods with a handle and several tines.',
#   'forks are usually made of metal or plastic if disposable.',
#   'forks are used to lift food to the mouth or to hold food in place while cutting.',
#   'forks are used in western cultures and there are special kinds for various foods.',
#   'a frying pan is a small pan with sloping sides and a handle.',
#   'a frying pan is used to fry sear and brown food.',
#   'the food is cooked on oil covering the bottom of the pan.',
#   'frying pans are made of iron or teflon-clad steel.',
#   'a girl is a female human who has not yet reached maturity.',
#   'at puberty the body of a girl develops into that of a woman.',
#   'girls often like playing with dolls and social games.',
#   'girls sometimes grow long hair and wear dresses and skirts.',
#   'a glove is a piece of clothing that covers the hand and fingers.',
#   'gloves to protect against cold are made of wool or lined waterproof material.',
#   'disposable rubber or latex gloves are used to shield hands from germs or chemicals.',
#   'a mitten is a kind of glove where the four fingers are covered together.',
#   'a hammer is a tool used to deliver an impact to an object.',
#   'a hammer is most often used to drive nails into wood.',
#   'the claw on the head can be used to remove nails.',
#   'hammers vary in the shape of the head and handle length.',
#   'a hand grenade is an explosive used as a weapon against people.',
#   'hand grenades are thrown and timed to explode a bit after that.',
#   'grenades can also be fired from rifles or shoulder launchers.',
#   'tear gas grenades are thrown into the middle of a mob to disperse it.',
#   'a horse is a large hoofed mammal with four long muscular legs.',
#   'a horse has a tail and a mane on its neck and is usually gray or brown.',
#   'horses have been used for draft work travel and entertainment.',
#   'a human can ride a horse while it walks trots or gallops.',
#   'people go to hospitals to be healed when they are sick or injured.',
#   'hospitals are staffed by professional physicians surgeons and nurses.',
#   'some patients go there for specialist diagnosis or therapy leaving the same day.',
#   'for some operations or treatments patients have to stay for several weeks.',
#   'a house is a permanent building or structure for people or families to live in.',
#   'a house has a roof and walls to keep out cold and rain and windows to let light in.',
#   'a house can have rooms for purposes like sleeping cooking or washing.',
#   'most people leave the house to work and come back at night to eat and sleep.',
#   'an igloo is a type of shelter made from blocks of snow by inuit.',
#   'igloos are built in places where snow covers the land most of the time.',
#   'igloos are often built in the shape of a dome with an entrance tunnel.',
#   'air pockets in snow insulate the space and body heat warms igloos.',
#   'a knife is a tool with a sharp edge that is used to cut things.',
#   'modern knives consist of a handle and a blade usually made of metal.',
#   'knives have also been used as weapons and instruments in rituals.',
#   'a knife can be used to attack by slashing stabbing or throwing.',
#   'lentils are the seeds of a plant of the legume family.',
#   'lentils can be red green brown black or yellow.',
#   'lentils are commonly used in indian and mediterranean cuisines.',
#   'lentils are cooked by boiling and are a great source of protein.',
#   'lettuce is a biennial plant often grown in temperate climates as a leaf vegetable.',
#   'lettuce can be eaten cold and raw in salads and other dishes or cooked.',
#   'lettuce is considered fairly easy to grow and a suitable crop for beginners.',
#   'most lettuce leaves taste bitter but some are bred to remove the bitterness.',
#   'a library is a place where a collection of books documents and media is kept.',
#   'librarians work at libraries and are experts at finding and organizing information.',
#   'people can go to public libraries and borrow books to take home for several weeks.',
#   'academic libraries support scholarly research and have specialized books.',
#   'a log cabin is a small house built from round logs.',
#   'log cabin is a symbol of american frontier life and humble origins.',
#   'log cabins were used as first shelters by european settlers.',
#   'log cabins were built using logs with notch joints at the ends.',
#   'a man is a male human adult.',
#   'a boy becomes a man after passing through puberty.',
#   'manhood is associated with masculinity and virility.',
#   'men differ from women in height weight and body structure.',
#   'milk is a white liquid produced by female mammals to feed their young.',
#   'newborn animals must be fed milk before they can eat solid food.',
#   'dairy products such as cheese and butter are made from milk.',
#   'liquid produced from soybeans and coconuts is sometimes called milk.',
#   'mosquitos are thin small flying insects that emit a high-pitched sound.',
#   'mosquitoes have mouthparts for piercing the skin of plants and animals.',
#   'female mosquitoes bite people and animals and suck their blood for protein.',
#   'mosquito bites can spread yellow fever malaria and other parasite diseases.',
#   'a mountain is a landform that rises steeply above surrounding land.',
#   'mountains rise higher than hills and sometimes have snow at the top.',
#   'a range of mountains forms due to tectonic plate collision.',
#   'mountaineers are people who climb or hike up mountains.',
#   'the mouth is the face cavity we put food in when we eat.',
#   'the mouth has teeth to chew food and mix it with saliva.',
#   'the mouth is also used for kissing and talking.',
#   'speech sounds are controlled by tongue placement in the mouth.',
#   'a mug is a sturdy cup with a handle for drinking hot liquids.',
#   'a mug is normally ceramic but can also be made of metal or glass.',
#   'a mug is thick and has a ring base for thermal insulation.',
#   'mugs can be plain or have drawings imprinted or carved on them.',
#   'murder is the unlawful killing of another human being with intent.',
#   'murder a serious crime because it deprives the victim of their existence.',
#   'killing in self-defense accidentally or in war is not considered murder.',
#   'a convicted murderer is often given a life sentence or the death penalty.',
#   'orange juice is a drink made from the liquid in orange pulp.',
#   'orange juice has a sweet acid taste and contains a lot of vitamin c.',
#   'freshly squeezed orange juice often contains pulp as well.',
#   'orange juice is often drunk at breakfast from a glass.',
#   'a parrot is a bird that lives in warm and tropical regions.',
#   'parrots have brightly-colored feathers and a sharp curved beak.',
#   'parrots can imitate the human voice if they hear it repeatedly.',
#   'their appearance and abilities makes them popular pets.',
#   'a peach is an orange-yellow fruit with a characteristic smell.',
#   'the skin of a peach is thin and covered in small fine hairs.',
#   'peaches have a large red-brown stone inside which contains the seed.',
#   'peaches are sweet and delicate and must be harvested after ripening.',
#   'the piano is a popular musical instrument played by means of a keyboard.',
#   'pressing a piano key causes a felt-tipped hammer to hit a vibrating steel string.',
#   'the piano has an enormous note range and pedals to change the sound quality.',
#   'the piano repertoire is large and famous pianists can give solo concerts.',
#   'piranhas are small ferocious fish that live in south american rivers.',
#   'piranhas live and attack in schools and are most active during the day.',
#   'piranhas have very sharp teeth and are opportunistic carnivores.',
#   'piranhas eat fish insects lizards mammals and carrion.',
#   'the raspberry is a fruit that grows in forest clearings or fields.',
#   'a single raspberry consists of many small fruits joined together.',
#   'raspberries are eaten by themselves or cooked with sugar into jam.',
#   'leaves of the raspberry are used fresh or dried in herbal teas.',
#   'a raven is a large black bird that thrives in many climates.',
#   'ravens feed on carrion insects berries or small animals.',
#   'ravens have large brains and are capable of problem solving.',
#   'in folklore ravens are birds of ill-omen and also tricksters.',
#   'a refrigerator is a cooling device used to contain and preserve food.',
#   'some refrigerators can have a small compartment at freezing temperature.',
#   'a refrigerator can have shelves and small compartments for different types of food.',
#   'a refrigerator is generally white and people often put magnets on its surface.',
#   'a rifle is a firearm that rests on the shoulder and has a barrel with twisting grooves.',
#   'the grooves make the bullets spin around the rifle axis as they fly through the air.',
#   'rifles are used in hunting and shooting sports sometimes with scopes.',
#   'assault rifles can fire in bursts and are the standard infantry weapon.',
#   'salmon is a fish that migrates from fresh water to the ocean and back to spawn.',
#   'salmon flesh is orange or red and has high protein content and a nice taste.',
#   'salmon can be eaten raw in sushi or cooked by grilling poaching or in other ways.',
#   'salmon is the most common farmed fish though it can also be caught in the wild.',
#   'a saw is a tool that uses a hard blade or abrasive wire to cut hard materials.',
#   'the small sharp points along the cutting side of the saw are called the teeth.',
#   'saws can be worked by hand or powered by an electric motor or gas engine.',
#   'saws are used extensively in forestry construction carpentry and medicine.',
#   'a scientist studies and produces new knowledge about the physical world.',
#   'a scientist creates hypotheses and does experiments to test them.',
#   'physics chemistry and biology are classic examples of sciences.',
#   'scientists publish their research in journals and conferences.',
#   'scissors are a two-bladed instrument used for cutting.',
#   'the blades are usually metallic with plastic or metal handles.',
#   'depending on the size and format scissors can cut paper hair or fabric.',
#   'shears are large scissors used for cutting shrubs or pieces of metal.',
#   'a screwdriver is a tool for inserting and tightening screws into something.',
#   'screwdrivers can also be used to remove screws after they are inserted.',
#   'the screwdriver tip applies the torque from rotating the handle.',
#   'the two major types of screwdrivers are phillips and flathead.',
#   'a shark is a large fish with a cartilage skeleton.',
#   'sharks have streamlined bodies with a large dorsal fin.',
#   'most sharks predate on fish and mammals with powerful jaws.',
#   'sharks have very keen senses and can detect electrical fields.',
#   'a ship is a large vehicle that floats and travels on water.',
#   'a ship can be powered in the ocean by sails steam or diesel engines.',
#   'ships are used to fish in the ocean and to transport cargo containers.',
#   'cruise ships are floating hotels that take people between cities.',
#   'a shoe is clothing for the foot with a sole an outsole and a heel.',
#   'shoes are usually made of leather canvas rubber or plastic.',
#   "women's shoes often have high heels and come in many styles and colors.",
#   'a sneaker is a shoe for sports and athletic activity.',
#   'a soldier is a member of the national armed forces who fights on land.',
#   'a soldier in the militia must wear a uniform usually camouflage.',
#   'in a volunteer army a soldier is paid for his or her work.',
#   'a soldier fights using weapons such as rifles and grenades.',
#   'spears are weapons that consist of a pole and sharpened head at one end.',
#   'spears were the most common personal weapon before the advent of firearms.',
#   'spears were used for stabbing or throwing when fighting in war.',
#   'some native people still use the spear for hunting and fishing.',
#   'spiders are insects with eight legs that make silk.',
#   'spiders build webs with silk and use them to catch insects.',
#   'spiders use venomous fangs to paralyse their stuck prey.',
#   'spiders can be as small as a coin or as big as a bird.',
#   'swamps are low spongy land subject to frequent inundation.',
#   'a swamp is covered with shallow water mud and vegetation.',
#   'swamps are nesting and breeding grounds for birds and reptiles.',
#   'farmers often drain swamps to produce fertile arable land.',
#   'a sweater is a heavy garment worn on the torso for warmth.',
#   'sweaters are often knitted from wool but cotton is also common.',
#   'a sweater that opens down the front is called a cardigan.',
#   'sweaters differ in cut collar and sleeve shape as well as decoration.',
#   'a table is a piece of furniture with a flat surface and legs.',
#   'there are usually chairs around a table for people to sit.',
#   'people set cutlery plates and food on a table to eat a meal together.',
#   'tables are also used as surfaces to work or write on.',
#   'a television is an appliance with a screen that displays moving images.',
#   'televisions are mostly used for watching programs or films.',
#   'they are used to play videogames when connected to a game console.',
#   'television content can be broadcast or received via cable or internet.',
#   "theft is the taking of person's property without their consent.",
#   'thieves steal to own something or to sell it to receivers.',
#   'theft is a crime and can be punishable with jail or fines.',
#   'industrial espionage is theft of ideas and intellectual property.',
#   'a toaster is a kitchen appliance for toasting bread using heating elements.',
#   'pop-up toasters toast the bread placed in a slot and eject it once done.',
#   'toaster ovens have a door on the side a tray within and temperature control.',
#   'they allow bread to be cooked with toppings like garlic or cheese.',
#   'the tomato is a shiny and smooth red fruit with a savory taste.',
#   'a tomato softens and changes color from green to red as it gets more ripe.',
#   'tomatoes can be used to make salads soup or ketchup as well as sauce.',
#   'there are many varieties of tomato with different sizes and tastes.',
#   'a train is a connected series of cars that moves between stations on a track.',
#   'the train is pulled by a locomotive powered by diesel or electricity.',
#   'a freight train transports containers of goods or fuel over long distances.',
#   'commuter trains transport people between suburbs and stations inside a city.',
#   'a train station is a place where passengers get on or off a train.',
#   'train stations have counters or machines for purchasing tickets.',
#   'there are waiting rooms and places to eat in a station.',
#   'passengers or cargo trains enter from a platform next to the line.',
#   'a tropical cyclone is a storm formed over warm tropical sea.',
#   'cyclones can produce very powerful winds and torrential rain.',
#   'tropical cyclone can also cause high waves and coastal flooding.',
#   'a tropical cyclone can move inland and seriously damage property.',
#   'the violin is an instrument with four strings that is played with a bow.',
#   'violin is the smallest and highest pitched instrument in its family.',
#   'a violinist holds the instrument between the chin and the collarbone.',
#   'different notes are made by fingering the neck with one hand while bowing.',
#   'vultures are scavenging birds feeding mostly on the carcasses of dead animals.',
#   'many vultures have a bald head without feathers for losing heat.',
#   'vultures use their large wings to soar for miles without flapping.',
#   'vultures seldom attack healthy animals but may kill the wounded or sick.',
#   'a wall is a solid structure that defines and sometimes protects an area.',
#   'walls delineate a building support the roof and divide the space into rooms.',
#   'walls are usually made of stone brick or cement as well as drywall.',
#   'retaining walls provide a barrier to movement of earth stone or water.',
#   'water is the most common liquid on earth covering 70% of its area.',
#   'plants animals and people must drink water in order to live.',
#   'water freezes at a low temperature and becomes solid ice.',
#   'rain is water that falls from clouds in the sky which are condensed vapor.',
#   'a whale is a very large mammal that lives in the ocean.',
#   'whales breathe through blowholes on their heads when surfacing.',
#   'the blubber in a whale serves as an energy reservoir and as insulation.',
#   'whales have been hunted for meat whale oil and ambergris.',
#   'a window is a transparent opening in a wall to let light through.',
#   'a typical window is made of sheets of glass held in place by frames.',
#   'when open a window will also let air and sound through.',
#   'some windows have multiple panes to increase insulation inside.',
#   'a woman is a female human adult.',
#   'a woman is stereotypically seen as a caregiver.',
#   'a woman can become pregnant and bear children.',
#   'a woman has different reproductive organs than a man.'],
#  'Scr1': ['beekeeping encourages the conservation of habitats local.',
#   "it is in every beekeeper's interest to conserve local plants produce that pollen.",
#   'as a passive of form agriculture it does not require that native vegetation be cleared to make way for crops.',
#   'beekeepers also discourage the use of pesticides on crops because could they kill the honeybees.',
#   'artisanal beekeepers go to extremes for their craft but their is product worth the effort.',
#   'artisanal emphasizes honey-making quality and character over quantity and consistency.',
# ...
#   'is a a glove of piece clothing that the covers hand fingers and.',
#   'protect against gloves to are cold made of or wool lined material waterproof.',
#   'or latex disposable rubber are gloves used to hands shield from or germs chemicals.',
#   'is a a mitten of kind glove where four the fingers covered are together.',
#   'is a a hammer used tool to deliver impact an to object an.',
#   'is a most hammer used often drive to into wood nails.',
#   'on the the claw can head used be remove nails to.',
#   'in hammers the vary of shape head the handle length and.',
#   'grenade a is hand explosive an as used weapon against a people.',
#   'are hand thrown grenades timed and explode to bit after a that.',
#   'also be grenades can from fired or rifles launchers shoulder.',
#   'grenades are tear gas into thrown the middle a of mob disperse to it.',
#   'is a a horse hoofed large with mammal long muscular four legs.',
#   'horse a and has tail a a mane its on neck and is gray usually or brown.',
#   'been used horses have draft for travel work entertainment and.',
#   'can a ride human horse a it while trots or walks gallops.',
#   'to hospitals people go be to healed when are they sick injured or.',
#   'staffed by hospitals physicians are professional and surgeons nurses.',
#   'go there some patients specialist for diagnosis or leaving therapy the day same.',
#   'operations for or some patients treatments to have for several stay weeks.',
#   'is a a house building permanent or structure people for or to families live in.',
#   'house a and has roof a walls to out keep cold and rain and windows to let in light.',
#   'can a have house for rooms like purposes cooking or sleeping washing.',
#   'leave the most people to house work and come back at to night eat sleep and.',
#   'is a an igloo of type shelter made blocks from of by snow inuit.',
#   'built in igloos are where places snow covers land the most the of time.',
#   'often built igloos are the in shape of dome a with entrance an tunnel.',
#   'in air snow pockets the insulate and space heat warms body igloos.',
#   'is a a knife with tool a sharp that edge is to used cut things.',
#   'consist of modern knives handle a and a usually blade made metal of.',
#   'also knives been have as used and weapons in rituals instruments.',
#   'can a be knife to used by attack stabbing or slashing throwing.',
#   'the lentils seeds are a of of plant legume family the.',
#   'be red lentils brown can green or black yellow.',
#   'commonly used lentils indian are in mediterranean and cuisines.',
#   'cooked lentils by are and boiling a are source of great protein.',
#   'a biennial lettuce is often plant grown in climates temperate as leaf a vegetable.',
#   'be eaten lettuce can and cold raw in and salads other or dishes cooked.',
#   'considered fairly lettuce is to easy grow and suitable a crop beginners for.',
#   'leaves taste most lettuce but bitter some are to bred remove bitterness the.',
#   'is a a library where place a collection books of documents media and is kept.',
#   'at librarians libraries work are and at experts and organizing finding information.',
#   'go to people can libraries public and borrow to books take for home several weeks.',
#   'support scholarly academic and libraries research specialized have books.',
#   'cabin a is log small a built house round logs from.',
#   'is log a cabin of symbol frontier american and humble life origins.',
#   'were used log cabins first as by shelters settlers european.',
#   'were log built cabins logs using notch with at the joints ends.',
#   'a a male man adult human is.',
#   'becomes a a after boy man through passing puberty.',
#   'manhood with masculinity is virility and associated.',
#   'from women men differ height in and weight structure body.',
#   'a white milk is produced liquid by female to mammals feed young their.',
#   'must newborn be animals milk fed they before eat solid can food.',
#   'such dairy as products and cheese are butter from milk made.',
#   'from soybeans liquid produced coconuts and sometimes is milk called.',
#   'thin mosquitos small are insects flying emit that high-pitched sound a.',
#   'mouthparts mosquitoes for have the piercing of skin and animals plants.',
#   'bite female people mosquitoes animals and suck and blood for their protein.',
#   'can mosquito spread bites fever yellow and malaria parasite diseases other.',
#   'is a a mountain that landform steeply rises surrounding land above.',
#   'higher mountains than rise and hills have sometimes at the snow top.',
#   'of mountains a range due forms tectonic to collision plate.',
#   'people who mountaineers or are climb up hike mountains.',
#   'is the the mouth cavity face we put in food when eat we.',
#   'has the teeth mouth chew to and food it with mix saliva.',
#   'is also the for mouth used and kissing talking.',
#   'are controlled speech sounds tongue by in placement mouth the.',
#   'is a a mug cup sturdy with a for handle drinking liquids hot.',
#   'is normally a mug but ceramic can also made be of or metal glass.',
#   'is a thick mug has and ring a for thermal base insulation.',
#   'be mugs plain can have or imprinted drawings carved on or them.',
#   'the murder unlawful is of killing human another with intent being.',
#   'serious murder crime a it because the deprives of their victim existence.',
#   'self-defense killing accidentally in in or is war considered murder not.',
#   'murderer is a convicted given often a life or sentence the penalty death.',
#   'is orange a juice made drink the from in orange liquid pulp.',
#   'has a orange juice acid sweet taste and a contains lot vitamin of c.',
#   'orange juice freshly contains squeezed often as pulp well.',
#   'is often orange juice at drunk from breakfast glass a.',
#   'is a a parrot that bird in lives and tropical warm regions.',
#   'brightly-colored feathers parrots a have and curved sharp beak.',
#   'imitate parrots the can voice human they if it repeatedly hear.',
#   'their abilities makes appearance popular them and pets.',
#   'is an a peach fruit orange-yellow a with smell characteristic.',
#   'of a the skin is peach thin and in covered small hairs fine.',
#   'a peaches large have stone red-brown which inside the seed contains.',
#   'sweet peaches and are and delicate be must after ripening harvested.',
#   'is a the piano musical popular instrument played means by of keyboard a.',
#   'piano key pressing a a causes felt-tipped hammer hit to a steel vibrating string.',
#   'has an the piano note enormous range and to pedals change sound the quality.',
#   'repertoire the is piano and large pianists famous give solo can concerts.',
#   'small piranhas ferocious are that fish in live american rivers south.',
#   'and attack piranhas live schools in and are active most during day the.',
#   'very sharp piranhas and have teeth opportunistic are carnivores.',
#   'piranhas insects lizards eat and mammals fish carrion.',
#   'is the a raspberry that fruit in grows clearings or forest fields.',
#   'raspberry consists a single many of fruits small together joined.',
#   'eaten raspberries by are or themselves with cooked into jam sugar.',
#   'the leaves raspberry of used are or fresh in herbal dried teas.',
#   'is a a raven black large that bird in many thrives climates.',
#   'on carrion ravens berries feed insects small or animals.',
#   'large brains ravens have are and of capable solving problem.',
#   'ravens are in folklore of birds and ill-omen tricksters also.',
#   'is a a refrigerator device cooling to used and preserve contain food.',
#   'can have some refrigerators small a at compartment temperature freezing.',
#   'can have a refrigerator and shelves small compartments different for types food of.',
#   'is generally a refrigerator and white people often magnets put on surface its.',
#   'rifle a that is firearm a rests on shoulder the and has a with barrel twisting grooves.',
#   'make the the grooves spin bullets around the rifle axis as fly they through air the.',
#   'used rifles in are and hunting sports shooting with scopes sometimes.',
#   'can assault fire rifles bursts in are and standard infantry the weapon.',
#   'a fish salmon is migrates that from fresh water to the and ocean back spawn to.',
#   'is orange salmon flesh red or and has protein high content a and nice taste.',
#   'be eaten salmon can in raw sushi or cooked by grilling or poaching in ways other.',
#   'the most salmon is farmed common fish though it can also caught be in wild the.',
#   'saw a that is tool a uses a blade hard or abrasive wire cut to hard materials.',
#   'sharp points the small the along cutting side the of saw called are the teeth.',
#   'be worked saws can hand by or powered an by electric or motor gas engine.',
#   'used extensively saws are forestry in carpentry construction medicine and.',
#   'studies a and scientist new produces about knowledge physical world the.',
#   'creates hypotheses a scientist does and to experiments them test.',
#   'and biology physics classic chemistry are of examples sciences.',
#   'scientists research in publish and journals their conferences.',
#   'scissors two-bladed instrument are for used a cutting.',
#   'are usually the blades with metallic or plastic handles metal.',
#   'the size depending on format and scissors can paper cut hair fabric or.',
#   'large shears scissors are for used shrubs cutting pieces of or metal.',
#   'is a a screwdriver for tool and inserting screws into tightening something.',
#   'also screwdrivers be can to used screws remove they are after inserted.',
#   'tip applies the screwdriver torque the rotating from handle the.',
#   'major types the two screwdrivers of phillips are flathead and.',
#   'is a a shark fish large a with skeleton cartilage.',
#   'streamlined bodies sharks a have with dorsal large fin.',
#   'predate on most sharks and fish with mammals jaws powerful.',
#   'very keen sharks have and senses detect can fields electrical.',
#   'is a a ship vehicle large floats that travels on and water.',
#   'can be a ship in powered the ocean sails by steam diesel or engines.',
#   'used to ships are in fish the ocean to and transport containers cargo.',
#   'are floating cruise ships that hotels people take cities between.',
#   'is clothing a shoe the for foot with sole a an and outsole a heel.',
#   'usually made shoes are leather of rubber canvas plastic or.',
#   "often have women's shoes heels high and come many in styles colors and.",
#   'is a a sneaker for shoe and sports activity athletic.',
#   'is a a soldier of member the national forces armed who on fights land.',
#   'in a the soldier must militia a wear usually camouflage uniform.',
#   'volunteer army in a soldier a is paid his for or work her.',
#   'fights using a soldier such weapons rifles as grenades and.',
#   'weapons that spears are of consist a pole sharpened and head one at end.',
#   'the spears most were personal common before weapon advent of the firearms.',
#   'used spears for were or stabbing when throwing in war fighting.',
#   'people some still native the use for spear and fishing hunting.',
#   'insects with spiders legs are eight make that silk.',
#   'webs spiders with build and silk them use catch insects to.',
#   'venomous fangs spiders paralyse use to stuck their prey.',
#   'be as spiders can as small a coin as or big a as bird.',
#   'low spongy swamps subject are land frequent to inundation.',
#   'is covered a swamp shallow with mud water vegetation and.',
#   'nesting and swamps are grounds breeding birds for reptiles and.',
#   'drain swamps farmers produce often to arable fertile land.',
#   'is a a sweater garment heavy on worn torso for the warmth.',
#   'often sweaters knitted are wool from cotton but also common is.',
#   'that a opens sweater the down is front a cardigan called.',
#   'in sweaters cut differ and collar shape sleeve well as as decoration.',
#   'is a a table of piece furniture with flat a surface legs and.',
#   'usually there chairs are a around for table to sit people.',
#   'cutlery plates people set food and on a to table eat meal a together.',
#   'also tables used are surfaces as work to write on or.',
#   'is a an television with appliance screen a displays moving that images.',
#   'mostly used televisions watching are for or programs films.',
#   'used they to are videogames play connected when a game to console.',
#   'can television be content or broadcast via received or internet cable.',
#   "the taking theft is person's of without property consent their.",
#   'to thieves own steal or something sell to to receivers it.',
#   'a theft crime is can and punishable be jail or with fines.',
#   'is theft industrial ideas espionage of intellectual and property.',
#   'is a a toaster appliance kitchen toasting for using heating bread elements.',
#   'toast the pop-up toasters placed bread in a and slot eject once it done.',
#   'have a toaster ovens on door the side tray a within temperature and control.',
#   'bread they to allow cooked be toppings with garlic or like cheese.',
#   'is a the tomato and shiny smooth red with fruit a taste savory.',
#   'softens and a tomato color changes from green red to as gets it more ripe.',
#   'be used tomatoes can make to salads soup ketchup or as as well sauce.',
#   'many there varieties are tomato of different with and tastes sizes.',
#   'is a a train series connected of cars moves that between on stations a track.',
#   'is the pulled train a by powered locomotive diesel or by electricity.',
#   'train a transports freight of containers or goods over long fuel distances.',
#   'transport commuter people trains suburbs between stations and a city inside.',
#   'station is a train place a where passengers on get or a off train.',
#   'have counters train machines stations or purchasing for tickets.',
#   'waiting there rooms are places and eat to a station in.',
#   'cargo passengers trains or from enter platform a to the next line.',
#   'cyclone a is tropical storm a over formed tropical sea warm.',
#   'produce very cyclones winds can powerful torrential and rain.',
#   'can also tropical cyclone high cause and waves flooding coastal.',
#   'cyclone can a tropical inland move seriously and property damage.',
#   'is an the violin with instrument four strings is that played a with bow.',
#   'the violin smallest is highest and instrument pitched its family in.',
#   'holds a the violinist between instrument chin the the collarbone and.',
#   'are made different notes fingering by the neck one with hand bowing while.',
#   'scavenging vultures birds are mostly feeding the on of dead carcasses animals.',
#   'have many a vultures head bald feathers without losing heat for.',
#   'their vultures large use to wings for soar without flapping miles.',
#   'attack vultures healthy seldom but animals kill may wounded or the sick.',
#   'is a a wall structure solid that defines sometimes and protects area an.',
#   'a building walls delineate the support roof and the divide space rooms into.',
#   'usually made walls are stone of brick or as cement well drywall as.',
#   'provide retaining a walls to barrier of movement stone or earth water.',
#   'the most water is liquid common on earth 70% covering of area its.',
#   'and plants people animals drink must in water to live order.',
#   'at a water freezes temperature low becomes and ice solid.',
#   'water that rain is from falls clouds in sky the which condensed are vapor.',
#   'is a a whale large very that mammal in the lives ocean.',
#   'through blowholes whales their breathe on when heads surfacing.',
#   'in a the blubber serves whale as an reservoir energy and insulation as.',
#   'been hunted whales have meat for oil whale ambergris and.',
#   'is a a window opening transparent in a to wall let through light.',
#   'window is a typical of made sheets of held glass in by place frames.',
#   'a when window open also will air let sound through and.',
#   'have multiple some to windows panes insulation increase inside.',
#   'a a female woman adult human is.',
#   'a stereotypically seen woman a as is caregiver.',
#   'a become pregnant woman bear and can children.',
#   'has different a organs woman reproductive a than man.']}

# %% [markdown]
# `save xarrays with scrambled stimulus sets`

# %%
def make_datasets(scrambled_sentence_list, cond):
    """
    Input: text file for each scrambling condition
    Output: Saves pickle files for each condition
    (same xarray just different stimulus_set!)
    """
    stimuli_scrambled = stimuli_df.copy()
    stimuli_scrambled["sentence"] = scrambled_sentence_list

    fname = f"{savedir}/stimuli_{cond}.pkl"
    with open(fname, 'wb') as fout:
        pickle.dump(stimuli_scrambled, fout)

for cond, scrambled_sentence_list in condition_dict.items():
    make_datasets(scrambled_sentence_list, cond)
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## 2. Create low PMI scrambled dataset version (Mollica et al. 2020)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ckauf/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /home/ckauf/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stimuli_files = ["stim_243sentences_nopunct.txt", "stim_384sentences_nopunct.txt"]

def create_low_pmi(stimuli_files):
    
    content_regex = re.compile('JJ.*|NN.*|RB.*|VB.*')
    #JJ = adjectives
    #NN = nouns
    #RB = adverbs
    #VB = verbs
    
    lowPMI = []

    for filename in stimuli_files:
        with open(os.path.join(stimuli_path,filename), "r") as f:
            sentences = f.readlines()
            sentences = [x.strip().lower() for x in sentences]

        for sent in sentences:
            words = re.split(r'\s+', sent) #don't use NLTK word tokenizer, or else build work-around for 's sentences
            pos_tagged = nltk.pos_tag(words)

            content = [x[0] for x in pos_tagged if re.match(content_regex,x[1])]
            function = [x[0] for x in pos_tagged if not re.match(content_regex,x[1])]

            content1 = []
            content2 = []
            for i, c in enumerate(content): #create two lists of content words (even and odd indexed content words in the sentence)
                if i % 2 == 0:
                    content1.append(c)
                else:
                    content2.append(c)
            function1 = []
            function2 = []
            for i, c in enumerate(function): #create two lists of function words (even and odd indexed function words in the sentence)
                if i % 2 == 0:
                    function1.append(c)
                else:
                    function2.append(c)
            lowPMI.append(' '.join(content1 + function1 + function2 + content2)+".")

    stimuli_lowPMI = stimuli_df.copy()
    stimuli_lowPMI["sentence"] = lowPMI

    fname = f"{savedir}/stimuli_lowPMI.pkl"
    with open(fname, 'wb') as fout:
        pickle.dump(stimuli_lowPMI, fout)

    return lowPMI

lowPMI = create_low_pmi(stimuli_files)
print("Done!")
# Out:
# Done!

# %% [markdown]
# ## 3. Create random word-list dataset version (Mollica et al. 2020)

# %%
stim_243 = os.path.join(stimuli_path, 'stim_243sentences_nopunct.txt')
stim_384 = os.path.join(stimuli_path, 'stim_384sentences_nopunct.txt')

# %%
all_words = []
lengths = []

for l in open(stim_243, 'r'):
    l = l.strip().lower()
    
    words = re.split(r'\s+', l)
    lengths.append(len(words))
    all_words += words

for l in open(stim_384, 'r'):
    l = l.strip().lower()
    
    words = re.split(r'\s+', l)
    lengths.append(len(words))
    all_words += words

print(len(all_words))
print(len(lengths))
random.shuffle(all_words)

random_sentences = []
for n in lengths:
    random_sample = random.sample(all_words,n)
    new_sentence = ' '.join(random_sample) + '.'
    random_sentences.append(new_sentence)
    
    [all_words.remove(elm) for elm in random_sample] #remove selected words from list
    #print(len(all_words))
    
assert len(all_words) == 0, f"Not all words from the dataset have been used. Length of word list is {len(all_words)}!"

print(random_sentences[:10])

stimuli_random = stimuli_df.copy()
stimuli_random["sentence"] = random_sentences

fname = f"{savedir}/stimuli_random.pkl"
with open(fname, 'wb') as fout:
    pickle.dump(stimuli_random, fout)
# Out:
# 7730
# 627
# ['three climb around the the spears vapor.', 'of shears metallic is in individual machine for fracture a singer can have.', "insulation body used i've control a fever shark a side crop humble pliers treated and places beekeeper large characteristic own.", 'stop stone the act are flood export and genetic cultures edge varieties reptiles used people.', 'polar almost a a she crime furniture many have the as taste if a of.', 'the sauce an hammers of log driving to and let.', 'was musical of the at that most apply ice swamp of.', 'cabin to meant were the drop glass objects the night the heads for hand same orchestra.', 'or in a locks of to can a the to four instantly replacement are things.', 'patients a plant is the regions small evidence eye bone solid.']

# %% [markdown]
# ## 4. Create backward dataset version (control for Mollica et al. 2020)

# %%
backward_stim = []

for l in open(stim_243, 'r'):
    l = l.strip().lower()
    
    words = re.split(r'\s+', l)
    new_words = words[::-1]
    new_sent = ' '.join(new_words) + '.'
    backward_stim.append(new_sent)

for l in open(stim_384, 'r'):
    l = l.strip().lower()
    
    words = re.split(r'\s+', l)
    new_words = words[::-1]
    new_sent = ' '.join(new_words) + '.'
    backward_stim.append(new_sent)

print(len(backward_stim))
print(words)
print(new_words)
print(new_sent)

stimuli_backward = stimuli_df.copy()
stimuli_backward["sentence"] = backward_stim

fname = f"{savedir}/stimuli_backward.pkl"
with open(fname, 'wb') as fout:
    pickle.dump(stimuli_backward, fout)
stimuli_backward
# Out:
# 627
# ['a', 'woman', 'has', 'different', 'reproductive', 'organs', 'than', 'a', 'man']
# ['man', 'a', 'than', 'organs', 'reproductive', 'different', 'has', 'woman', 'a']
# man a than organs reproductive different has woman a.
#                                               sentence  sentence_num  \
# 0    habitats local of conservation the encourages ...             0
# 1    pollen produce that plants local conserve to i...             1
# 2    crops for way make to cleared be vegetation na...             2
# 3    honeybees the kill could they because crops on...             3
# 4    effort the worth is product their but craft th...             4
# ..                                                 ...           ...
# 622  inside insulation increase to panes multiple h...           379
# 623                   adult human female a is woman a.           380
# 624    caregiver a as seen stereotypically is woman a.           381
# 625     children bear and pregnant become can woman a.           382
# 626  man a than organs reproductive different has w...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
# [627 rows x 8 columns]

# %%
backward_stim[:5]
# Out:
# ['habitats local of conservation the encourages beekeeping.',
#  "pollen produce that plants local conserve to interest beekeeper's every in is it.",
#  'crops for way make to cleared be vegetation native that require not does it agriculture of form passive a as.',
#  'honeybees the kill could they because crops on pesticides of use the discourage also beekeepers.',
#  'effort the worth is product their but craft their for extremes to go beekeepers artisanal.']

# %% [markdown]
# ## 5. Create random LowPMI dataset version (control for Mollica et al. 2020)
#
# ### requires OM

# %% [markdown]
# `go to folder "add_random_lowPMI_condition" & follow instructions there.`
